# %%
import pandas as pd
import numpy as np
import yfinance as yf
import os
import time
import concurrent.futures
from typing import Dict, Any
import logging
from threading import Lock

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Thread-safe lock for file writing
file_lock = Lock()

# %%
import glob
import gradio as gr
import google.generativeai as genai
from dotenv import load_dotenv
import re

# %%
# imports for langchain and Chroma and plotly

from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.schema import Document, BaseRetriever
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.prompts import PromptTemplate

# from langchain_huggingface import HuggingFaceEmbeddings

from langchain.vectorstores import Chroma

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.prompts import ChatPromptTemplate

import numpy as np
from sklearn.manifold import TSNE
import plotly.graph_objects as go
from typing import List
from pydantic import Field

# %%
# constants
end_date = "2025-05-16"

# %%
def calculate_rsi(data, window=14):
    # Ensure the 'Close' column is correctly accessed
    if isinstance(data.columns, pd.MultiIndex):
        close_prices = data['Close'].iloc[:, 0]
    else:
        close_prices = data['Close']

    # Calculate price changes
    delta = close_prices.diff()

    # Separate gains (positive) and losses (negative)
    gains = delta.where(delta > 0, 0)
    losses = -delta.where(delta < 0, 0)

    # Initialize the averages
    avg_gains = [np.nan] * len(close_prices)
    avg_losses = [np.nan] * len(close_prices)

    # Calculate first averages after initial window
    first_avg_gain = gains[1:window+1].mean()
    first_avg_loss = losses[1:window+1].mean()
    avg_gains[window] = first_avg_gain
    avg_losses[window] = first_avg_loss

    # Calculate subsequent values using the Wilder's smoothing method
    for i in range(window+1, len(close_prices)):
        avg_gain = (avg_gains[i-1] * (window-1) + gains.iloc[i]) / window
        avg_loss = (avg_losses[i-1] * (window-1) + losses.iloc[i]) / window
        avg_gains[i] = avg_gain
        avg_losses[i] = avg_loss

    # Convert to Series with proper index
    avg_gains = pd.Series(avg_gains, index=close_prices.index)
    avg_losses = pd.Series(avg_losses, index=close_prices.index)

    # Calculate RS and RSI
    rs = avg_gains / avg_losses
    rsi = 100 - (100 / (1 + rs))

    return rsi

# %%
def get_stock_data(symbol, period='1y', end_date=None):
    """Fetch stock data with proper error handling and ensure unique data per stock

    Args:
        symbol (str): Stock symbol
        period (str): Data period to fetch (default='1y')
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses current date

    Returns:
        tuple: (DataFrame with stock data, actual_end_date)
    """
    try:
        time.sleep(1)  # Add delay to prevent rate limiting

        kwargs = {
            'tickers': f"{symbol}.NS",
            'period': period,
            'progress': False,
            'threads': False,
            'ignore_tz': True,
            'auto_adjust': True,
            'prepost': False,
            'repair': True
        }

        # Add end parameter if end_date is provided
        if end_date:
            kwargs['end'] = end_date
            # Calculate start date based on period
            if period == '1y':
                start_date = pd.to_datetime(end_date) - pd.DateOffset(years=1)
            elif period == '2y':
                start_date = pd.to_datetime(end_date) - pd.DateOffset(years=2)
            kwargs['start'] = start_date.strftime('%Y-%m-%d')

        # Download data
        data = yf.download(**kwargs)

        if data.empty:
            logger.warning(f"No data available for {symbol}")
            return pd.DataFrame(), None

        # Get the actual last date from the data
        actual_end_date = data.index[-1]

        # Handle multi-index columns if present
        if isinstance(data.columns, pd.MultiIndex):
            df = pd.DataFrame(index=data.index)
            column_map = {
                'Open': ('Open', symbol + '.NS'),
                'High': ('High', symbol + '.NS'),
                'Low': ('Low', symbol + '.NS'),
                'Close': ('Close', symbol + '.NS'),
                'Volume': ('Volume', symbol + '.NS')
            }
            for col, multi_idx in column_map.items():
                try:
                    if multi_idx in data.columns:
                        df[col] = data[multi_idx]
                    else:
                        df[col] = data[(multi_idx[0],)]
                except:
                    df[col] = data[multi_idx[0]]
        else:
            df = data.copy()

        # Verify data is valid
        if 'Close' in df.columns:
            latest_price = df['Close'].iloc[-1]
            logger.info(f"Verified unique data for {symbol}: Latest price = Rs.{latest_price:.2f}")
            if end_date:
                requested_date = pd.to_datetime(end_date).normalize()
                actual_date = actual_end_date.normalize()
                if actual_date != requested_date:
                    logger.info(f"Note: Last available date ({actual_date.strftime('%Y-%m-%d')}) differs from requested date ({requested_date.strftime('%Y-%m-%d')})")
        else:
            logger.error(f"Missing Close column for {symbol}")
            return pd.DataFrame(), None

        return df, actual_end_date

    except Exception as e:
        logger.error(f"Error fetching data for {symbol}: {e}")
        return pd.DataFrame(), None

# %%
def calculate_macd(data, fast=12, slow=26, signal=9):
    try:
        # Make sure we're working with a copy of the data to avoid warnings
        if isinstance(data.columns, pd.MultiIndex):
            close_series = data['Close'].iloc[:, 0].copy()
        else:
            close_series = data['Close'].copy()

        # Calculate EMAs
        ema_fast = close_series.ewm(span=fast, adjust=False).mean()
        ema_slow = close_series.ewm(span=slow, adjust=False).mean()

        # Calculate MACD components
        macd_line = ema_fast - ema_slow
        signal_line = macd_line.ewm(span=signal, adjust=False).mean()
        histogram = macd_line - signal_line

        return macd_line, signal_line, histogram
    except Exception as e:
        logger.error(f"Error calculating MACD: {e}")
        empty_series = pd.Series(dtype=float)
        return empty_series, empty_series, empty_series

# %%
def calculate_momentum(data, period=20):
    try:
        if isinstance(data.columns, pd.MultiIndex):
            close_series = data['Close'].iloc[:, 0]
        else:
            close_series = data['Close']

        momentum = close_series / close_series.shift(period) - 1
        return momentum * 100
    except Exception as e:
        logger.error(f"Error calculating momentum: {e}")
        return pd.Series(dtype=float)

# %%
def calculate_momentum_index(data, period=126):
    try:
        if isinstance(data.columns, pd.MultiIndex):
            close_series = data['Close'].iloc[:, 0]
        else:
            close_series = data['Close']

        returns = close_series.pct_change().dropna()
        momentum_std = returns.rolling(window=period).std() * np.sqrt(252)
        return momentum_std
    except Exception as e:
        logger.error(f"Error calculating momentum index: {e}")
        return pd.Series(dtype=float)

# %%
def get_fundamental_data(symbol: str) -> Dict[str, Any]:
    """Fetch fundamental data"""
    try:
        ticker = yf.Ticker(f"{symbol}.NS")
        info = ticker.info
        fundamental_data = {
            'P/E Ratio': info.get('trailingPE', 'N/A'),
            'Forward P/E': info.get('forwardPE', 'N/A'),
            'Market Cap': info.get('marketCap', 'N/A'),
            'EPS': info.get('trailingEps', 'N/A'),
            'Dividend Yield': info.get('dividendYield', 'N/A'),
            'Debt to Equity': info.get('debtToEquity', 'N/A'),
            'Return on Equity': info.get('returnOnEquity', 'N/A'),
            'Revenue Growth': info.get('revenueGrowth', 'N/A'),
            'Profit Margins': info.get('profitMargins', 'N/A'),
            'Beta': info.get('beta', 'N/A'),
            'Current Ratio': info.get('currentRatio', 'N/A'),
            'Book Value': info.get('bookValue', 'N/A'),
            '52-Week High': info.get('fiftyTwoWeekHigh', 'N/A'),
            '52-Week Low': info.get('fiftyTwoWeekLow', 'N/A'),
            'Target Price': info.get('targetMeanPrice', 'N/A')
        }
        return fundamental_data
    except Exception as e:
        logger.error(f"Error fetching fundamental data for {symbol}: {e}")
        return {}

# %%
def determine_strength(data, rsi, macd_line, signal_line):
    # Ensure data is not empty
    if isinstance(data, pd.DataFrame) and data.empty:
        return [], []

    # Handle multi-index columns if they exist
    if isinstance(data.columns, pd.MultiIndex):
        # Extract the first level columns if multi-index
        data_cols = {
            'Open': data['Open'].iloc[:, 0],
            'High': data['High'].iloc[:, 0],
            'Low': data['Low'].iloc[:, 0],
            'Close': data['Close'].iloc[:, 0],
            'Volume': data['Volume'].iloc[:, 0]
        }
        data_df = pd.DataFrame(data_cols, index=data.index)
    else:
        data_df = data

    current_price = data_df['Close'].iloc[-1]
    sma_50 = data_df['Close'].rolling(window=50).mean().iloc[-1]
    sma_200 = data_df['Close'].rolling(window=200).mean().iloc[-1]

    # Convert any Series to scalar values
    if isinstance(current_price, pd.Series):
        current_price = current_price.iloc[0]
    if isinstance(sma_50, pd.Series):
        sma_50 = sma_50.iloc[0]
    if isinstance(sma_200, pd.Series):
        sma_200 = sma_200.iloc[0]

    strengths = []
    weaknesses = []

    # RSI Analysis
    if not isinstance(rsi, pd.Series) or len(rsi) == 0:
        print("RSI data is empty")
    else:
        last_rsi = rsi.iloc[-1]
        if isinstance(last_rsi, pd.Series):
            last_rsi = last_rsi.item()
        if last_rsi > 70:
            weaknesses.append("RSI indicates overbought conditions")
        elif last_rsi < 30:
            strengths.append("RSI indicates oversold conditions (potential buying opportunity)")
        elif 40 <= last_rsi <= 60:
            strengths.append("RSI in neutral zone showing balance between buyers and sellers")
        elif 60 < last_rsi < 70:
            strengths.append("Strong RSI showing positive momentum")

    # MACD Analysis
    if (not isinstance(macd_line, pd.Series) or len(macd_line) == 0 or
        not isinstance(signal_line, pd.Series) or len(signal_line) == 0):
        print("MACD or signal line data is empty")
    else:
        macd_value = macd_line.iloc[-1]
        signal_value = signal_line.iloc[-1]
        if isinstance(macd_value, pd.Series):
            macd_value = macd_value.item()
        if isinstance(signal_value, pd.Series):
            signal_value = signal_value.item()
        if macd_value > signal_value:
            strengths.append("MACD line above signal line indicating bullish momentum")
        else:
            weaknesses.append("MACD line below signal line indicating bearish momentum")

    # Moving Average Analysis
    if pd.notna(sma_50) and pd.notna(current_price):
        if current_price > sma_50:
            strengths.append("Price above 50-day SMA showing short-term strength")
        else:
            weaknesses.append("Price below 50-day SMA showing short-term weakness")

    if pd.notna(sma_200) and pd.notna(current_price):
        if current_price > sma_200:
            strengths.append("Price above 200-day SMA suggesting long-term uptrend")
        else:
            weaknesses.append("Price below 200-day SMA suggesting long-term downtrend")

    # Golden/Death Cross
    if pd.notna(sma_50) and pd.notna(sma_200):
        if sma_50 > sma_200 and (sma_50 / sma_200 - 1) < 0.03:
            strengths.append("Recent golden cross or nearing golden cross (50-day SMA crossing above 200-day SMA)")
        elif sma_50 < sma_200 and (sma_200 / sma_50 - 1) < 0.03:
            weaknesses.append("Recent death cross or nearing death cross (50-day SMA crossing below 200-day SMA)")

    # Volume Analysis
    avg_volume = data_df['Volume'].mean()
    if isinstance(avg_volume, pd.Series):
        avg_volume = avg_volume.item()

    recent_volume = data_df['Volume'].iloc[-5:].mean()
    if isinstance(recent_volume, pd.Series):
        recent_volume = recent_volume.item()

    # Calculate price trend
    recent_price_mean = data_df['Close'].iloc[-5:].mean()
    if isinstance(recent_price_mean, pd.Series):
        recent_price_mean = recent_price_mean.item()

    price_trend_up = current_price > recent_price_mean

    if recent_volume > avg_volume * 1.2:
        if price_trend_up:
            strengths.append("Strong volume supporting upward price movement")
        else:
            weaknesses.append("High volume during price decline indicates selling pressure")
    elif recent_volume < avg_volume * 0.8:
        if price_trend_up:
            strengths.append("Price rising on low volume - potential weakness")
        else:
            weaknesses.append("Price declining on low volume - potential for reversal")

    # Price Movement
    if len(data_df['Close']) >= 22:
        latest_price = data_df['Close'].iloc[-1]
        price_22_days_ago = data_df['Close'].iloc[-22]

        if isinstance(latest_price, pd.Series):
            latest_price = latest_price.item()
        if isinstance(price_22_days_ago, pd.Series):
            price_22_days_ago = price_22_days_ago.item()

        monthly_return = (latest_price / price_22_days_ago - 1) * 100

        if monthly_return > 5:
            strengths.append(f"Strong monthly return of {monthly_return:.2f}%")
        elif monthly_return < -5:
            weaknesses.append(f"Weak monthly return of {monthly_return:.2f}%")

    # Volatility
    if len(data_df['Close']) >= 2:
        returns = data_df['Close'].pct_change().dropna()
        if len(returns) > 0:
            volatility = returns.std() * np.sqrt(252) * 100
            if isinstance(volatility, pd.Series):
                volatility = volatility.item()

            if volatility > 30:
                weaknesses.append(f"High volatility ({volatility:.2f}%) indicating increased risk")
            elif volatility < 15:
                strengths.append(f"Low volatility ({volatility:.2f}%) indicating stability")

    return strengths, weaknesses

# %%
def get_weekday(date):
    """Get weekday number (1=Monday to 7=Sunday)"""
    return date.isoweekday()

def get_next_friday(target_date):
    """Get the next Friday from a given date. If the date is Friday, return the same date."""
    weekday = get_weekday(target_date)
    if weekday == 5:  # If Friday
        return target_date

    days_until_friday = {
        1: 4,  # Monday -> +4 days
        2: 3,  # Tuesday -> +3 days
        3: 2,  # Wednesday -> +2 days
        4: 1,  # Thursday -> +1 day
        6: 6,  # Saturday -> +6 days
        7: 5   # Sunday -> +5 days
    }
    days_to_add = days_until_friday[weekday]
    return target_date + pd.Timedelta(days=days_to_add)

def get_next_thursday(target_date):
    """Get the next Thursday from a given date. If the date is Friday, return the previous day."""
    weekday = get_weekday(target_date)
    if weekday == 5:  # If Friday
        return target_date - pd.Timedelta(days=1)
    return get_next_friday(target_date) - pd.Timedelta(days=1)

def find_closest_trading_day(data, target_date):
    """Find the closest trading day in the data for a given target date"""
    target_friday = get_next_friday(target_date)
    target_thursday = get_next_thursday(target_date)

    # Convert index to datetime if it's not already and normalize to remove time component
    date_index = pd.to_datetime(data.index).normalize()

    # Normalize target dates to remove time component
    target_friday = pd.to_datetime(target_friday).normalize()
    target_thursday = pd.to_datetime(target_thursday).normalize()

    # Try to find exact matches first
    friday_match = date_index[date_index == target_friday]
    thursday_match = date_index[date_index == target_thursday]

    if not friday_match.empty:
        return friday_match[0]
    elif not thursday_match.empty:
        return thursday_match[0]

    # If no exact match, find the closest available date
    all_dates = date_index
    closest_date = min(all_dates, key=lambda x: abs(x - target_friday))

    return closest_date

def get_date_one_year_back(data, from_date=None):
    """Calculate the date from the given date (or last date in stock data) to 1 year back"""
    if from_date:
        last_date = pd.to_datetime(from_date).normalize()
    else:
        last_date = pd.to_datetime(data.index[-1]).normalize()
    target_date = last_date - pd.DateOffset(months=12)
    return find_closest_trading_day(data, target_date)

def get_date_six_months_back(data, from_date=None):
    """Calculate the date from the given date (or last date in stock data) to 6 months back"""
    if from_date:
        last_date = pd.to_datetime(from_date).normalize()
    else:
        last_date = pd.to_datetime(data.index[-1]).normalize()
    target_date = last_date - pd.DateOffset(months=6)
    return find_closest_trading_day(data, target_date)

def get_first_available_date(data):
    """Get the first date for which price data is available"""
    return pd.to_datetime(data.index[0]).normalize()

def get_prices_for_dates(data, end_date=None):
    """Get prices for specified date (or current date), 6 months back and 1 year back, and calculate price changes.

    Args:
        data (pd.DataFrame): Stock price data with 'Close' prices
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses last date in data

    Returns:
        dict: Dictionary containing price data and changes for different time periods
    """
    # Get the actual last date from data
    actual_last_date = pd.to_datetime(data.index[-1]).normalize()

    # If end_date is provided but different from actual_last_date, use actual_last_date
    if end_date:
        requested_date = pd.to_datetime(end_date).normalize()
        if requested_date != actual_last_date:
            logger.info(f"Using last available date {actual_last_date.strftime('%Y-%m-%d')} instead of requested date {requested_date.strftime('%Y-%m-%d')}")
            current_date = actual_last_date
        else:
            current_date = requested_date
    else:
        current_date = actual_last_date

    six_month_date = get_date_six_months_back(data, current_date)
    one_year_date = get_date_one_year_back(data, current_date)
    first_available_date = get_first_available_date(data)

    # Handle multi-index columns if they exist
    if isinstance(data.columns, pd.MultiIndex):
        close_prices = data['Close'].iloc[:, 0]
    else:
        close_prices = data['Close']

    # Get current price (should always be available since we're using actual last date)
    current_price = close_prices[current_date]

    # Get 6-month price if available, otherwise use first available date
    try:
        six_month_price = close_prices[six_month_date]
        six_month_actual_date = six_month_date
    except KeyError:
        six_month_price = close_prices[first_available_date]
        six_month_actual_date = first_available_date

    # Get 1-year price if available, otherwise use first available date
    try:
        one_year_price = close_prices[one_year_date]
        one_year_actual_date = one_year_date
    except KeyError:
        one_year_price = close_prices[first_available_date]
        one_year_actual_date = first_available_date

    # Calculate price changes
    twelve_month_change = (current_price / one_year_price - 1) if one_year_price != 0 else 0
    six_month_change = (current_price / six_month_price - 1) if six_month_price != 0 else 0

    # Create a dictionary with dates, prices and price changes
    price_data = {
        'Current': {
            'date': current_date.strftime('%Y-%m-%d'),
            'price': round(current_price, 2)
        },
        '6_months_back': {
            'date': six_month_actual_date.strftime('%Y-%m-%d'),
            'price': round(six_month_price, 2),
            'price_change_percent': round(six_month_change * 100, 2),
            'is_first_available': six_month_actual_date == first_available_date
        },
        '1_year_back': {
            'date': one_year_actual_date.strftime('%Y-%m-%d'),
            'price': round(one_year_price, 2),
            'price_change_percent': round(twelve_month_change * 100, 2),
            'is_first_available': one_year_actual_date == first_available_date
        }
    }

    return price_data

# %%
def calculate_log_returns(data, end_date=None):
    """Calculate logarithmic returns between consecutive trading days for the past year
    Returns the log returns as percentages along with the prices used in calculations.

    Args:
        data (pd.DataFrame): Stock price data with 'Close' prices
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses last date in data

    Returns:
        tuple: (log_returns, price_data)
    """
    # Get the dates for 1 year period
    if end_date:
        current_date = pd.to_datetime(end_date).normalize()
    else:
        current_date = pd.to_datetime(data.index[-1]).normalize()

    one_year_back_date = get_date_one_year_back(data, end_date)

    # Handle multi-index columns if they exist
    if isinstance(data.columns, pd.MultiIndex):
        close_prices = data['Close'].iloc[:, 0]
    else:
        close_prices = data['Close']

    # Get the slice of data between one year back and current date
    mask = (data.index >= one_year_back_date) & (data.index <= current_date)
    period_prices = close_prices[mask]

    # Create a DataFrame to store prices and calculations
    price_data = pd.DataFrame({
        'Current_Price': period_prices.astype(float),
        'Previous_Price': period_prices.shift(1).astype(float)
    })

    # Calculate price ratios first (current/previous)
    price_data['Price_Ratio'] = price_data['Current_Price'] / price_data['Previous_Price']

    # Calculate log returns exactly as Excel does: LN(current/previous)
    price_data['Log_Return_Percent'] = np.log(price_data['Price_Ratio']) * 100

    # Round to 3 decimal places after all calculations
    price_data['Log_Return_Percent'] = price_data['Log_Return_Percent'].round(3)

    # Round other columns to 2 decimal places
    for column in ['Current_Price', 'Previous_Price', 'Price_Ratio']:
        price_data[column] = price_data[column].round(2)

    # Drop the first row as it will have NaN values due to the shift operation
    price_data = price_data.dropna()

    # Create the log returns series
    log_returns = price_data['Log_Return_Percent']

    return log_returns, price_data

# %%
def calculate_log_stdev(data, end_date=None):
    """Calculate standard deviation using all log values from last 1 year till the specified date.
    Similar to Excel's STDEV(A:B) where A:B would be the range of log values.
    Returns the standard deviation divided by 100.

    Args:
        data (pd.DataFrame): Stock price data with 'Close' prices
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses last date in data

    Returns:
        tuple: (one_year_stdev, six_month_stdev) where values are divided by 100
    """
    # Get the dates
    if end_date:
        current_date = pd.to_datetime(end_date).normalize()
    else:
        current_date = pd.to_datetime(data.index[-1]).normalize()

    six_month_date = get_date_six_months_back(data, end_date)
    one_year_date = get_date_one_year_back(data, end_date)

    # Get log returns for the entire period
    log_returns, _ = calculate_log_returns(data, end_date)

    try:
        # Get all log values from one year ago to current date
        one_year_mask = (log_returns.index >= one_year_date) & (log_returns.index <= current_date)
        one_year_logs = log_returns[one_year_mask]
        # Calculate standard deviation using all values in the period and divide by 100
        one_year_stdev = np.std(one_year_logs) / 100
    except KeyError:
        one_year_stdev = None

    try:
        # Get all log values from six months ago to current date
        six_month_mask = (log_returns.index >= six_month_date) & (log_returns.index <= current_date)
        six_month_logs = log_returns[six_month_mask]
        # Calculate standard deviation using all values in the period and divide by 100
        six_month_stdev = np.std(six_month_logs) / 100
    except KeyError:
        six_month_stdev = None

    return one_year_stdev, six_month_stdev

# %%
def calculate_momentum_ratio(data, end_date=None):
    """Calculate momentum ratios for 1 year and 6 months periods.
    Momentum ratio = Price change percentage / (Standard deviation * 100)

    Args:
        data (pd.DataFrame): Stock price data with 'Close' prices
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses last date in data

    Returns:
        dict: Dictionary containing momentum ratios for both periods
    """
    # Get price changes
    prices_data = get_prices_for_dates(data, end_date)
    one_year_change = prices_data['1_year_back']['price_change_percent']
    six_month_change = prices_data['6_months_back']['price_change_percent']

    # Get standard deviations (already divided by 100 in calculate_log_stdev)
    one_year_stdev, six_month_stdev = calculate_log_stdev(data, end_date)

    # Calculate momentum ratios
    # Note: We multiply stdev by 100 to match the scale of price_change_percent
    one_year_momentum = one_year_change / (one_year_stdev * 100) if one_year_stdev else None
    six_month_momentum = six_month_change / (six_month_stdev * 100) if six_month_stdev else None

    result = {
        'momentum_ratios': {
            'one_year': round(one_year_momentum, 4) if one_year_momentum is not None else None,
            'six_month': round(six_month_momentum, 4) if six_month_momentum is not None else None
        },
        'components': {
            'one_year': {
                'price_change_percent': one_year_change,
                'standard_deviation': one_year_stdev * 100 if one_year_stdev else None
            },
            'six_month': {
                'price_change_percent': six_month_change,
                'standard_deviation': six_month_stdev * 100 if six_month_stdev else None
            }
        }
    }

    return result

# %%
def calculate_universe_stats(momentum_values):
    """Calculate standard deviation and mean for a list of momentum ratios.
    Similar to Excel's STDEV and AVERAGE functions.

    Args:
        momentum_values: List of momentum ratio values

    Returns:
        tuple: (standard_deviation, mean)
    """
    # Remove None and NaN values
    valid_values = [v for v in momentum_values if v is not None and not np.isnan(v)]

    if not valid_values:
        return None, None

    # Calculate standard deviation (similar to Excel's STDEV)
    stdev = np.std(valid_values, ddof=1)  # ddof=1 for sample standard deviation (like Excel)

    # Calculate mean (similar to Excel's AVERAGE)
    mean = np.mean(valid_values)

    return stdev, mean

# %%
def calculate_z_score(value, mean, stdev):
    """Calculate z-score for a value.

    Z-score = (value - mean) / standard_deviation

    Args:
        value: The value to calculate z-score for
        mean: Mean of the universe
        stdev: Standard deviation of the universe

    Returns:
        float: z-score or None if inputs are invalid
    """
    if value is None or mean is None or stdev is None or stdev == 0:
        return None

    return (value - mean) / stdev

# %%
def calculate_weighted_z_score(one_year_z_score, six_month_z_score, weights=None):
    """Calculate weighted z-score from 1-year and 6-month z-scores.

    Args:
        one_year_z_score: Z-score for 1-year momentum ratio
        six_month_z_score: Z-score for 6-month momentum ratio
        weights: Dictionary with weights for each period.
                Default is {'one_year': 0.5, 'six_month': 0.5}

    Returns:
        float: Weighted z-score or None if inputs are invalid
    """
    if one_year_z_score is None or six_month_z_score is None:
        return None

    # Use default weights if none provided
    if weights is None:
        weights = {'one_year': 0.5, 'six_month': 0.5}

    weighted_z_score = (
        one_year_z_score * weights['one_year'] +
        six_month_z_score * weights['six_month']
    )

    return weighted_z_score

# %%
def calculate_normalized_z_score(z_score):
    """Calculate normalized z-score using the formula: IF(z_score>0,(1+z_score),(1-z_score)^-1)

    Args:
        z_score: The z-score to normalize

    Returns:
        float: Normalized z-score or None if input is invalid
    """
    if z_score is None:
        return None

    return (1 + z_score) if z_score > 0 else (1 - z_score) ** -1

# %%
def calculate_rank(value, values_list):
    """Calculate the rank of a value within a list. Similar to Excel's RANK(number, ref, [order])

    Args:
        value: The number whose rank you want to find
        values_list: A list of numbers that defines the relative ranking

    Returns:
        int: The rank of the number (1 being the highest)
    """
    # Remove None and NaN values from the list
    valid_values = [v for v in values_list if v is not None and not np.isnan(v)]

    if value is None or np.isnan(value) or not valid_values:
        return None

    # Sort values in descending order (mimicking Excel's RANK with order=0)
    sorted_values = sorted(set(valid_values), reverse=True)

    try:
        # Find the rank (adding 1 because index starts at 0)
        rank = sorted_values.index(value) + 1
        return rank
    except ValueError:
        # Try to find closest match for floating point comparison issues
        closest_idx = min(range(len(sorted_values)),
                         key=lambda i: abs(sorted_values[i] - value))
        return closest_idx + 1

# %%
def generate_rank_analysis_markdown(stock_data, symbol, one_year_rank=None, six_month_rank=None, total_stocks=None):
    """Generate markdown documentation for RANK analysis calculations.

    This function creates detailed markdown explaining all calculations used in the analysis.
    """
    md_content = "## RANK Analysis\n\n"

    # Date Calculations Section
    md_content += "### Date Reference Points\n\n"
    current_date = stock_data.index[-1].strftime('%Y-%m-%d')
    one_year_back_date = get_date_one_year_back(stock_data)
    six_month_back_date = get_date_six_months_back(stock_data)

    md_content += f"- **Current Date:** {current_date}\n"
    md_content += f"- **1-Year Reference Date:** {one_year_back_date.strftime('%Y-%m-%d')}\n"
    md_content += f"- **6-Month Reference Date:** {six_month_back_date.strftime('%Y-%m-%d')}\n\n"

    # Price Changes Section
    md_content += "### Price Changes\n\n"
    current_price = stock_data['Close'].iloc[-1]
    year_start_price = stock_data.loc[one_year_back_date, 'Close']
    six_month_start_price = stock_data.loc[six_month_back_date, 'Close']

    year_change = (current_price / year_start_price - 1) * 100
    six_month_change = (current_price / six_month_start_price - 1) * 100

    md_content += f"**1-Year Price Change:**\n"
    md_content += f"- Start Price: ₹{year_start_price:.2f}\n"
    md_content += f"- Current Price: ₹{current_price:.2f}\n"
    md_content += f"- Change: {year_change:.2f}%\n\n"

    md_content += f"**6-Month Price Change:**\n"
    md_content += f"- Start Price: ₹{six_month_start_price:.2f}\n"
    md_content += f"- Current Price: ₹{current_price:.2f}\n"
    md_content += f"- Change: {six_month_change:.2f}%\n\n"

    # Log Returns Section
    md_content += "### Log Returns and Standard Deviation\n\n"
    log_returns, price_data = calculate_log_returns(stock_data)
    one_year_stdev, six_month_stdev = calculate_log_stdev(stock_data)

    md_content += "**Log Returns Calculation:**\n"
    md_content += "- Formula: `ln(current_price / previous_price) * 100`\n"
    md_content += f"- Recent Log Returns (last 5 days):\n"
    for date, row in price_data.tail().iterrows():
        md_content += f"  * {date.strftime('%Y-%m-%d')}: {row['Log_Return_Percent']:.3f}%\n"

    md_content += "\n**Standard Deviation:**\n"
    md_content += f"- 1-Year σ: {one_year_stdev*100:.3f}%\n"
    md_content += f"- 6-Month σ: {six_month_stdev*100:.3f}%\n\n"

    # Momentum Ratio Section
    md_content += "### Momentum Ratio\n\n"
    momentum_ratio = calculate_momentum_ratio(stock_data)

    md_content += "**Momentum Ratio Formula:** Price Change % / (Standard Deviation * 100)\n\n"

    md_content += "**1-Year Momentum Components:**\n"
    md_content += f"- Price Change: {momentum_ratio['components']['one_year']['price_change_percent']:.2f}%\n"
    md_content += f"- Standard Deviation: {momentum_ratio['components']['one_year']['standard_deviation']:.2f}%\n"
    md_content += f"- Momentum Ratio: {momentum_ratio['momentum_ratios']['one_year']:.4f}\n"
    if one_year_rank is not None and total_stocks is not None:
        md_content += f"- Rank: {one_year_rank} out of {total_stocks}\n\n"

    md_content += "**6-Month Momentum Components:**\n"
    md_content += f"- Price Change: {momentum_ratio['components']['six_month']['price_change_percent']:.2f}%\n"
    md_content += f"- Standard Deviation: {momentum_ratio['components']['six_month']['standard_deviation']:.2f}%\n"
    md_content += f"- Momentum Ratio: {momentum_ratio['momentum_ratios']['six_month']:.4f}\n"
    if six_month_rank is not None and total_stocks is not None:
        md_content += f"- Rank: {six_month_rank} out of {total_stocks}\n\n"

    return md_content

# %%
def analyze_stocks(stocks_df, output_dir="stock_analysis", max_workers=5, end_date=None):
    """Analyze a list of stocks and calculate momentum metrics for each.

    Args:
        stocks_df: List of tuples (company_name, symbol)
        output_dir: Directory to store analysis results
        max_workers: Maximum number of parallel workers
        end_date: End date for analysis in YYYY-MM-DD format
    """
    os.makedirs(output_dir, exist_ok=True)
    results = {}

    # Global rank data structure to store universe-wide statistics
    global rank_data
    rank_data = {
        'one_year': {'values': [], 'ranks': {}, 'universe_stats': {'stdev': None, 'mean': None}},
        'six_month': {'values': [], 'ranks': {}, 'universe_stats': {'stdev': None, 'mean': None}},
        'weighted_z_score': {'values': [], 'ranks': {}},
        'normalized_z_score': {'values': [], 'ranks': {}}
    }

    def process_stock(stock_tuple):
        company_name, symbol = stock_tuple
        logger.info(f"Processing {company_name} ({symbol})")

        try:
            # Get stock data with actual end date
            data, actual_end_date = get_stock_data(symbol, period='2y', end_date=end_date)
            if data.empty:
                logger.warning(f"No data available for {symbol}")
                return None

            # Use actual end date for all calculations
            actual_end_date_str = actual_end_date.strftime('%Y-%m-%d')

            # Calculate technical indicators
            rsi = calculate_rsi(data)
            macd_line, signal_line, histogram = calculate_macd(data)
            momentum_period20 = calculate_momentum(data, period=20)
            momentum_index = calculate_momentum_index(data)
            momentum_ratio = calculate_momentum_ratio(data, actual_end_date_str)

            # Get price data using actual end date
            prices = get_prices_for_dates(data, actual_end_date_str)

            # Determine strengths and weaknesses
            strengths, weaknesses = determine_strength(data, rsi, macd_line, signal_line)

            # Store the result with all necessary data
            result = {
                'company_name': company_name,
                'symbol': symbol,
                'actual_end_date': actual_end_date_str,
                'current_price': prices['Current']['price'],
                'price_data': prices,
                'technical_indicators': {
                    'rsi': rsi.iloc[-1] if not rsi.empty else None,
                    'macd': {
                        'macd_line': macd_line.iloc[-1] if not macd_line.empty else None,
                        'signal_line': signal_line.iloc[-1] if not signal_line.empty else None,
                        'histogram': histogram.iloc[-1] if not histogram.empty else None
                    },
                    'momentum': {
                        'momentum_20day': momentum_period20.iloc[-1] if not momentum_period20.empty else None,
                        'momentum_index': momentum_index.iloc[-1] if not momentum_index.empty else None,
                        'momentum_ratio': momentum_ratio
                    }
                },
                'analysis': {
                    'strengths': strengths,
                    'weaknesses': weaknesses
                },
                'data': data
            }

            # Store momentum values for universe calculations
            one_year_momentum = momentum_ratio['momentum_ratios']['one_year']
            six_month_momentum = momentum_ratio['momentum_ratios']['six_month']

            if one_year_momentum is not None:
                rank_data['one_year']['values'].append(one_year_momentum)
            if six_month_momentum is not None:
                rank_data['six_month']['values'].append(six_month_momentum)

            return result

        except Exception as e:
            logger.error(f"Error processing {symbol}: {e}")
            return None

    # Process stocks in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_stock, stock): stock for stock in stocks_df}

        for future in concurrent.futures.as_completed(futures):
            stock = futures[future]
            try:
                result = future.result()
                if result:
                    results[result['symbol']] = result
            except Exception as e:
                logger.error(f"Error processing {stock}: {e}")

    # Calculate universe statistics for both periods
    for period in ['one_year', 'six_month']:
        values = rank_data[period]['values']
        stdev, mean = calculate_universe_stats(values)
        rank_data[period]['universe_stats']['stdev'] = stdev
        rank_data[period]['universe_stats']['mean'] = mean

        # Calculate ranks and z-scores
        for symbol, result in results.items():
            momentum = result['technical_indicators']['momentum']['momentum_ratio']['momentum_ratios'][period]
            if momentum is not None:
                rank = calculate_rank(momentum, values)
                z_score = calculate_z_score(momentum, mean, stdev)
                rank_data[period]['ranks'][symbol] = rank

                # Update the result with rank and z-score information
                result['technical_indicators']['momentum']['momentum_ratio']['ranks'] = result['technical_indicators']['momentum']['momentum_ratio'].get('ranks', {})
                result['technical_indicators']['momentum']['momentum_ratio']['ranks'][period] = rank
                result['technical_indicators']['momentum']['momentum_ratio']['z_scores'] = result['technical_indicators']['momentum']['momentum_ratio'].get('z_scores', {})
                result['technical_indicators']['momentum']['momentum_ratio']['z_scores'][period] = z_score
                result['technical_indicators']['momentum']['momentum_ratio']['universe_stats'] = {
                    'stdev': stdev,
                    'mean': mean
                }

    # Calculate weighted z-score ranks and normalized z-scores
    weighted_z_scores = {}
    normalized_z_scores = {}
    for symbol, result in results.items():
        one_year_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('one_year')
        six_month_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('six_month')
        weighted_z_score = calculate_weighted_z_score(one_year_z_score, six_month_z_score)

        if weighted_z_score is not None:
            weighted_z_scores[symbol] = weighted_z_score
            rank_data['weighted_z_score']['values'].append(weighted_z_score)

            # Calculate normalized z-score
            normalized_z_score = calculate_normalized_z_score(weighted_z_score)
            if normalized_z_score is not None:
                normalized_z_scores[symbol] = normalized_z_score
                rank_data['normalized_z_score']['values'].append(normalized_z_score)

    # Calculate ranks for weighted z-scores
    rank_data['weighted_z_score']['values'] = [v for v in rank_data['weighted_z_score']['values'] if v is not None and not np.isnan(v)]
    sorted_weighted_z = sorted(rank_data['weighted_z_score']['values'], reverse=True)
    for symbol, weighted_z_score in weighted_z_scores.items():
        if weighted_z_score is not None and not np.isnan(weighted_z_score) and sorted_weighted_z:
            try:
                rank = sorted_weighted_z.index(weighted_z_score) + 1
            except ValueError:
                # Find the closest value if exact match not found due to floating point issues
                closest_idx = min(range(len(sorted_weighted_z)),
                                key=lambda i: abs(sorted_weighted_z[i] - weighted_z_score))
                rank = closest_idx + 1

            rank_data['weighted_z_score']['ranks'][symbol] = rank
            results[symbol]['technical_indicators']['momentum']['momentum_ratio']['weighted_z_score'] = {
                'score': weighted_z_score,
                'rank': rank,
                'total_stocks': len(sorted_weighted_z)  # Use count of valid values
            }

    # Calculate ranks for normalized z-scores
    rank_data['normalized_z_score']['values'] = [v for v in rank_data['normalized_z_score']['values'] if v is not None and not np.isnan(v)]
    sorted_normalized_z = sorted(rank_data['normalized_z_score']['values'], reverse=True)
    for symbol, normalized_z_score in normalized_z_scores.items():
        if normalized_z_score is not None and not np.isnan(normalized_z_score) and sorted_normalized_z:
            try:
                rank = sorted_normalized_z.index(normalized_z_score) + 1
            except ValueError:
                # Find the closest value if exact match not found due to floating point issues
                closest_idx = min(range(len(sorted_normalized_z)),
                                key=lambda i: abs(sorted_normalized_z[i] - normalized_z_score))
                rank = closest_idx + 1

            rank_data['normalized_z_score']['ranks'][symbol] = rank
            results[symbol]['technical_indicators']['momentum']['momentum_ratio']['normalized_z_score'] = {
                'score': normalized_z_score,
                'rank': rank,
                'total_stocks': len(sorted_normalized_z)  # Use count of valid values
            }

    # Generate markdown files
    for symbol, result in results.items():
        company_name = result['company_name']

        # Generate rank analysis markdown
        rank_analysis_md = generate_rank_analysis_markdown(
            result['data'],
            symbol,
            one_year_rank=rank_data['one_year']['ranks'].get(symbol),
            six_month_rank=rank_data['six_month']['ranks'].get(symbol),
            total_stocks=len(results)
        )

        # Create comprehensive markdown content
        md_content = f"# {company_name} ({symbol}) Analysis\n\n"

        md_content += f"Company Name (ticker): {symbol}\n\n"

        # Extract the category/universe from the output_dir path
        category = output_dir.split('/')[-1]  # This will extract "nifty_50", "midcap_150", etc.
        # Format the category for display - remove underscore and capitalize
        display_category = category.replace('_', ' ').title()
        md_content += f"Universe/Category: {display_category}\n\n"

        # Add actual date used for analysis
        if end_date and result['actual_end_date'] != end_date:
            md_content += f"*Note: Analysis uses last available date {result['actual_end_date']} instead of requested date {end_date}*\n\n"

        # Current Price and Performance
        md_content += "## Current Price and Performance\n\n"
        md_content += f"Current Price: Rs.{result['price_data']['Current']['price']:.2f}\n"
        if '1_year_back' in result['price_data']:
            md_content += f"1-Year Change: {result['price_data']['1_year_back']['price_change_percent']:.2f}%\n"
        if '6_months_back' in result['price_data']:
            md_content += f"6-Month Change: {result['price_data']['6_months_back']['price_change_percent']:.2f}%\n\n"

        # Technical Indicators
        md_content += "## Technical Indicators\n\n"
        if result['technical_indicators']['rsi'] is not None:
            md_content += f"RSI (14-day): {float(result['technical_indicators']['rsi']):.2f}\n"
        if result['technical_indicators']['macd']['macd_line'] is not None:
            md_content += f"MACD Line: {float(result['technical_indicators']['macd']['macd_line']):.2f}\n"
            md_content += f"Signal Line: {float(result['technical_indicators']['macd']['signal_line']):.2f}\n"
            md_content += f"MACD Histogram: {float(result['technical_indicators']['macd']['histogram']):.2f}\n"

        # Momentum Rankings and Universe Statistics
        md_content += "\n## Momentum Rankings and Universe Statistics\n\n"

        # 1-Year Stats
        md_content += "### 1-Year Momentum\n"
        one_year_rank = rank_data['one_year']['ranks'].get(symbol)
        one_year_momentum = result['technical_indicators']['momentum']['momentum_ratio']['momentum_ratios']['one_year']
        one_year_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('one_year')

        if one_year_rank and one_year_momentum:
            md_content += f"- Rank: {one_year_rank} out of {len(results)}\n"
            md_content += f"- Momentum Ratio: {one_year_momentum:.4f}\n"
            md_content += f"- Universe Mean: {rank_data['one_year']['universe_stats']['mean']:.4f}\n"
            md_content += f"- Universe StDev: {rank_data['one_year']['universe_stats']['stdev']:.4f}\n"
            if one_year_z_score is not None:
                md_content += f"- Z-Score: {one_year_z_score:.4f}\n"

        # 6-Month Stats
        md_content += "\n### 6-Month Momentum\n"
        six_month_rank = rank_data['six_month']['ranks'].get(symbol)
        six_month_momentum = result['technical_indicators']['momentum']['momentum_ratio']['momentum_ratios']['six_month']
        six_month_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('six_month')

        if six_month_rank and six_month_momentum:
            md_content += f"- Rank: {six_month_rank} out of {len(results)}\n"
            md_content += f"- Momentum Ratio: {six_month_momentum:.4f}\n"
            md_content += f"- Universe Mean: {rank_data['six_month']['universe_stats']['mean']:.4f}\n"
            md_content += f"- Universe StDev: {rank_data['six_month']['universe_stats']['stdev']:.4f}\n"
            if six_month_z_score is not None:
                md_content += f"- Z-Score: {six_month_z_score:.4f}\n"

        # Add dedicated Rank and Z-Score section
        one_year_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('one_year')
        six_month_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('six_month')
        weighted_z_score_data = result['technical_indicators']['momentum']['momentum_ratio'].get('weighted_z_score', {})
        normalized_z_score_data = result['technical_indicators']['momentum']['momentum_ratio'].get('normalized_z_score', {})

        md_content += "\n## Rank and Z-Score Analysis\n\n"
        md_content += "### Z-Scores\n"
        if one_year_z_score is not None:
            md_content += f"- 1-Year Z-Score: {one_year_z_score:.4f}\n"
        if six_month_z_score is not None:
            md_content += f"- 6-Month Z-Score: {six_month_z_score:.4f}\n"
        if weighted_z_score_data.get('score') is not None:
            md_content += f"- Weighted Z-Score: {weighted_z_score_data['score']:.4f}\n"
            md_content += "  *(Calculated as: 1-Year Z-Score × 0.5 + 6-Month Z-Score × 0.5)*\n"
        if normalized_z_score_data.get('score') is not None:
            md_content += f"- Normalized Z-Score: {normalized_z_score_data['score']:.4f}\n"
            md_content += "  *(Calculated as: IF(weighted_z_score>0, (1+weighted_z_score), (1-weighted_z_score)^-1))*\n"

        md_content += "\n### Rankings\n"
        if one_year_rank:
            md_content += f"- 1-Year Momentum Rank: {one_year_rank} out of {len(results)}\n"
        if six_month_rank:
            md_content += f"- 6-Month Momentum Rank: {six_month_rank} out of {len(results)}\n"
        if weighted_z_score_data.get('rank') is not None:
            md_content += f"- Weighted Z-Score Rank: {weighted_z_score_data['rank']} out of {weighted_z_score_data['total_stocks']}\n"
        if normalized_z_score_data.get('rank') is not None:
            md_content += f"- Normalized Z-Score Rank: {normalized_z_score_data['rank']} out of {normalized_z_score_data['total_stocks']}\n"

        # Add universe statistics only if they exist
        md_content += "\n### Universe Statistics\n"
        md_content += "**1-Year Momentum:**\n"
        if rank_data['one_year']['universe_stats']['mean'] is not None and not np.isnan(rank_data['one_year']['universe_stats']['mean']):
            md_content += f"- Mean: {rank_data['one_year']['universe_stats']['mean']:.4f}\n"
        else:
            md_content += "- Mean: Not available\n"

        if rank_data['one_year']['universe_stats']['stdev'] is not None and not np.isnan(rank_data['one_year']['universe_stats']['stdev']):
            md_content += f"- Standard Deviation: {rank_data['one_year']['universe_stats']['stdev']:.4f}\n\n"
        else:
            md_content += "- Standard Deviation: Not available\n\n"

        md_content += "**6-Month Momentum:**\n"
        if rank_data['six_month']['universe_stats']['mean'] is not None and not np.isnan(rank_data['six_month']['universe_stats']['mean']):
            md_content += f"- Mean: {rank_data['six_month']['universe_stats']['mean']:.4f}\n"
        else:
            md_content += "- Mean: Not available\n"

        if rank_data['six_month']['universe_stats']['stdev'] is not None and not np.isnan(rank_data['six_month']['universe_stats']['stdev']):
            md_content += f"- Standard Deviation: {rank_data['six_month']['universe_stats']['stdev']:.4f}\n"
        else:
            md_content += "- Standard Deviation: Not available\n"

        # Strengths and Weaknesses
        md_content += "\n## Analysis\n\n"
        md_content += "### Strengths\n"
        for strength in result['analysis']['strengths']:
            md_content += f"- {strength}\n"

        md_content += "\n### Weaknesses\n"
        for weakness in result['analysis']['weaknesses']:
            md_content += f"- {weakness}\n"

        # Add rank analysis content
        md_content += "\n" + rank_analysis_md

        # Save markdown file with all analysis
        analysis_file = os.path.join(output_dir, f"{symbol}.md")
        with file_lock:
            with open(analysis_file, 'w', encoding='utf-8') as f:
                f.write(md_content)

    return results

# %%
def parse_stock_list(stock_list_text):
    stocks = []
    lines = stock_list_text.strip().split('\n')

    for line in lines:
        if '\t' in line:
            parts = line.split('\t')
            if len(parts) >= 2:
                company_name = parts[0].strip()
                symbol = parts[1].strip()
                if company_name not in ['Company Name', ''] and symbol not in ['Symbol', '']:
                    stocks.append((company_name, symbol))

    return stocks

# %%
# Example usage:
stock_list_nifty = """Company Name	Symbol
Adani Enterprises Ltd.	ADANIENT
Adani Ports and Special Economic Zone Ltd.	ADANIPORTS
Apollo Hospitals Enterprise Ltd.	APOLLOHOSP
Asian Paints Ltd.	ASIANPAINT
Axis Bank Ltd.	AXISBANK
Bajaj Auto Ltd.	BAJAJ-AUTO
Bajaj Finance Ltd.	BAJFINANCE
Bajaj Finserv Ltd.	BAJAJFINSV
Bharat Electronics Ltd.	BEL
Bharti Airtel Ltd.	BHARTIARTL
Cipla Ltd.	CIPLA
Coal India Ltd.	COALINDIA
Dr. Reddy's Laboratories Ltd.	DRREDDY
Eicher Motors Ltd.	EICHERMOT
Grasim Industries Ltd.	GRASIM
HCL Technologies Ltd.	HCLTECH
HDFC Bank Ltd.	HDFCBANK
HDFC Life Insurance Company Ltd.	HDFCLIFE
Hero MotoCorp Ltd.	HEROMOTOCO
Hindalco Industries Ltd.	HINDALCO
Hindustan Unilever Ltd.	HINDUNILVR
ICICI Bank Ltd.	ICICIBANK
ITC Ltd.	ITC
IndusInd Bank Ltd.	INDUSINDBK
Infosys Ltd.	INFY
JSW Steel Ltd.	JSWSTEEL
Jio Financial Services Ltd.	JIOFIN
Kotak Mahindra Bank Ltd.	KOTAKBANK
Larsen & Toubro Ltd.	LT
Mahindra & Mahindra Ltd.	M&M
Maruti Suzuki India Ltd.	MARUTI
NTPC Ltd.	NTPC
Nestle India Ltd.	NESTLEIND
Oil & Natural Gas Corporation Ltd.	ONGC
Power Grid Corporation of India Ltd.	POWERGRID
Reliance Industries Ltd.	RELIANCE
SBI Life Insurance Company Ltd.	SBILIFE
Shriram Finance Ltd.	SHRIRAMFIN
State Bank of India	SBIN
Sun Pharmaceutical Industries Ltd.	SUNPHARMA
Tata Consultancy Services Ltd.	TCS
Tata Consumer Products Ltd.	TATACONSUM
Tata Motors Ltd.	TATAMOTORS
Tata Steel Ltd.	TATASTEEL
Tech Mahindra Ltd.	TECHM
Titan Company Ltd.	TITAN
Trent Ltd.	TRENT
UltraTech Cement Ltd.	ULTRACEMCO
Wipro Ltd.	WIPRO
Zomato Ltd.	ZOMATO"""

stocks_nifty = parse_stock_list(stock_list_nifty)
results_nifty50 = analyze_stocks(stocks_nifty, output_dir="stock_analysis/reports_v2/nifty_50", max_workers=10, end_date="2025-04-12")
# Out:
# 2025-05-19 16:18:26,708 - INFO - Processing Adani Enterprises Ltd. (ADANIENT)
# 2025-05-19 16:18:26,712 - INFO - Processing Adani Ports and Special Economic Zone Ltd. (ADANIPORTS)
# 2025-05-19 16:18:26,714 - INFO - Processing Apollo Hospitals Enterprise Ltd. (APOLLOHOSP)
# 2025-05-19 16:18:26,717 - INFO - Processing Asian Paints Ltd. (ASIANPAINT)
# 2025-05-19 16:18:26,719 - INFO - Processing Axis Bank Ltd. (AXISBANK)
# 2025-05-19 16:18:26,723 - INFO - Processing Bajaj Auto Ltd. (BAJAJ-AUTO)
# 2025-05-19 16:18:26,725 - INFO - Processing Bajaj Finance Ltd. (BAJFINANCE)
# 2025-05-19 16:18:26,727 - INFO - Processing Bajaj Finserv Ltd. (BAJAJFINSV)
# 2025-05-19 16:18:26,728 - INFO - Processing Bharat Electronics Ltd. (BEL)
# 2025-05-19 16:18:26,731 - INFO - Processing Bharti Airtel Ltd. (BHARTIARTL)
# 2025-05-19 16:18:29,416 - INFO - AXISBANK.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-05-19 16:18:29,634 - INFO - Verified unique data for AXISBANK: Latest price = Rs.1068.95
# 2025-05-19 16:18:29,654 - INFO - ADANIENT.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-05-19 16:18:29,662 - INFO - APOLLOHOSP.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-18']
# 2025-05-19 16:18:29,670 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:29,757 - INFO - Verified unique data for BAJAJFINSV: Latest price = Rs.1946.30
# 2025-05-19 16:18:29,761 - INFO - Verified unique data for ADANIPORTS: Latest price = Rs.1164.55
# 2025-05-19 16:18:29,818 - INFO - Verified unique data for ASIANPAINT: Latest price = Rs.2393.60
# 2025-05-19 16:18:29,852 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:29,855 - INFO - Processing Cipla Ltd. (CIPLA)
# 2025-05-19 16:18:29,858 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:29,873 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:29,877 - INFO - Verified unique data for ADANIENT: Latest price = Rs.2321.40
# 2025-05-19 16:18:29,877 - INFO - Verified unique data for BEL: Latest price = Rs.285.00
# 2025-05-19 16:18:29,908 - INFO - Verified unique data for BAJFINANCE: Latest price = Rs.8908.98
# 2025-05-19 16:18:29,950 - INFO - Verified unique data for APOLLOHOSP: Latest price = Rs.6780.95
# 2025-05-19 16:18:29,951 - INFO - Processing Coal India Ltd. (COALINDIA)
# 2025-05-19 16:18:29,953 - INFO - Verified unique data for BHARTIARTL: Latest price = Rs.1756.60
# 2025-05-19 16:18:29,964 - INFO - Processing Dr. Reddy's Laboratories Ltd. (DRREDDY)
# 2025-05-19 16:18:29,973 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:29,978 - INFO - Verified unique data for BAJAJ-AUTO: Latest price = Rs.7768.85
# 2025-05-19 16:18:29,988 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:29,990 - INFO - Processing Eicher Motors Ltd. (EICHERMOT)
# 2025-05-19 16:18:29,991 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:29,993 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:29,996 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:30,019 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:30,040 - INFO - Processing Grasim Industries Ltd. (GRASIM)
# 2025-05-19 16:18:30,068 - INFO - Processing HCL Technologies Ltd. (HCLTECH)
# 2025-05-19 16:18:30,117 - INFO - Processing HDFC Bank Ltd. (HDFCBANK)
# 2025-05-19 16:18:30,127 - INFO - Processing HDFC Life Insurance Company Ltd. (HDFCLIFE)
# 2025-05-19 16:18:30,134 - INFO - Processing Hero MotoCorp Ltd. (HEROMOTOCO)
# 2025-05-19 16:18:30,164 - INFO - Processing Hindalco Industries Ltd. (HINDALCO)
# 2025-05-19 16:18:31,257 - INFO - CIPLA.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-21']
# 2025-05-19 16:18:31,281 - INFO - Verified unique data for COALINDIA: Latest price = Rs.392.10
# 2025-05-19 16:18:31,287 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,357 - INFO - Verified unique data for CIPLA: Latest price = Rs.1463.05
# 2025-05-19 16:18:31,357 - INFO - Processing Hindustan Unilever Ltd. (HINDUNILVR)
# 2025-05-19 16:18:31,360 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,492 - INFO - Processing ICICI Bank Ltd. (ICICIBANK)
# 2025-05-19 16:18:31,561 - INFO - Verified unique data for DRREDDY: Latest price = Rs.1109.50
# 2025-05-19 16:18:31,584 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,715 - INFO - Processing ITC Ltd. (ITC)
# 2025-05-19 16:18:31,733 - INFO - Verified unique data for HDFCLIFE: Latest price = Rs.685.55
# 2025-05-19 16:18:31,762 - INFO - Verified unique data for EICHERMOT: Latest price = Rs.5350.90
# 2025-05-19 16:18:31,777 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,790 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,822 - INFO - Verified unique data for HEROMOTOCO: Latest price = Rs.3666.00
# 2025-05-19 16:18:31,848 - INFO - Verified unique data for GRASIM: Latest price = Rs.2651.25
# 2025-05-19 16:18:31,880 - INFO - Processing IndusInd Bank Ltd. (INDUSINDBK)
# 2025-05-19 16:18:31,886 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,897 - INFO - Processing Infosys Ltd. (INFY)
# 2025-05-19 16:18:31,901 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,907 - INFO - Verified unique data for HDFCBANK: Latest price = Rs.1806.75
# 2025-05-19 16:18:31,939 - INFO - Verified unique data for HINDALCO: Latest price = Rs.600.30
# 2025-05-19 16:18:31,953 - INFO - Processing JSW Steel Ltd. (JSWSTEEL)
# 2025-05-19 16:18:31,957 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,962 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:31,976 - INFO - Verified unique data for HCLTECH: Latest price = Rs.1374.69
# 2025-05-19 16:18:31,981 - INFO - Processing Jio Financial Services Ltd. (JIOFIN)
# 2025-05-19 16:18:32,025 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:32,028 - INFO - Processing Kotak Mahindra Bank Ltd. (KOTAKBANK)
# 2025-05-19 16:18:32,036 - INFO - Processing Larsen & Toubro Ltd. (LT)
# 2025-05-19 16:18:32,066 - INFO - Processing Mahindra & Mahindra Ltd. (M&M)
# 2025-05-19 16:18:32,625 - INFO - Verified unique data for HINDUNILVR: Latest price = Rs.2366.15
# 2025-05-19 16:18:32,627 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:32,654 - INFO - Processing Maruti Suzuki India Ltd. (MARUTI)
# 2025-05-19 16:18:32,783 - INFO - ICICIBANK.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-08']
# 2025-05-19 16:18:32,811 - INFO - Verified unique data for ICICIBANK: Latest price = Rs.1311.65
# 2025-05-19 16:18:32,813 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:32,840 - INFO - Processing NTPC Ltd. (NTPC)
# 2025-05-19 16:18:33,025 - INFO - Verified unique data for ITC: Latest price = Rs.421.55
# 2025-05-19 16:18:33,026 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,057 - INFO - Processing Nestle India Ltd. (NESTLEIND)
# 2025-05-19 16:18:33,299 - INFO - Verified unique data for INDUSINDBK: Latest price = Rs.689.50
# 2025-05-19 16:18:33,340 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,467 - INFO - Verified unique data for INFY: Latest price = Rs.1409.45
# 2025-05-19 16:18:33,497 - INFO - Processing Oil & Natural Gas Corporation Ltd. (ONGC)
# 2025-05-19 16:18:33,505 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,524 - INFO - Verified unique data for JSWSTEEL: Latest price = Rs.990.25
# 2025-05-19 16:18:33,571 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,617 - INFO - Verified unique data for KOTAKBANK: Latest price = Rs.2111.20
# 2025-05-19 16:18:33,635 - INFO - Processing Power Grid Corporation of India Ltd. (POWERGRID)
# 2025-05-19 16:18:33,654 - INFO - Verified unique data for LT: Latest price = Rs.3115.95
# 2025-05-19 16:18:33,663 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,666 - INFO - Processing Reliance Industries Ltd. (RELIANCE)
# 2025-05-19 16:18:33,671 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,679 - INFO - Verified unique data for M&M: Latest price = Rs.2580.35
# 2025-05-19 16:18:33,742 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,742 - INFO - Processing SBI Life Insurance Company Ltd. (SBILIFE)
# 2025-05-19 16:18:33,756 - INFO - Processing Shriram Finance Ltd. (SHRIRAMFIN)
# 2025-05-19 16:18:33,791 - INFO - Processing State Bank of India (SBIN)
# 2025-05-19 16:18:33,870 - INFO - Verified unique data for JIOFIN: Latest price = Rs.230.02
# 2025-05-19 16:18:33,873 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,904 - INFO - Processing Sun Pharmaceutical Industries Ltd. (SUNPHARMA)
# 2025-05-19 16:18:33,949 - INFO - Verified unique data for MARUTI: Latest price = Rs.11599.05
# 2025-05-19 16:18:33,950 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:33,987 - INFO - Processing Tata Consultancy Services Ltd. (TCS)
# 2025-05-19 16:18:34,137 - INFO - Verified unique data for NTPC: Latest price = Rs.360.10
# 2025-05-19 16:18:34,139 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:34,168 - INFO - Processing Tata Consumer Products Ltd. (TATACONSUM)
# 2025-05-19 16:18:34,321 - INFO - Verified unique data for NESTLEIND: Latest price = Rs.2361.40
# 2025-05-19 16:18:34,323 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:34,353 - INFO - Processing Tata Motors Ltd. (TATAMOTORS)
# 2025-05-19 16:18:34,778 - INFO - Verified unique data for ONGC: Latest price = Rs.230.37
# 2025-05-19 16:18:34,781 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:34,814 - INFO - Processing Tata Steel Ltd. (TATASTEEL)
# 2025-05-19 16:18:35,081 - INFO - Verified unique data for POWERGRID: Latest price = Rs.304.10
# 2025-05-19 16:18:35,084 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:35,087 - INFO - Verified unique data for RELIANCE: Latest price = Rs.1218.95
# 2025-05-19 16:18:35,128 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:35,191 - INFO - Processing Tech Mahindra Ltd. (TECHM)
# 2025-05-19 16:18:35,214 - INFO - Processing Titan Company Ltd. (TITAN)
# 2025-05-19 16:18:35,261 - INFO - Verified unique data for SBIN: Latest price = Rs.739.01
# 2025-05-19 16:18:35,266 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:35,277 - INFO - Verified unique data for SBILIFE: Latest price = Rs.1521.90
# 2025-05-19 16:18:35,298 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:35,360 - INFO - Verified unique data for SHRIRAMFIN: Latest price = Rs.638.80
# 2025-05-19 16:18:35,361 - INFO - Processing Trent Ltd. (TRENT)
# 2025-05-19 16:18:35,368 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:35,372 - INFO - Processing UltraTech Cement Ltd. (ULTRACEMCO)
# 2025-05-19 16:18:35,413 - INFO - Verified unique data for SUNPHARMA: Latest price = Rs.1687.55
# 2025-05-19 16:18:35,437 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:35,441 - INFO - Processing Wipro Ltd. (WIPRO)
# 2025-05-19 16:18:35,503 - INFO - Processing Zomato Ltd. (ZOMATO)
# 2025-05-19 16:18:35,535 - INFO - Verified unique data for TCS: Latest price = Rs.3231.50
# 2025-05-19 16:18:35,537 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:35,567 - INFO - Verified unique data for TATACONSUM: Latest price = Rs.1097.90
# 2025-05-19 16:18:35,576 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:35,644 - INFO - Verified unique data for TATAMOTORS: Latest price = Rs.595.05
# 2025-05-19 16:18:35,645 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:36,039 - INFO - Verified unique data for TATASTEEL: Latest price = Rs.133.42
# 2025-05-19 16:18:36,040 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:36,476 - INFO - TITAN.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-06-26']
# 2025-05-19 16:18:36,510 - INFO - Verified unique data for TITAN: Latest price = Rs.3234.90
# 2025-05-19 16:18:36,519 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:36,584 - INFO - Verified unique data for TECHM: Latest price = Rs.1282.25
# 2025-05-19 16:18:36,585 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:36,760 - INFO - Verified unique data for WIPRO: Latest price = Rs.239.75
# 2025-05-19 16:18:36,770 - INFO - Verified unique data for ZOMATO: Latest price = Rs.211.39
# 2025-05-19 16:18:36,771 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:36,772 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:36,939 - INFO - Verified unique data for ULTRACEMCO: Latest price = Rs.11502.65
# 2025-05-19 16:18:36,943 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:36,987 - INFO - Verified unique data for TRENT: Latest price = Rs.4780.55
# 2025-05-19 16:18:36,998 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)

# %%
stock_list_midcap = """Company Name	Symbol
360 ONE WAM Ltd.	360ONE
3M India Ltd.	3MINDIA
ACC Ltd.	ACC
AIA Engineering Ltd.	AIAENG
APL Apollo Tubes Ltd.	APLAPOLLO
AU Small Finance Bank Ltd.	AUBANK
Abbott India Ltd.	ABBOTINDIA
Adani Total Gas Ltd.	ATGL
Adani Wilmar Ltd.	AWL
Aditya Birla Capital Ltd.	ABCAPITAL
Aditya Birla Fashion and Retail Ltd.	ABFRL
Ajanta Pharmaceuticals Ltd.	AJANTPHARM
Alkem Laboratories Ltd.	ALKEM
Apar Industries Ltd.	APARINDS
Apollo Tyres Ltd.	APOLLOTYRE
Ashok Leyland Ltd.	ASHOKLEY
Astral Ltd.	ASTRAL
Aurobindo Pharma Ltd.	AUROPHARMA
BSE Ltd.	BSE
Balkrishna Industries Ltd.	BALKRISIND
Bandhan Bank Ltd.	BANDHANBNK
Bank of India	BANKINDIA
Bank of Maharashtra	MAHABANK
Berger Paints India Ltd.	BERGEPAINT
Bharat Dynamics Ltd.	BDL
Bharat Forge Ltd.	BHARATFORG
Bharat Heavy Electricals Ltd.	BHEL
Bharti Hexacom Ltd.	BHARTIHEXA
Biocon Ltd.	BIOCON
Blue Star Ltd.	BLUESTARCO
CRISIL Ltd.	CRISIL
Cochin Shipyard Ltd.	COCHINSHIP
Coforge Ltd.	COFORGE
Colgate Palmolive (India) Ltd.	COLPAL
Container Corporation of India Ltd.	CONCOR
Coromandel International Ltd.	COROMANDEL
Cummins India Ltd.	CUMMINSIND
Dalmia Bharat Ltd.	DALBHARAT
Deepak Nitrite Ltd.	DEEPAKNTR
Dixon Technologies (India) Ltd.	DIXON
Emami Ltd.	EMAMILTD
Endurance Technologies Ltd.	ENDURANCE
Escorts Kubota Ltd.	ESCORTS
Exide Industries Ltd.	EXIDEIND
FSN E-Commerce Ventures Ltd.	NYKAA
Federal Bank Ltd.	FEDERALBNK
Fortis Healthcare Ltd.	FORTIS
GE Vernova T&D India Ltd.	GVT&D
GMR Airports Ltd.	GMRAIRPORT
General Insurance Corporation of India	GICRE
Gland Pharma Ltd.	GLAND
Glaxosmithkline Pharmaceuticals Ltd.	GLAXO
Glenmark Pharmaceuticals Ltd.	GLENMARK
Global Health Ltd.	MEDANTA
Godrej Industries Ltd.	GODREJIND
Godrej Properties Ltd.	GODREJPROP
Gujarat Fluorochemicals Ltd.	FLUOROCHEM
Gujarat Gas Ltd.	GUJGASLTD
HDFC Asset Management Company Ltd.	HDFCAMC
Hindustan Petroleum Corporation Ltd.	HINDPETRO
Hindustan Zinc Ltd.	HINDZINC
Hitachi Energy India Ltd.	POWERINDIA
Honeywell Automation India Ltd.	HONAUT
Housing & Urban Development Corporation Ltd.	HUDCO
IDFC First Bank Ltd.	IDFCFIRSTB
IRB Infrastructure Developers Ltd.	IRB
Indian Bank	INDIANB
Indian Railway Catering And Tourism Corporation Ltd.	IRCTC
Indian Renewable Energy Development Agency Ltd.	IREDA
Indraprastha Gas Ltd.	IGL
Indus Towers Ltd.	INDUSTOWER
Ipca Laboratories Ltd.	IPCALAB
J.K. Cement Ltd.	JKCEMENT
JSW Infrastructure Ltd.	JSWINFRA
Jindal Stainless Ltd.	JSL
Jubilant Foodworks Ltd.	JUBLFOOD
K.P.R. Mill Ltd.	KPRMILL
KEI Industries Ltd.	KEI
KPIT Technologies Ltd.	KPITTECH
Kalyan Jewellers India Ltd.	KALYANKJIL
L&T Finance Ltd.	LTF
L&T Technology Services Ltd.	LTTS
LIC Housing Finance Ltd.	LICHSGFIN
Linde India Ltd.	LINDEINDIA
Lloyds Metals And Energy Ltd.	LLOYDSME
Lupin Ltd.	LUPIN
MRF Ltd.	MRF
Mahindra & Mahindra Financial Services Ltd.	M&MFIN
Mangalore Refinery & Petrochemicals Ltd.	MRPL
Mankind Pharma Ltd.	MANKIND
Marico Ltd.	MARICO
Max Financial Services Ltd.	MFSL
Max Healthcare Institute Ltd.	MAXHEALTH
Mazagoan Dock Shipbuilders Ltd.	MAZDOCK
Motherson Sumi Wiring India Ltd.	MSUMI
Motilal Oswal Financial Services Ltd.	MOTILALOFS
MphasiS Ltd.	MPHASIS
Muthoot Finance Ltd.	MUTHOOTFIN
NHPC Ltd.	NHPC
NLC India Ltd.	NLCINDIA
NMDC Ltd.	NMDC
NTPC Green Energy Ltd.	NTPCGREEN
National Aluminium Co. Ltd.	NATIONALUM
Nippon Life India Asset Management Ltd.	NAM-INDIA
Oberoi Realty Ltd.	OBEROIRLTY
Oil India Ltd.	OIL
Ola Electric Mobility Ltd.	OLAELEC
One 97 Communications Ltd.	PAYTM
Oracle Financial Services Software Ltd.	OFSS
PB Fintech Ltd.	POLICYBZR
PI Industries Ltd.	PIIND
Page Industries Ltd.	PAGEIND
Patanjali Foods Ltd.	PATANJALI
Persistent Systems Ltd.	PERSISTENT
Petronet LNG Ltd.	PETRONET
Phoenix Mills Ltd.	PHOENIXLTD
Polycab India Ltd.	POLYCAB
Premier Energies Ltd.	PREMIERENE
Prestige Estates Projects Ltd.	PRESTIGE
Rail Vikas Nigam Ltd.	RVNL
SBI Cards and Payment Services Ltd.	SBICARD
SJVN Ltd.	SJVN
SRF Ltd.	SRF
Schaeffler India Ltd.	SCHAEFFLER
Solar Industries India Ltd.	SOLARINDS
Sona BLW Precision Forgings Ltd.	SONACOMS
Star Health and Allied Insurance Company Ltd.	STARHEALTH
Steel Authority of India Ltd.	SAIL
Sun TV Network Ltd.	SUNTV
Sundaram Finance Ltd.	SUNDARMFIN
Supreme Industries Ltd.	SUPREMEIND
Suzlon Energy Ltd.	SUZLON
Syngene International Ltd.	SYNGENE
Tata Communications Ltd.	TATACOMM
Tata Elxsi Ltd.	TATAELXSI
Tata Investment Corporation Ltd.	TATAINVEST
Tata Technologies Ltd.	TATATECH
The New India Assurance Company Ltd.	NIACL
Thermax Ltd.	THERMAX
Torrent Power Ltd.	TORNTPOWER
Tube Investments of India Ltd.	TIINDIA
UNO Minda Ltd.	UNOMINDA
UPL Ltd.	UPL
Union Bank of India	UNIONBANK
United Breweries Ltd.	UBL
Vishal Mega Mart Ltd.	VMM
Vodafone Idea Ltd.	IDEA
Voltas Ltd.	VOLTAS
Waaree Energies Ltd.	WAAREEENER
Yes Bank Ltd.	YESBANK"""


stocks_midcap = parse_stock_list(stock_list_midcap)
results_midcap = analyze_stocks(stocks_midcap, output_dir="stock_analysis/reports_v2/midcap_150", max_workers=10, end_date="2025-04-12")
# Out:
# 2025-05-19 16:18:38,524 - INFO - Processing 360 ONE WAM Ltd. (360ONE)
# 2025-05-19 16:18:38,527 - INFO - Processing 3M India Ltd. (3MINDIA)
# 2025-05-19 16:18:38,529 - INFO - Processing ACC Ltd. (ACC)
# 2025-05-19 16:18:38,531 - INFO - Processing AIA Engineering Ltd. (AIAENG)
# 2025-05-19 16:18:38,533 - INFO - Processing APL Apollo Tubes Ltd. (APLAPOLLO)
# 2025-05-19 16:18:38,538 - INFO - Processing AU Small Finance Bank Ltd. (AUBANK)
# 2025-05-19 16:18:38,538 - INFO - Processing Abbott India Ltd. (ABBOTINDIA)
# 2025-05-19 16:18:38,541 - INFO - Processing Adani Total Gas Ltd. (ATGL)
# 2025-05-19 16:18:38,543 - INFO - Processing Adani Wilmar Ltd. (AWL)
# 2025-05-19 16:18:38,544 - INFO - Processing Aditya Birla Capital Ltd. (ABCAPITAL)
# 2025-05-19 16:18:40,014 - INFO - Verified unique data for AUBANK: Latest price = Rs.557.10
# 2025-05-19 16:18:40,065 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,068 - INFO - Verified unique data for ABCAPITAL: Latest price = Rs.185.33
# 2025-05-19 16:18:40,167 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,323 - INFO - Processing Aditya Birla Fashion and Retail Ltd. (ABFRL)
# 2025-05-19 16:18:40,328 - INFO - Verified unique data for 360ONE: Latest price = Rs.864.89
# 2025-05-19 16:18:40,340 - INFO - Processing Ajanta Pharmaceuticals Ltd. (AJANTPHARM)
# 2025-05-19 16:18:40,346 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,351 - INFO - Verified unique data for APLAPOLLO: Latest price = Rs.1517.35
# 2025-05-19 16:18:40,358 - INFO - Verified unique data for AWL: Latest price = Rs.272.55
# 2025-05-19 16:18:40,406 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,414 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,469 - INFO - Verified unique data for ABBOTINDIA: Latest price = Rs.29641.10
# 2025-05-19 16:18:40,479 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,495 - INFO - Processing Alkem Laboratories Ltd. (ALKEM)
# 2025-05-19 16:18:40,496 - INFO - Processing Apar Industries Ltd. (APARINDS)
# 2025-05-19 16:18:40,526 - INFO - Verified unique data for AIAENG: Latest price = Rs.3168.75
# 2025-05-19 16:18:40,528 - INFO - Verified unique data for ACC: Latest price = Rs.2007.35
# 2025-05-19 16:18:40,595 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,600 - INFO - Processing Apollo Tyres Ltd. (APOLLOTYRE)
# 2025-05-19 16:18:40,603 - INFO - Processing Ashok Leyland Ltd. (ASHOKLEY)
# 2025-05-19 16:18:40,604 - INFO - Verified unique data for ATGL: Latest price = Rs.592.05
# 2025-05-19 16:18:40,607 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,697 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,710 - INFO - Processing Astral Ltd. (ASTRAL)
# 2025-05-19 16:18:40,781 - INFO - Processing Aurobindo Pharma Ltd. (AUROPHARMA)
# 2025-05-19 16:18:40,798 - INFO - Verified unique data for 3MINDIA: Latest price = Rs.29006.30
# 2025-05-19 16:18:40,802 - INFO - Processing BSE Ltd. (BSE)
# 2025-05-19 16:18:40,804 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:40,841 - INFO - Processing Balkrishna Industries Ltd. (BALKRISIND)
# 2025-05-19 16:18:41,574 - INFO - Verified unique data for ABFRL: Latest price = Rs.254.00
# 2025-05-19 16:18:41,575 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:41,629 - INFO - Processing Bandhan Bank Ltd. (BANDHANBNK)
# 2025-05-19 16:18:41,655 - INFO - Verified unique data for AJANTPHARM: Latest price = Rs.2565.40
# 2025-05-19 16:18:41,658 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:41,687 - INFO - Processing Bank of India (BANKINDIA)
# 2025-05-19 16:18:41,806 - INFO - Verified unique data for APARINDS: Latest price = Rs.5028.40
# 2025-05-19 16:18:41,810 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:41,859 - INFO - Processing Bank of Maharashtra (MAHABANK)
# 2025-05-19 16:18:41,902 - INFO - Verified unique data for ALKEM: Latest price = Rs.4887.45
# 2025-05-19 16:18:41,904 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:41,960 - INFO - Processing Berger Paints India Ltd. (BERGEPAINT)
# 2025-05-19 16:18:41,998 - INFO - ASHOKLEY.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-05-19 16:18:42,011 - INFO - Verified unique data for APOLLOTYRE: Latest price = Rs.427.75
# 2025-05-19 16:18:42,014 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:42,070 - INFO - Processing Bharat Dynamics Ltd. (BDL)
# 2025-05-19 16:18:42,102 - INFO - BSE.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-04']
# 2025-05-19 16:18:42,153 - INFO - Verified unique data for ASHOKLEY: Latest price = Rs.208.50
# 2025-05-19 16:18:42,163 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:42,254 - INFO - Processing Bharat Forge Ltd. (BHARATFORG)
# 2025-05-19 16:18:42,278 - INFO - Verified unique data for BSE: Latest price = Rs.5640.89
# 2025-05-19 16:18:42,288 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:42,296 - INFO - Verified unique data for ASTRAL: Latest price = Rs.1248.90
# 2025-05-19 16:18:42,302 - INFO - Verified unique data for AUROPHARMA: Latest price = Rs.1082.45
# 2025-05-19 16:18:42,331 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:42,339 - INFO - Processing Bharat Heavy Electricals Ltd. (BHEL)
# 2025-05-19 16:18:42,340 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:42,364 - INFO - Verified unique data for BALKRISIND: Latest price = Rs.2337.50
# 2025-05-19 16:18:42,398 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:42,402 - INFO - Processing Bharti Hexacom Ltd. (BHARTIHEXA)
# 2025-05-19 16:18:42,429 - INFO - Processing Biocon Ltd. (BIOCON)
# 2025-05-19 16:18:42,444 - INFO - Processing Blue Star Ltd. (BLUESTARCO)
# 2025-05-19 16:18:42,856 - INFO - Verified unique data for BANDHANBNK: Latest price = Rs.149.68
# 2025-05-19 16:18:42,857 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:42,888 - INFO - Processing CRISIL Ltd. (CRISIL)
# 2025-05-19 16:18:42,935 - INFO - Verified unique data for BANKINDIA: Latest price = Rs.108.16
# 2025-05-19 16:18:42,937 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:42,971 - INFO - Processing Cochin Shipyard Ltd. (COCHINSHIP)
# 2025-05-19 16:18:43,137 - INFO - MAHABANK.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-06-02']
# 2025-05-19 16:18:43,162 - INFO - Verified unique data for MAHABANK: Latest price = Rs.44.30
# 2025-05-19 16:18:43,163 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:43,237 - INFO - Processing Coforge Ltd. (COFORGE)
# 2025-05-19 16:18:43,267 - INFO - Verified unique data for BERGEPAINT: Latest price = Rs.530.50
# 2025-05-19 16:18:43,270 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:43,314 - INFO - Processing Colgate Palmolive (India) Ltd. (COLPAL)
# 2025-05-19 16:18:43,354 - INFO - Verified unique data for BDL: Latest price = Rs.1325.10
# 2025-05-19 16:18:43,355 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:43,381 - INFO - Processing Container Corporation of India Ltd. (CONCOR)
# 2025-05-19 16:18:43,661 - INFO - Verified unique data for BHEL: Latest price = Rs.212.97
# 2025-05-19 16:18:43,684 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:43,721 - INFO - BIOCON.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-05-19 16:18:43,730 - INFO - Processing Coromandel International Ltd. (COROMANDEL)
# 2025-05-19 16:18:43,749 - INFO - Verified unique data for BHARTIHEXA: Latest price = Rs.1504.75
# 2025-05-19 16:18:43,780 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:43,803 - INFO - Verified unique data for BIOCON: Latest price = Rs.316.55
# 2025-05-19 16:18:43,817 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:43,831 - INFO - Processing Cummins India Ltd. (CUMMINSIND)
# 2025-05-19 16:18:43,869 - INFO - Verified unique data for BLUESTARCO: Latest price = Rs.1967.20
# 2025-05-19 16:18:43,870 - INFO - Processing Dalmia Bharat Ltd. (DALBHARAT)
# 2025-05-19 16:18:43,872 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:43,900 - INFO - Processing Deepak Nitrite Ltd. (DEEPAKNTR)
# 2025-05-19 16:18:44,152 - INFO - Verified unique data for CRISIL: Latest price = Rs.4208.59
# 2025-05-19 16:18:44,153 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:44,175 - INFO - Processing Dixon Technologies (India) Ltd. (DIXON)
# 2025-05-19 16:18:44,339 - INFO - Verified unique data for BHARATFORG: Latest price = Rs.1002.15
# 2025-05-19 16:18:44,341 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:44,365 - INFO - Processing Emami Ltd. (EMAMILTD)
# 2025-05-19 16:18:44,499 - INFO - Verified unique data for COFORGE: Latest price = Rs.6301.17
# 2025-05-19 16:18:44,501 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:44,527 - INFO - Processing Endurance Technologies Ltd. (ENDURANCE)
# 2025-05-19 16:18:44,569 - INFO - Verified unique data for COLPAL: Latest price = Rs.2491.65
# 2025-05-19 16:18:44,570 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:44,595 - INFO - Processing Escorts Kubota Ltd. (ESCORTS)
# 2025-05-19 16:18:44,654 - INFO - Verified unique data for CONCOR: Latest price = Rs.684.80
# 2025-05-19 16:18:44,655 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:44,680 - INFO - Processing Exide Industries Ltd. (EXIDEIND)
# 2025-05-19 16:18:45,217 - INFO - COROMANDEL.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-14']
# 2025-05-19 16:18:45,297 - INFO - Verified unique data for COCHINSHIP: Latest price = Rs.1401.00
# 2025-05-19 16:18:45,317 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:45,353 - INFO - Verified unique data for COROMANDEL: Latest price = Rs.2060.00
# 2025-05-19 16:18:45,373 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:45,392 - INFO - Processing FSN E-Commerce Ventures Ltd. (NYKAA)
# 2025-05-19 16:18:45,407 - INFO - Verified unique data for CUMMINSIND: Latest price = Rs.2814.95
# 2025-05-19 16:18:45,413 - INFO - Processing Federal Bank Ltd. (FEDERALBNK)
# 2025-05-19 16:18:45,415 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:45,430 - INFO - Verified unique data for DEEPAKNTR: Latest price = Rs.1932.85
# 2025-05-19 16:18:45,444 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:45,492 - INFO - Processing Fortis Healthcare Ltd. (FORTIS)
# 2025-05-19 16:18:45,496 - INFO - Processing GE Vernova T&D India Ltd. (GVT&D)
# 2025-05-19 16:18:45,524 - INFO - Verified unique data for DIXON: Latest price = Rs.14301.90
# 2025-05-19 16:18:45,525 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:45,550 - INFO - Processing GMR Airports Ltd. (GMRAIRPORT)
# 2025-05-19 16:18:45,763 - INFO - Verified unique data for ENDURANCE: Latest price = Rs.1860.40
# 2025-05-19 16:18:45,764 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:45,798 - INFO - Processing General Insurance Corporation of India (GICRE)
# 2025-05-19 16:18:45,989 - INFO - Verified unique data for DALBHARAT: Latest price = Rs.1811.65
# 2025-05-19 16:18:45,991 - INFO - Verified unique data for ESCORTS: Latest price = Rs.3178.20
# 2025-05-19 16:18:46,021 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:46,011 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:46,128 - INFO - Processing Gland Pharma Ltd. (GLAND)
# 2025-05-19 16:18:46,138 - INFO - Processing Glaxosmithkline Pharmaceuticals Ltd. (GLAXO)
# 2025-05-19 16:18:46,144 - INFO - Verified unique data for EMAMILTD: Latest price = Rs.608.50
# 2025-05-19 16:18:46,151 - INFO - Verified unique data for EXIDEIND: Latest price = Rs.369.30
# 2025-05-19 16:18:46,153 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:46,154 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:46,206 - INFO - Processing Glenmark Pharmaceuticals Ltd. (GLENMARK)
# 2025-05-19 16:18:46,214 - INFO - Processing Global Health Ltd. (MEDANTA)
# 2025-05-19 16:18:46,633 - INFO - Verified unique data for NYKAA: Latest price = Rs.179.90
# 2025-05-19 16:18:46,634 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:46,660 - INFO - Processing Godrej Industries Ltd. (GODREJIND)
# 2025-05-19 16:18:46,694 - INFO - Verified unique data for FEDERALBNK: Latest price = Rs.190.44
# 2025-05-19 16:18:46,696 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:46,743 - INFO - Processing Godrej Properties Ltd. (GODREJPROP)
# 2025-05-19 16:18:46,818 - INFO - Verified unique data for GVT&D: Latest price = Rs.1771.10
# 2025-05-19 16:18:46,825 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:46,832 - INFO - Verified unique data for GMRAIRPORT: Latest price = Rs.85.72
# 2025-05-19 16:18:46,849 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:46,860 - INFO - Processing Gujarat Fluorochemicals Ltd. (FLUOROCHEM)
# 2025-05-19 16:18:46,886 - INFO - Processing Gujarat Gas Ltd. (GUJGASLTD)
# 2025-05-19 16:18:47,076 - INFO - Verified unique data for FORTIS: Latest price = Rs.649.55
# 2025-05-19 16:18:47,077 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:47,101 - INFO - Processing HDFC Asset Management Company Ltd. (HDFCAMC)
# 2025-05-19 16:18:47,137 - INFO - Verified unique data for GICRE: Latest price = Rs.397.35
# 2025-05-19 16:18:47,137 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:47,164 - INFO - Processing Hindustan Petroleum Corporation Ltd. (HINDPETRO)
# 2025-05-19 16:18:47,442 - INFO - Verified unique data for GLAXO: Latest price = Rs.2751.10
# 2025-05-19 16:18:47,452 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:47,508 - INFO - Verified unique data for GLAND: Latest price = Rs.1393.75
# 2025-05-19 16:18:47,513 - INFO - Processing Hindustan Zinc Ltd. (HINDZINC)
# 2025-05-19 16:18:47,524 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:47,576 - INFO - Processing Hitachi Energy India Ltd. (POWERINDIA)
# 2025-05-19 16:18:47,587 - INFO - Verified unique data for GLENMARK: Latest price = Rs.1378.10
# 2025-05-19 16:18:47,589 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:47,604 - INFO - Verified unique data for MEDANTA: Latest price = Rs.1269.95
# 2025-05-19 16:18:47,619 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:47,627 - INFO - Processing Honeywell Automation India Ltd. (HONAUT)
# 2025-05-19 16:18:47,650 - INFO - Processing Housing & Urban Development Corporation Ltd. (HUDCO)
# 2025-05-19 16:18:47,915 - INFO - Verified unique data for GODREJIND: Latest price = Rs.1136.70
# 2025-05-19 16:18:47,916 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:47,947 - INFO - Processing IDFC First Bank Ltd. (IDFCFIRSTB)
# 2025-05-19 16:18:48,018 - INFO - Verified unique data for GODREJPROP: Latest price = Rs.1948.40
# 2025-05-19 16:18:48,019 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:48,048 - INFO - Processing IRB Infrastructure Developers Ltd. (IRB)
# 2025-05-19 16:18:48,144 - INFO - Verified unique data for FLUOROCHEM: Latest price = Rs.3865.30
# 2025-05-19 16:18:48,154 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:48,157 - INFO - Verified unique data for GUJGASLTD: Latest price = Rs.428.30
# 2025-05-19 16:18:48,169 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:48,199 - INFO - Processing Indian Bank (INDIANB)
# 2025-05-19 16:18:48,215 - INFO - Processing Indian Railway Catering And Tourism Corporation Ltd. (IRCTC)
# 2025-05-19 16:18:48,434 - INFO - Verified unique data for HDFCAMC: Latest price = Rs.3987.25
# 2025-05-19 16:18:48,435 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:48,460 - INFO - Processing Indian Renewable Energy Development Agency Ltd. (IREDA)
# 2025-05-19 16:18:48,508 - INFO - Verified unique data for HINDPETRO: Latest price = Rs.382.20
# 2025-05-19 16:18:48,509 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:48,535 - INFO - Processing Indraprastha Gas Ltd. (IGL)
# 2025-05-19 16:18:48,786 - INFO - Verified unique data for HINDZINC: Latest price = Rs.411.05
# 2025-05-19 16:18:48,788 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:48,814 - INFO - Processing Indus Towers Ltd. (INDUSTOWER)
# 2025-05-19 16:18:48,857 - INFO - Verified unique data for POWERINDIA: Latest price = Rs.11979.30
# 2025-05-19 16:18:48,858 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:48,884 - INFO - Processing Ipca Laboratories Ltd. (IPCALAB)
# 2025-05-19 16:18:48,927 - INFO - Verified unique data for HONAUT: Latest price = Rs.34014.65
# 2025-05-19 16:18:48,928 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:48,995 - INFO - Processing J.K. Cement Ltd. (JKCEMENT)
# 2025-05-19 16:18:49,011 - INFO - Verified unique data for HUDCO: Latest price = Rs.215.81
# 2025-05-19 16:18:49,012 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:49,040 - INFO - Processing JSW Infrastructure Ltd. (JSWINFRA)
# 2025-05-19 16:18:49,201 - INFO - Verified unique data for IDFCFIRSTB: Latest price = Rs.59.92
# 2025-05-19 16:18:49,203 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:49,239 - INFO - Processing Jindal Stainless Ltd. (JSL)
# 2025-05-19 16:18:49,300 - INFO - Verified unique data for IRB: Latest price = Rs.45.01
# 2025-05-19 16:18:49,301 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:49,323 - INFO - Processing Jubilant Foodworks Ltd. (JUBLFOOD)
# 2025-05-19 16:18:49,467 - INFO - Verified unique data for IRCTC: Latest price = Rs.730.70
# 2025-05-19 16:18:49,468 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:49,525 - INFO - Processing K.P.R. Mill Ltd. (KPRMILL)
# 2025-05-19 16:18:49,539 - INFO - Verified unique data for INDIANB: Latest price = Rs.535.80
# 2025-05-19 16:18:49,543 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:49,565 - INFO - Processing KEI Industries Ltd. (KEI)
# 2025-05-19 16:18:49,828 - INFO - Verified unique data for IGL: Latest price = Rs.174.76
# 2025-05-19 16:18:49,837 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:49,842 - INFO - Verified unique data for IREDA: Latest price = Rs.154.20
# 2025-05-19 16:18:49,858 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:49,879 - INFO - Processing KPIT Technologies Ltd. (KPITTECH)
# 2025-05-19 16:18:49,897 - INFO - Processing Kalyan Jewellers India Ltd. (KALYANKJIL)
# 2025-05-19 16:18:50,030 - INFO - Verified unique data for INDUSTOWER: Latest price = Rs.373.65
# 2025-05-19 16:18:50,031 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:50,059 - INFO - Processing L&T Finance Ltd. (LTF)
# 2025-05-19 16:18:50,169 - INFO - Verified unique data for IPCALAB: Latest price = Rs.1330.95
# 2025-05-19 16:18:50,170 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:50,195 - INFO - Processing L&T Technology Services Ltd. (LTTS)
# 2025-05-19 16:18:50,281 - INFO - Verified unique data for JKCEMENT: Latest price = Rs.4957.45
# 2025-05-19 16:18:50,296 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:50,340 - INFO - Processing LIC Housing Finance Ltd. (LICHSGFIN)
# 2025-05-19 16:18:50,561 - INFO - Verified unique data for JSL: Latest price = Rs.542.05
# 2025-05-19 16:18:50,563 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:50,588 - INFO - Processing Linde India Ltd. (LINDEINDIA)
# 2025-05-19 16:18:50,631 - INFO - Verified unique data for JUBLFOOD: Latest price = Rs.685.30
# 2025-05-19 16:18:50,633 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:50,668 - INFO - Processing Lloyds Metals And Energy Ltd. (LLOYDSME)
# 2025-05-19 16:18:50,791 - INFO - Verified unique data for KPRMILL: Latest price = Rs.974.85
# 2025-05-19 16:18:50,792 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:50,844 - INFO - Processing Lupin Ltd. (LUPIN)
# 2025-05-19 16:18:50,896 - INFO - Verified unique data for JSWINFRA: Latest price = Rs.296.10
# 2025-05-19 16:18:50,902 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:50,945 - INFO - Processing MRF Ltd. (MRF)
# 2025-05-19 16:18:50,964 - INFO - Verified unique data for KEI: Latest price = Rs.2607.35
# 2025-05-19 16:18:50,965 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:50,989 - INFO - Processing Mahindra & Mahindra Financial Services Ltd. (M&MFIN)
# 2025-05-19 16:18:51,101 - INFO - Verified unique data for KALYANKJIL: Latest price = Rs.510.75
# 2025-05-19 16:18:51,103 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:51,125 - INFO - Processing Mangalore Refinery & Petrochemicals Ltd. (MRPL)
# 2025-05-19 16:18:51,166 - INFO - Verified unique data for KPITTECH: Latest price = Rs.1118.95
# 2025-05-19 16:18:51,167 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:51,190 - INFO - Processing Mankind Pharma Ltd. (MANKIND)
# 2025-05-19 16:18:51,273 - INFO - Verified unique data for LTF: Latest price = Rs.155.46
# 2025-05-19 16:18:51,274 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:51,297 - INFO - Processing Marico Ltd. (MARICO)
# 2025-05-19 16:18:51,443 - INFO - Verified unique data for LTTS: Latest price = Rs.4132.25
# 2025-05-19 16:18:51,444 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:51,466 - INFO - Processing Max Financial Services Ltd. (MFSL)
# 2025-05-19 16:18:51,668 - INFO - Verified unique data for LICHSGFIN: Latest price = Rs.559.65
# 2025-05-19 16:18:51,669 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:51,694 - INFO - Processing Max Healthcare Institute Ltd. (MAXHEALTH)
# 2025-05-19 16:18:51,886 - INFO - Verified unique data for LINDEINDIA: Latest price = Rs.5895.45
# 2025-05-19 16:18:51,900 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:51,933 - INFO - Processing Mazagoan Dock Shipbuilders Ltd. (MAZDOCK)
# 2025-05-19 16:18:51,937 - INFO - Verified unique data for LLOYDSME: Latest price = Rs.1197.35
# 2025-05-19 16:18:51,938 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:51,964 - INFO - Processing Motherson Sumi Wiring India Ltd. (MSUMI)
# 2025-05-19 16:18:52,095 - INFO - Verified unique data for LUPIN: Latest price = Rs.1969.25
# 2025-05-19 16:18:52,096 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:52,119 - INFO - Processing Motilal Oswal Financial Services Ltd. (MOTILALOFS)
# 2025-05-19 16:18:52,237 - INFO - Verified unique data for M&MFIN: Latest price = Rs.263.10
# 2025-05-19 16:18:52,239 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:52,261 - INFO - Processing MphasiS Ltd. (MPHASIS)
# 2025-05-19 16:18:52,317 - INFO - Verified unique data for MRF: Latest price = Rs.117544.40
# 2025-05-19 16:18:52,318 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:52,344 - INFO - Processing Muthoot Finance Ltd. (MUTHOOTFIN)
# 2025-05-19 16:18:52,387 - INFO - Verified unique data for MRPL: Latest price = Rs.130.81
# 2025-05-19 16:18:52,396 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:52,437 - INFO - Verified unique data for MANKIND: Latest price = Rs.2350.50
# 2025-05-19 16:18:52,438 - INFO - Processing NHPC Ltd. (NHPC)
# 2025-05-19 16:18:52,440 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:52,462 - INFO - Processing NLC India Ltd. (NLCINDIA)
# 2025-05-19 16:18:52,589 - INFO - Verified unique data for MARICO: Latest price = Rs.709.95
# 2025-05-19 16:18:52,590 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:52,611 - INFO - Processing NMDC Ltd. (NMDC)
# 2025-05-19 16:18:52,725 - INFO - Verified unique data for MFSL: Latest price = Rs.1163.30
# 2025-05-19 16:18:52,726 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:52,747 - INFO - Processing NTPC Green Energy Ltd. (NTPCGREEN)
# 2025-05-19 16:18:52,948 - INFO - Verified unique data for MAXHEALTH: Latest price = Rs.1089.30
# 2025-05-19 16:18:52,950 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:52,981 - INFO - Processing National Aluminium Co. Ltd. (NATIONALUM)
# 2025-05-19 16:18:53,146 - INFO - Verified unique data for MAZDOCK: Latest price = Rs.2429.81
# 2025-05-19 16:18:53,147 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,170 - INFO - Processing Nippon Life India Asset Management Ltd. (NAM-INDIA)
# 2025-05-19 16:18:53,207 - INFO - Verified unique data for MSUMI: Latest price = Rs.52.92
# 2025-05-19 16:18:53,208 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,228 - INFO - Processing Oberoi Realty Ltd. (OBEROIRLTY)
# 2025-05-19 16:18:53,371 - INFO - MOTILALOFS.NS: 1d: price-repair-split: Corrected: 2023-04-12 -> 2023-12-29
# 2025-05-19 16:18:53,385 - INFO - Verified unique data for MOTILALOFS: Latest price = Rs.606.20
# 2025-05-19 16:18:53,387 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,411 - INFO - Processing Oil India Ltd. (OIL)
# 2025-05-19 16:18:53,531 - INFO - Verified unique data for MPHASIS: Latest price = Rs.2160.55
# 2025-05-19 16:18:53,532 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,557 - INFO - Processing Ola Electric Mobility Ltd. (OLAELEC)
# 2025-05-19 16:18:53,679 - INFO - Verified unique data for NHPC: Latest price = Rs.84.20
# 2025-05-19 16:18:53,681 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,719 - INFO - Verified unique data for MUTHOOTFIN: Latest price = Rs.1992.61
# 2025-05-19 16:18:53,721 - INFO - Processing One 97 Communications Ltd. (PAYTM)
# 2025-05-19 16:18:53,721 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,785 - INFO - Processing Oracle Financial Services Software Ltd. (OFSS)
# 2025-05-19 16:18:53,789 - INFO - Verified unique data for NLCINDIA: Latest price = Rs.229.49
# 2025-05-19 16:18:53,790 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,815 - INFO - Processing PB Fintech Ltd. (POLICYBZR)
# 2025-05-19 16:18:53,881 - INFO - Verified unique data for NMDC: Latest price = Rs.62.91
# 2025-05-19 16:18:53,882 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,905 - INFO - Processing PI Industries Ltd. (PIIND)
# 2025-05-19 16:18:53,930 - INFO - Verified unique data for NTPCGREEN: Latest price = Rs.95.79
# 2025-05-19 16:18:53,931 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:53,955 - INFO - Processing Page Industries Ltd. (PAGEIND)
# 2025-05-19 16:18:54,360 - INFO - Verified unique data for NATIONALUM: Latest price = Rs.143.22
# 2025-05-19 16:18:54,361 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:54,389 - INFO - Processing Patanjali Foods Ltd. (PATANJALI)
# 2025-05-19 16:18:54,437 - INFO - Verified unique data for NAM-INDIA: Latest price = Rs.551.10
# 2025-05-19 16:18:54,438 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:54,464 - INFO - Processing Persistent Systems Ltd. (PERSISTENT)
# 2025-05-19 16:18:54,522 - INFO - Verified unique data for OBEROIRLTY: Latest price = Rs.1545.42
# 2025-05-19 16:18:54,524 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:54,549 - INFO - Processing Petronet LNG Ltd. (PETRONET)
# 2025-05-19 16:18:54,642 - INFO - Verified unique data for OIL: Latest price = Rs.358.90
# 2025-05-19 16:18:54,644 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:54,667 - INFO - Processing Phoenix Mills Ltd. (PHOENIXLTD)
# 2025-05-19 16:18:54,732 - INFO - Verified unique data for OLAELEC: Latest price = Rs.50.20
# 2025-05-19 16:18:54,733 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:54,758 - INFO - Processing Polycab India Ltd. (POLYCAB)
# 2025-05-19 16:18:55,056 - INFO - Verified unique data for OFSS: Latest price = Rs.7344.41
# 2025-05-19 16:18:55,067 - INFO - Verified unique data for PAYTM: Latest price = Rs.840.70
# 2025-05-19 16:18:55,068 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,070 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,114 - INFO - Processing Premier Energies Ltd. (PREMIERENE)
# 2025-05-19 16:18:55,131 - INFO - Processing Prestige Estates Projects Ltd. (PRESTIGE)
# 2025-05-19 16:18:55,188 - INFO - PIIND.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-11']
# 2025-05-19 16:18:55,203 - INFO - Verified unique data for POLICYBZR: Latest price = Rs.1533.15
# 2025-05-19 16:18:55,207 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,230 - INFO - Verified unique data for PIIND: Latest price = Rs.3607.45
# 2025-05-19 16:18:55,246 - INFO - Processing Rail Vikas Nigam Ltd. (RVNL)
# 2025-05-19 16:18:55,247 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,273 - INFO - Processing SBI Cards and Payment Services Ltd. (SBICARD)
# 2025-05-19 16:18:55,359 - INFO - Verified unique data for PAGEIND: Latest price = Rs.44481.40
# 2025-05-19 16:18:55,361 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,383 - INFO - Processing SJVN Ltd. (SJVN)
# 2025-05-19 16:18:55,671 - INFO - Verified unique data for PATANJALI: Latest price = Rs.1886.35
# 2025-05-19 16:18:55,673 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,696 - INFO - Processing SRF Ltd. (SRF)
# 2025-05-19 16:18:55,757 - INFO - Verified unique data for PERSISTENT: Latest price = Rs.4544.60
# 2025-05-19 16:18:55,758 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,819 - INFO - Processing Schaeffler India Ltd. (SCHAEFFLER)
# 2025-05-19 16:18:55,830 - INFO - Verified unique data for PETRONET: Latest price = Rs.284.90
# 2025-05-19 16:18:55,831 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,854 - INFO - Processing Solar Industries India Ltd. (SOLARINDS)
# 2025-05-19 16:18:55,919 - INFO - Verified unique data for PHOENIXLTD: Latest price = Rs.1478.00
# 2025-05-19 16:18:55,920 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:55,941 - INFO - Processing Sona BLW Precision Forgings Ltd. (SONACOMS)
# 2025-05-19 16:18:56,193 - INFO - Verified unique data for POLYCAB: Latest price = Rs.5093.25
# 2025-05-19 16:18:56,195 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:56,217 - INFO - Processing Star Health and Allied Insurance Company Ltd. (STARHEALTH)
# 2025-05-19 16:18:56,301 - INFO - Verified unique data for PREMIERENE: Latest price = Rs.892.95
# 2025-05-19 16:18:56,302 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:56,330 - INFO - Processing Steel Authority of India Ltd. (SAIL)
# 2025-05-19 16:18:56,372 - INFO - Verified unique data for PRESTIGE: Latest price = Rs.1122.85
# 2025-05-19 16:18:56,373 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:56,402 - INFO - Processing Sun TV Network Ltd. (SUNTV)
# 2025-05-19 16:18:56,486 - INFO - Verified unique data for RVNL: Latest price = Rs.346.30
# 2025-05-19 16:18:56,498 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:56,537 - INFO - Verified unique data for SBICARD: Latest price = Rs.852.00
# 2025-05-19 16:18:56,552 - INFO - Processing Sundaram Finance Ltd. (SUNDARMFIN)
# 2025-05-19 16:18:56,552 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:56,575 - INFO - Processing Supreme Industries Ltd. (SUPREMEIND)
# 2025-05-19 16:18:56,716 - INFO - Verified unique data for SJVN: Latest price = Rs.91.43
# 2025-05-19 16:18:56,717 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:56,744 - INFO - Processing Suzlon Energy Ltd. (SUZLON)
# 2025-05-19 16:18:56,920 - INFO - Verified unique data for SRF: Latest price = Rs.2947.35
# 2025-05-19 16:18:56,921 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:56,949 - INFO - Processing Syngene International Ltd. (SYNGENE)
# 2025-05-19 16:18:57,149 - INFO - Verified unique data for SOLARINDS: Latest price = Rs.11317.05
# 2025-05-19 16:18:57,151 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:57,180 - INFO - Processing Tata Communications Ltd. (TATACOMM)
# 2025-05-19 16:18:57,240 - INFO - Verified unique data for SONACOMS: Latest price = Rs.430.10
# 2025-05-19 16:18:57,241 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:57,282 - INFO - Processing Tata Elxsi Ltd. (TATAELXSI)
# 2025-05-19 16:18:57,336 - INFO - Verified unique data for SCHAEFFLER: Latest price = Rs.3017.11
# 2025-05-19 16:18:57,338 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:57,364 - INFO - Processing Tata Investment Corporation Ltd. (TATAINVEST)
# 2025-05-19 16:18:57,408 - INFO - Verified unique data for STARHEALTH: Latest price = Rs.360.30
# 2025-05-19 16:18:57,411 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:57,444 - INFO - Processing Tata Technologies Ltd. (TATATECH)
# 2025-05-19 16:18:57,608 - INFO - Verified unique data for SAIL: Latest price = Rs.108.34
# 2025-05-19 16:18:57,610 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:57,639 - INFO - Processing The New India Assurance Company Ltd. (NIACL)
# 2025-05-19 16:18:57,705 - INFO - Verified unique data for SUNTV: Latest price = Rs.660.10
# 2025-05-19 16:18:57,706 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:57,734 - INFO - Processing Thermax Ltd. (THERMAX)
# 2025-05-19 16:18:57,810 - INFO - Verified unique data for SUNDARMFIN: Latest price = Rs.4645.75
# 2025-05-19 16:18:57,812 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:57,867 - INFO - Processing Torrent Power Ltd. (TORNTPOWER)
# 2025-05-19 16:18:57,879 - INFO - Verified unique data for SUPREMEIND: Latest price = Rs.3168.50
# 2025-05-19 16:18:57,880 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:57,903 - INFO - Processing Tube Investments of India Ltd. (TIINDIA)
# 2025-05-19 16:18:57,985 - INFO - Verified unique data for SUZLON: Latest price = Rs.53.00
# 2025-05-19 16:18:57,989 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:58,023 - INFO - Processing UNO Minda Ltd. (UNOMINDA)
# 2025-05-19 16:18:58,518 - INFO - Verified unique data for TATACOMM: Latest price = Rs.1564.25
# 2025-05-19 16:18:58,519 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:58,579 - INFO - Processing UPL Ltd. (UPL)
# 2025-05-19 16:18:58,602 - INFO - Verified unique data for TATAELXSI: Latest price = Rs.4752.05
# 2025-05-19 16:18:58,646 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:58,735 - INFO - Processing Union Bank of India (UNIONBANK)
# 2025-05-19 16:18:58,788 - INFO - Verified unique data for SYNGENE: Latest price = Rs.701.80
# 2025-05-19 16:18:58,814 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:58,802 - INFO - Verified unique data for TATAINVEST: Latest price = Rs.6171.50
# 2025-05-19 16:18:58,848 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:58,895 - INFO - Processing United Breweries Ltd. (UBL)
# 2025-05-19 16:18:58,903 - INFO - Processing Vishal Mega Mart Ltd. (VMM)
# 2025-05-19 16:18:58,952 - INFO - Verified unique data for NIACL: Latest price = Rs.156.28
# 2025-05-19 16:18:58,955 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:58,990 - INFO - Processing Vodafone Idea Ltd. (IDEA)
# 2025-05-19 16:18:59,081 - INFO - Verified unique data for THERMAX: Latest price = Rs.3085.45
# 2025-05-19 16:18:59,086 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:59,122 - INFO - Processing Voltas Ltd. (VOLTAS)
# 2025-05-19 16:18:59,316 - INFO - Verified unique data for TORNTPOWER: Latest price = Rs.1562.15
# 2025-05-19 16:18:59,339 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:59,381 - INFO - Verified unique data for TIINDIA: Latest price = Rs.2509.70
# 2025-05-19 16:18:59,399 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:59,415 - INFO - Processing Waaree Energies Ltd. (WAAREEENER)
# 2025-05-19 16:18:59,444 - INFO - Processing Yes Bank Ltd. (YESBANK)
# 2025-05-19 16:18:59,470 - INFO - Verified unique data for UNOMINDA: Latest price = Rs.824.15
# 2025-05-19 16:18:59,487 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:59,532 - INFO - Verified unique data for TATATECH: Latest price = Rs.632.05
# 2025-05-19 16:18:59,534 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:18:59,837 - INFO - Verified unique data for UPL: Latest price = Rs.638.85
# 2025-05-19 16:18:59,838 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:00,069 - INFO - Verified unique data for VMM: Latest price = Rs.104.51
# 2025-05-19 16:19:00,070 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:00,148 - INFO - Verified unique data for UNIONBANK: Latest price = Rs.117.83
# 2025-05-19 16:19:00,161 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:00,219 - INFO - Verified unique data for IDEA: Latest price = Rs.7.17
# 2025-05-19 16:19:00,220 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:00,398 - INFO - Verified unique data for UBL: Latest price = Rs.2019.50
# 2025-05-19 16:19:00,399 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:00,463 - INFO - Verified unique data for VOLTAS: Latest price = Rs.1284.90
# 2025-05-19 16:19:00,464 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:00,615 - INFO - Verified unique data for WAAREEENER: Latest price = Rs.2161.45
# 2025-05-19 16:19:00,617 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:00,667 - INFO - Verified unique data for YESBANK: Latest price = Rs.17.15
# 2025-05-19 16:19:00,668 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)

# %%
stock_list_smallcap = """Company Name	Symbol
ACME Solar Holdings Ltd.	ACMESOLAR
Aadhar Housing Finance Ltd.	AADHARHFC
Aarti Industries Ltd.	AARTIIND
Aavas Financiers Ltd.	AAVAS
Action Construction Equipment Ltd.	ACE
Aditya Birla Real Estate Ltd.	ABREL
Aditya Birla Sun Life AMC Ltd.	ABSLAMC
Aegis Logistics Ltd.	AEGISLOG
Afcons Infrastructure Ltd.	AFCONS
Affle (India) Ltd.	AFFLE
Akums Drugs and Pharmaceuticals Ltd.	AKUMS
Alembic Pharmaceuticals Ltd.	APLLTD
Alivus Life Sciences Ltd.	ALIVUS
Alkyl Amines Chemicals Ltd.	ALKYLAMINE
Alok Industries Ltd.	ALOKINDS
Amara Raja Energy & Mobility Ltd.	ARE&M
Amber Enterprises India Ltd.	AMBER
Anand Rathi Wealth Ltd.	ANANDRATHI
Anant Raj Ltd.	ANANTRAJ
Angel One Ltd.	ANGELONE
Aptus Value Housing Finance India Ltd.	APTUS
Asahi India Glass Ltd.	ASAHIINDIA
Aster DM Healthcare Ltd.	ASTERDM
AstraZenca Pharma India Ltd.	ASTRAZEN
Atul Ltd.	ATUL
Authum Investment & Infrastructure Ltd.	AIIL
BASF India Ltd.	BASF
BEML Ltd.	BEML
BLS International Services Ltd.	BLS
Balrampur Chini Mills Ltd.	BALRAMCHIN
Bata India Ltd.	BATAINDIA
Bayer Cropscience Ltd.	BAYERCROP
Bikaji Foods International Ltd.	BIKAJI
Birlasoft Ltd.	BSOFT
Blue Dart Express Ltd.	BLUEDART
Bombay Burmah Trading Corporation Ltd.	BBTC
Brainbees Solutions Ltd.	FIRSTCRY
Brigade Enterprises Ltd.	BRIGADE
C.E. Info Systems Ltd.	MAPMYINDIA
CCL Products (I) Ltd.	CCL
CESC Ltd.	CESC
Campus Activewear Ltd.	CAMPUS
Can Fin Homes Ltd.	CANFINHOME
Caplin Point Laboratories Ltd.	CAPLIPOINT
Capri Global Capital Ltd.	CGCL
Carborundum Universal Ltd.	CARBORUNIV
Castrol India Ltd.	CASTROLIND
Ceat Ltd.	CEATLTD
Central Bank of India	CENTRALBK
Central Depository Services (India) Ltd.	CDSL
Century Plyboards (India) Ltd.	CENTURYPLY
Cera Sanitaryware Ltd	CERA
Chalet Hotels Ltd.	CHALET
Chambal Fertilizers & Chemicals Ltd.	CHAMBLFERT
Chennai Petroleum Corporation Ltd.	CHENNPETRO
Cholamandalam Financial Holdings Ltd.	CHOLAHLDNG
City Union Bank Ltd.	CUB
Clean Science and Technology Ltd.	CLEAN
Computer Age Management Services Ltd.	CAMS
Concord Biotech Ltd.	CONCORDBIO
Craftsman Automation Ltd.	CRAFTSMAN
CreditAccess Grameen Ltd.	CREDITACC
Crompton Greaves Consumer Electricals Ltd.	CROMPTON
Cyient Ltd.	CYIENT
DCM Shriram Ltd.	DCMSHRIRAM
DOMS Industries Ltd.	DOMS
Data Patterns (India) Ltd.	DATAPATTNS
Deepak Fertilisers & Petrochemicals Corp. Ltd.	DEEPAKFERT
Delhivery Ltd.	DELHIVERY
Devyani International Ltd.	DEVYANI
Dr. Lal Path Labs Ltd.	LALPATHLAB
E.I.D. Parry (India) Ltd.	EIDPARRY
EIH Ltd.	EIHOTEL
Elecon Engineering Co. Ltd.	ELECON
Elgi Equipments Ltd.	ELGIEQUIP
Emcure Pharmaceuticals Ltd.	EMCURE
Engineers India Ltd.	ENGINERSIN
Eris Lifesciences Ltd.	ERIS
Fertilisers and Chemicals Travancore Ltd.	FACT
Finolex Cables Ltd.	FINCABLES
Finolex Industries Ltd.	FINPIPE
Firstsource Solutions Ltd.	FSL
Five-Star Business Finance Ltd.	FIVESTAR
Garden Reach Shipbuilders & Engineers Ltd.	GRSE
Gillette India Ltd.	GILLETTE
Go Digit General Insurance Ltd.	GODIGIT
Godawari Power & Ispat Ltd.	GPIL
Godfrey Phillips India Ltd.	GODFRYPHLP
Godrej Agrovet Ltd.	GODREJAGRO
Granules India Ltd.	GRANULES
Graphite India Ltd.	GRAPHITE
Gravita India Ltd.	GRAVITA
Great Eastern Shipping Co. Ltd.	GESHIP
Gujarat Mineral Development Corporation Ltd.	GMDCLTD
Gujarat Narmada Valley Fertilizers and Chemicals Ltd.	GNFC
Gujarat Pipavav Port Ltd.	GPPL
Gujarat State Petronet Ltd.	GSPL
H.E.G. Ltd.	HEG
HBL Engineering Ltd.	HBLENGINE
HFCL Ltd.	HFCL
Happiest Minds Technologies Ltd.	HAPPSTMNDS
Himadri Speciality Chemical Ltd.	HSCL
Hindustan Copper Ltd.	HINDCOPPER
Home First Finance Company India Ltd.	HOMEFIRST
Honasa Consumer Ltd.	HONASA
IDBI Bank Ltd.	IDBI
IFCI Ltd.	IFCI
IIFL Finance Ltd.	IIFL
INOX India Ltd.	INOXINDIA
IRCON International Ltd.	IRCON
ITI Ltd.	ITI
Indegene Ltd.	INDGN
India Cements Ltd.	INDIACEM
Indiamart Intermesh Ltd.	INDIAMART
Indian Energy Exchange Ltd.	IEX
Indian Overseas Bank	IOB
Inox Wind Ltd.	INOXWIND
Intellect Design Arena Ltd.	INTELLECT
International Gemmological Institute (India) Ltd.	IGIL
Inventurus Knowledge Solutions Ltd.	IKS
J.B. Chemicals & Pharmaceuticals Ltd.	JBCHEPHARM
JBM Auto Ltd.	JBMA
JK Tyre & Industries Ltd.	JKTYRE
JM Financial Ltd.	JMFINANCIL
JSW Holdings Ltd.	JSWHL
Jaiprakash Power Ventures Ltd.	JPPOWER
Jammu & Kashmir Bank Ltd.	J&KBANK
Jindal Saw Ltd.	JINDALSAW
Jubilant Ingrevia Ltd.	JUBLINGREA
Jubilant Pharmova Ltd.	JUBLPHARMA
Jupiter Wagons Ltd.	JWL
Justdial Ltd.	JUSTDIAL
Jyothy Labs Ltd.	JYOTHYLAB
Jyoti CNC Automation Ltd.	JYOTICNC
KNR Constructions Ltd.	KNRCON
Kajaria Ceramics Ltd.	KAJARIACER
Kalpataru Projects International Ltd.	KPIL
Kansai Nerolac Paints Ltd.	KANSAINER
Karur Vysya Bank Ltd.	KARURVYSYA
Kaynes Technology India Ltd.	KAYNES
Kec International Ltd.	KEC
Kfin Technologies Ltd.	KFINTECH
Kirloskar Brothers Ltd.	KIRLOSBROS
Kirloskar Oil Eng Ltd.	KIRLOSENG
Krishna Institute of Medical Sciences Ltd.	KIMS
LT Foods Ltd.	LTFOODS
Latent View Analytics Ltd.	LATENTVIEW
Laurus Labs Ltd.	LAURUSLABS
Lemon Tree Hotels Ltd.	LEMONTREE
MMTC Ltd.	MMTC
Mahanagar Gas Ltd.	MGL
Maharashtra Seamless Ltd.	MAHSEAMLES
Manappuram Finance Ltd.	MANAPPURAM
Mastek Ltd.	MASTEK
Metropolis Healthcare Ltd.	METROPOLIS
Minda Corporation Ltd.	MINDACORP
Multi Commodity Exchange of India Ltd.	MCX
NATCO Pharma Ltd.	NATCOPHARM
NBCC (India) Ltd.	NBCC
NCC Ltd.	NCC
NMDC Steel Ltd.	NSLNISP
Narayana Hrudayalaya Ltd.	NH
Nava Ltd.	NAVA
Navin Fluorine International Ltd.	NAVINFLUOR
Netweb Technologies India Ltd.	NETWEB
Network18 Media & Investments Ltd.	NETWORK18
Neuland Laboratories Ltd.	NEULANDLAB
Newgen Software Technologies Ltd.	NEWGEN
Niva Bupa Health Insurance Company Ltd.	NIVABUPA
Nuvama Wealth Management Ltd.	NUVAMA
Olectra Greentech Ltd.	OLECTRA
PCBL Chemical Ltd.	PCBL
PG Electroplast Ltd.	PGEL
PNB Housing Finance Ltd.	PNBHOUSING
PNC Infratech Ltd.	PNCINFRA
PTC Industries Ltd.	PTCIL
PVR INOX Ltd.	PVRINOX
Pfizer Ltd.	PFIZER
Piramal Enterprises Ltd.	PEL
Piramal Pharma Ltd.	PPLPHARMA
Poly Medicure Ltd.	POLYMED
Poonawalla Fincorp Ltd.	POONAWALLA
Praj Industries Ltd.	PRAJIND
Quess Corp Ltd.	QUESS
R R Kabel Ltd.	RRKABEL
RBL Bank Ltd.	RBLBANK
RHI MAGNESITA INDIA LTD.	RHIM
RITES Ltd.	RITES
Radico Khaitan Ltd	RADICO
Railtel Corporation Of India Ltd.	RAILTEL
Rainbow Childrens Medicare Ltd.	RAINBOW
Ramkrishna Forgings Ltd.	RKFORGE
Rashtriya Chemicals & Fertilizers Ltd.	RCF
RattanIndia Enterprises Ltd.	RTNINDIA
Raymond Lifestyle Ltd.	RAYMONDLSL
Raymond Ltd.	RAYMOND
Redington Ltd.	REDINGTON
Reliance Power Ltd.	RPOWER
Route Mobile Ltd.	ROUTE
SBFC Finance Ltd.	SBFC
SKF India Ltd.	SKFINDIA
Sagility India Ltd.	SAGILITY
Sai Life Sciences Ltd.	SAILIFE
Sammaan Capital Ltd.	SAMMAANCAP
Sapphire Foods India Ltd.	SAPPHIRE
Sarda Energy and Minerals Ltd.	SARDAEN
Saregama India Ltd	SAREGAMA
Schneider Electric Infrastructure Ltd.	SCHNEIDER
Shipping Corporation of India Ltd.	SCI
Shree Renuka Sugars Ltd.	RENUKA
Shyam Metalics and Energy Ltd.	SHYAMMETL
Signatureglobal (India) Ltd.	SIGNATURE
Sobha Ltd.	SOBHA
Sonata Software Ltd.	SONATSOFTW
Sterling and Wilson Renewable Energy Ltd.	SWSOLAR
Sumitomo Chemical India Ltd.	SUMICHEM
Suven Pharmaceuticals Ltd.	SUVENPHAR
Swan Energy Ltd.	SWANENERGY
Syrma SGS Technology Ltd.	SYRMA
TBO Tek Ltd.	TBOTEK
Tanla Platforms Ltd.	TANLA
Tata Chemicals Ltd.	TATACHEM
Tata Teleservices (Maharashtra) Ltd.	TTML
Techno Electric & Engineering Company Ltd.	TECHNOE
Tejas Networks Ltd.	TEJASNET
The Ramco Cements Ltd.	RAMCOCEM
Timken India Ltd.	TIMKEN
Titagarh Rail Systems Ltd.	TITAGARH
Transformers And Rectifiers (India) Ltd.	TARIL
Trident Ltd.	TRIDENT
Triveni Engineering & Industries Ltd.	TRIVENI
Triveni Turbine Ltd.	TRITURBINE
UCO Bank	UCOBANK
UTI Asset Management Company Ltd.	UTIAMC
Usha Martin Ltd.	USHAMART
V-Guard Industries Ltd.	VGUARD
Valor Estate Ltd.	DBREALTY
Vardhman Textiles Ltd.	VTL
Vedant Fashions Ltd.	MANYAVAR
Vijaya Diagnostic Centre Ltd.	VIJAYA
Welspun Corp Ltd.	WELCORP
Welspun Living Ltd.	WELSPUNLIV
Westlife Foodworld Ltd.	WESTLIFE
Whirlpool of India Ltd.	WHIRLPOOL
Wockhardt Ltd.	WOCKPHARMA
ZF Commercial Vehicle Control Systems India Ltd.	ZFCVINDIA
Zee Entertainment Enterprises Ltd.	ZEEL
Zen Technologies Ltd.	ZENTEC
Zensar Technolgies Ltd.	ZENSARTECH
eClerx Services Ltd.	ECLERX"""


stocks_smallcap = parse_stock_list(stock_list_smallcap)
results_smallcap = analyze_stocks(stocks_smallcap, output_dir="stock_analysis/reports_v2/smallcap_250", max_workers=10, end_date="2025-04-12")
# Out:
# 2025-05-19 16:19:03,755 - INFO - Processing ACME Solar Holdings Ltd. (ACMESOLAR)
# 2025-05-19 16:19:03,758 - INFO - Processing Aadhar Housing Finance Ltd. (AADHARHFC)
# 2025-05-19 16:19:03,760 - INFO - Processing Aarti Industries Ltd. (AARTIIND)
# 2025-05-19 16:19:03,761 - INFO - Processing Aavas Financiers Ltd. (AAVAS)
# 2025-05-19 16:19:03,767 - INFO - Processing Action Construction Equipment Ltd. (ACE)
# 2025-05-19 16:19:03,769 - INFO - Processing Aditya Birla Real Estate Ltd. (ABREL)
# 2025-05-19 16:19:03,770 - INFO - Processing Aditya Birla Sun Life AMC Ltd. (ABSLAMC)
# 2025-05-19 16:19:03,772 - INFO - Processing Aegis Logistics Ltd. (AEGISLOG)
# 2025-05-19 16:19:03,773 - INFO - Processing Afcons Infrastructure Ltd. (AFCONS)
# 2025-05-19 16:19:03,775 - INFO - Processing Affle (India) Ltd. (AFFLE)
# 2025-05-19 16:19:04,956 - INFO - Verified unique data for AADHARHFC: Latest price = Rs.463.40
# 2025-05-19 16:19:04,958 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,062 - INFO - Processing Akums Drugs and Pharmaceuticals Ltd. (AKUMS)
# 2025-05-19 16:19:05,154 - INFO - Verified unique data for ACMESOLAR: Latest price = Rs.196.90
# 2025-05-19 16:19:05,183 - INFO - Verified unique data for AFCONS: Latest price = Rs.428.20
# 2025-05-19 16:19:05,209 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,268 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,287 - INFO - Verified unique data for AFFLE: Latest price = Rs.1501.55
# 2025-05-19 16:19:05,350 - INFO - Verified unique data for AARTIIND: Latest price = Rs.382.95
# 2025-05-19 16:19:05,396 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,398 - INFO - Processing Alembic Pharmaceuticals Ltd. (APLLTD)
# 2025-05-19 16:19:05,400 - INFO - Processing Alivus Life Sciences Ltd. (ALIVUS)
# 2025-05-19 16:19:05,403 - INFO - Verified unique data for ABREL: Latest price = Rs.1786.40
# 2025-05-19 16:19:05,411 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,495 - INFO - Processing Alkyl Amines Chemicals Ltd. (ALKYLAMINE)
# 2025-05-19 16:19:05,499 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,505 - INFO - Verified unique data for AAVAS: Latest price = Rs.2028.15
# 2025-05-19 16:19:05,529 - INFO - Verified unique data for ACE: Latest price = Rs.1230.75
# 2025-05-19 16:19:05,541 - INFO - Verified unique data for ABSLAMC: Latest price = Rs.625.05
# 2025-05-19 16:19:05,579 - INFO - Processing Alok Industries Ltd. (ALOKINDS)
# 2025-05-19 16:19:05,593 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,602 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,608 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,613 - INFO - Processing Amara Raja Energy & Mobility Ltd. (ARE&M)
# 2025-05-19 16:19:05,654 - INFO - Verified unique data for AEGISLOG: Latest price = Rs.755.75
# 2025-05-19 16:19:05,687 - INFO - Processing Amber Enterprises India Ltd. (AMBER)
# 2025-05-19 16:19:05,692 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:05,694 - INFO - Processing Anand Rathi Wealth Ltd. (ANANDRATHI)
# 2025-05-19 16:19:05,697 - INFO - Processing Anant Raj Ltd. (ANANTRAJ)
# 2025-05-19 16:19:05,723 - INFO - Processing Angel One Ltd. (ANGELONE)
# 2025-05-19 16:19:06,465 - INFO - Verified unique data for AKUMS: Latest price = Rs.433.80
# 2025-05-19 16:19:06,466 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:06,490 - INFO - Processing Aptus Value Housing Finance India Ltd. (APTUS)
# 2025-05-19 16:19:06,679 - INFO - Verified unique data for ALIVUS: Latest price = Rs.965.30
# 2025-05-19 16:19:06,691 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:06,717 - INFO - Processing Asahi India Glass Ltd. (ASAHIINDIA)
# 2025-05-19 16:19:06,736 - INFO - Verified unique data for APLLTD: Latest price = Rs.846.40
# 2025-05-19 16:19:06,739 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:06,768 - INFO - Processing Aster DM Healthcare Ltd. (ASTERDM)
# 2025-05-19 16:19:06,968 - INFO - Verified unique data for ALOKINDS: Latest price = Rs.15.62
# 2025-05-19 16:19:06,974 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:07,050 - INFO - Processing AstraZenca Pharma India Ltd. (ASTRAZEN)
# 2025-05-19 16:19:07,107 - INFO - Verified unique data for AMBER: Latest price = Rs.6530.05
# 2025-05-19 16:19:07,126 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:07,171 - INFO - Verified unique data for ANANTRAJ: Latest price = Rs.439.20
# 2025-05-19 16:19:07,179 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:07,200 - INFO - Processing Atul Ltd. (ATUL)
# 2025-05-19 16:19:07,258 - INFO - Processing Authum Investment & Infrastructure Ltd. (AIIL)
# 2025-05-19 16:19:07,265 - INFO - Verified unique data for ANANDRATHI: Latest price = Rs.1792.91
# 2025-05-19 16:19:07,280 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:07,308 - INFO - Verified unique data for ANGELONE: Latest price = Rs.2265.00
# 2025-05-19 16:19:07,331 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:07,372 - INFO - Processing BASF India Ltd. (BASF)
# 2025-05-19 16:19:07,400 - INFO - Processing BEML Ltd. (BEML)
# 2025-05-19 16:19:07,408 - INFO - Verified unique data for ALKYLAMINE: Latest price = Rs.1740.45
# 2025-05-19 16:19:07,416 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:07,449 - INFO - Processing BLS International Services Ltd. (BLS)
# 2025-05-19 16:19:07,508 - INFO - Verified unique data for ARE&M: Latest price = Rs.975.55
# 2025-05-19 16:19:07,510 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:07,535 - INFO - Processing Balrampur Chini Mills Ltd. (BALRAMCHIN)
# 2025-05-19 16:19:08,102 - INFO - Verified unique data for ASAHIINDIA: Latest price = Rs.662.75
# 2025-05-19 16:19:08,104 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,146 - INFO - Processing Bata India Ltd. (BATAINDIA)
# 2025-05-19 16:19:08,191 - INFO - Verified unique data for APTUS: Latest price = Rs.300.14
# 2025-05-19 16:19:08,212 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,246 - INFO - Verified unique data for ASTERDM: Latest price = Rs.500.30
# 2025-05-19 16:19:08,253 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,255 - INFO - Processing Bayer Cropscience Ltd. (BAYERCROP)
# 2025-05-19 16:19:08,284 - INFO - Processing Bikaji Foods International Ltd. (BIKAJI)
# 2025-05-19 16:19:08,379 - INFO - Verified unique data for ASTRAZEN: Latest price = Rs.8457.40
# 2025-05-19 16:19:08,380 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,407 - INFO - Processing Birlasoft Ltd. (BSOFT)
# 2025-05-19 16:19:08,485 - INFO - Verified unique data for ATUL: Latest price = Rs.5727.35
# 2025-05-19 16:19:08,486 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,516 - INFO - Processing Blue Dart Express Ltd. (BLUEDART)
# 2025-05-19 16:19:08,681 - INFO - Verified unique data for BASF: Latest price = Rs.4486.05
# 2025-05-19 16:19:08,694 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,742 - INFO - Processing Bombay Burmah Trading Corporation Ltd. (BBTC)
# 2025-05-19 16:19:08,790 - INFO - Verified unique data for BLS: Latest price = Rs.359.10
# 2025-05-19 16:19:08,799 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,837 - INFO - Processing Brainbees Solutions Ltd. (FIRSTCRY)
# 2025-05-19 16:19:08,931 - INFO - Verified unique data for BEML: Latest price = Rs.3021.32
# 2025-05-19 16:19:08,933 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,969 - INFO - Verified unique data for AIIL: Latest price = Rs.1608.63
# 2025-05-19 16:19:08,980 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:08,983 - INFO - Processing Brigade Enterprises Ltd. (BRIGADE)
# 2025-05-19 16:19:09,004 - INFO - Verified unique data for BALRAMCHIN: Latest price = Rs.529.90
# 2025-05-19 16:19:09,014 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:09,024 - INFO - Processing C.E. Info Systems Ltd. (MAPMYINDIA)
# 2025-05-19 16:19:09,050 - INFO - Processing CCL Products (I) Ltd. (CCL)
# 2025-05-19 16:19:09,568 - INFO - BAYERCROP.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-04']
# 2025-05-19 16:19:09,592 - INFO - Verified unique data for BATAINDIA: Latest price = Rs.1241.85
# 2025-05-19 16:19:09,599 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:09,667 - INFO - Processing CESC Ltd. (CESC)
# 2025-05-19 16:19:09,714 - INFO - Verified unique data for BIKAJI: Latest price = Rs.709.45
# 2025-05-19 16:19:09,717 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:09,747 - INFO - Verified unique data for BSOFT: Latest price = Rs.359.75
# 2025-05-19 16:19:09,763 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:09,768 - INFO - Processing Campus Activewear Ltd. (CAMPUS)
# 2025-05-19 16:19:09,816 - INFO - Processing Can Fin Homes Ltd. (CANFINHOME)
# 2025-05-19 16:19:09,869 - INFO - Verified unique data for BLUEDART: Latest price = Rs.6312.10
# 2025-05-19 16:19:09,899 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:09,922 - INFO - Verified unique data for BAYERCROP: Latest price = Rs.4826.90
# 2025-05-19 16:19:09,935 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:09,937 - INFO - Processing Caplin Point Laboratories Ltd. (CAPLIPOINT)
# 2025-05-19 16:19:09,961 - INFO - Processing Capri Global Capital Ltd. (CGCL)
# 2025-05-19 16:19:10,077 - INFO - Verified unique data for FIRSTCRY: Latest price = Rs.327.00
# 2025-05-19 16:19:10,097 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:10,175 - INFO - Processing Carborundum Universal Ltd. (CARBORUNIV)
# 2025-05-19 16:19:10,186 - INFO - Verified unique data for BBTC: Latest price = Rs.1826.25
# 2025-05-19 16:19:10,188 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:10,252 - INFO - Processing Castrol India Ltd. (CASTROLIND)
# 2025-05-19 16:19:10,395 - INFO - Verified unique data for BRIGADE: Latest price = Rs.934.60
# 2025-05-19 16:19:10,409 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:10,429 - INFO - Verified unique data for MAPMYINDIA: Latest price = Rs.1723.25
# 2025-05-19 16:19:10,432 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:10,461 - INFO - Verified unique data for CCL: Latest price = Rs.599.10
# 2025-05-19 16:19:10,475 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:10,481 - INFO - Processing Ceat Ltd. (CEATLTD)
# 2025-05-19 16:19:10,500 - INFO - Processing Central Bank of India (CENTRALBK)
# 2025-05-19 16:19:10,524 - INFO - Processing Central Depository Services (India) Ltd. (CDSL)
# 2025-05-19 16:19:11,108 - INFO - Verified unique data for CANFINHOME: Latest price = Rs.652.00
# 2025-05-19 16:19:11,116 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:11,162 - INFO - Processing Century Plyboards (India) Ltd. (CENTURYPLY)
# 2025-05-19 16:19:11,215 - INFO - Verified unique data for CAMPUS: Latest price = Rs.238.31
# 2025-05-19 16:19:11,224 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:11,280 - INFO - Processing Cera Sanitaryware Ltd (CERA)
# 2025-05-19 16:19:11,312 - INFO - Verified unique data for CAPLIPOINT: Latest price = Rs.1869.40
# 2025-05-19 16:19:11,317 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:11,321 - INFO - CGCL.NS: 1d: price-repair-split: Corrected: 2023-04-12 -> 2023-12-29
# 2025-05-19 16:19:11,354 - INFO - Processing Chalet Hotels Ltd. (CHALET)
# 2025-05-19 16:19:11,377 - INFO - Verified unique data for CGCL: Latest price = Rs.155.84
# 2025-05-19 16:19:11,379 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:11,433 - INFO - Processing Chambal Fertilizers & Chemicals Ltd. (CHAMBLFERT)
# 2025-05-19 16:19:11,489 - INFO - Verified unique data for CARBORUNIV: Latest price = Rs.955.35
# 2025-05-19 16:19:11,491 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:11,521 - INFO - Processing Chennai Petroleum Corporation Ltd. (CHENNPETRO)
# 2025-05-19 16:19:11,613 - INFO - Verified unique data for CASTROLIND: Latest price = Rs.199.33
# 2025-05-19 16:19:11,614 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:11,639 - INFO - Processing Cholamandalam Financial Holdings Ltd. (CHOLAHLDNG)
# 2025-05-19 16:19:11,711 - INFO - Verified unique data for CENTRALBK: Latest price = Rs.34.43
# 2025-05-19 16:19:11,712 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:11,761 - INFO - Processing City Union Bank Ltd. (CUB)
# 2025-05-19 16:19:11,850 - INFO - Verified unique data for CDSL: Latest price = Rs.1168.00
# 2025-05-19 16:19:11,851 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:11,879 - INFO - Processing Clean Science and Technology Ltd. (CLEAN)
# 2025-05-19 16:19:12,094 - INFO - Verified unique data for CEATLTD: Latest price = Rs.2832.50
# 2025-05-19 16:19:12,094 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:12,122 - INFO - Processing Computer Age Management Services Ltd. (CAMS)
# 2025-05-19 16:19:12,204 - INFO - Verified unique data for CESC: Latest price = Rs.153.70
# 2025-05-19 16:19:12,205 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:12,240 - INFO - Processing Concord Biotech Ltd. (CONCORDBIO)
# 2025-05-19 16:19:12,454 - INFO - Verified unique data for CENTURYPLY: Latest price = Rs.696.90
# 2025-05-19 16:19:12,455 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:12,490 - INFO - Processing Craftsman Automation Ltd. (CRAFTSMAN)
# 2025-05-19 16:19:12,599 - INFO - Verified unique data for CHALET: Latest price = Rs.819.80
# 2025-05-19 16:19:12,601 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:12,641 - INFO - Verified unique data for CERA: Latest price = Rs.5393.50
# 2025-05-19 16:19:12,646 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:12,647 - INFO - Processing CreditAccess Grameen Ltd. (CREDITACC)
# 2025-05-19 16:19:12,681 - INFO - Processing Crompton Greaves Consumer Electricals Ltd. (CROMPTON)
# 2025-05-19 16:19:12,749 - INFO - Verified unique data for CHAMBLFERT: Latest price = Rs.645.25
# 2025-05-19 16:19:12,751 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:12,778 - INFO - Processing Cyient Ltd. (CYIENT)
# 2025-05-19 16:19:12,865 - INFO - Verified unique data for CHENNPETRO: Latest price = Rs.616.20
# 2025-05-19 16:19:12,866 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:12,898 - INFO - Processing DCM Shriram Ltd. (DCMSHRIRAM)
# 2025-05-19 16:19:12,939 - INFO - Verified unique data for CHOLAHLDNG: Latest price = Rs.1780.40
# 2025-05-19 16:19:12,940 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:12,971 - INFO - Processing DOMS Industries Ltd. (DOMS)
# 2025-05-19 16:19:13,031 - INFO - Verified unique data for CUB: Latest price = Rs.166.97
# 2025-05-19 16:19:13,033 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:13,059 - INFO - Processing Data Patterns (India) Ltd. (DATAPATTNS)
# 2025-05-19 16:19:13,149 - INFO - Verified unique data for CLEAN: Latest price = Rs.1180.95
# 2025-05-19 16:19:13,150 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:13,176 - INFO - Processing Deepak Fertilisers & Petrochemicals Corp. Ltd. (DEEPAKFERT)
# 2025-05-19 16:19:13,403 - INFO - Verified unique data for CAMS: Latest price = Rs.3716.70
# 2025-05-19 16:19:13,405 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:13,433 - INFO - Processing Delhivery Ltd. (DELHIVERY)
# 2025-05-19 16:19:13,472 - INFO - Verified unique data for CONCORDBIO: Latest price = Rs.1653.85
# 2025-05-19 16:19:13,474 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:13,506 - INFO - Processing Devyani International Ltd. (DEVYANI)
# 2025-05-19 16:19:13,726 - INFO - Verified unique data for CRAFTSMAN: Latest price = Rs.4364.15
# 2025-05-19 16:19:13,727 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:13,756 - INFO - Processing Dr. Lal Path Labs Ltd. (LALPATHLAB)
# 2025-05-19 16:19:13,927 - INFO - Verified unique data for CREDITACC: Latest price = Rs.1023.10
# 2025-05-19 16:19:13,929 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:13,957 - INFO - Processing E.I.D. Parry (India) Ltd. (EIDPARRY)
# 2025-05-19 16:19:14,002 - INFO - CROMPTON.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-07']
# 2025-05-19 16:19:14,031 - INFO - Verified unique data for CROMPTON: Latest price = Rs.334.10
# 2025-05-19 16:19:14,032 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:14,067 - INFO - Processing EIH Ltd. (EIHOTEL)
# 2025-05-19 16:19:14,175 - INFO - Verified unique data for CYIENT: Latest price = Rs.1144.20
# 2025-05-19 16:19:14,184 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:14,261 - INFO - DCMSHRIRAM.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-17']
# 2025-05-19 16:19:14,268 - INFO - Processing Elecon Engineering Co. Ltd. (ELECON)
# 2025-05-19 16:19:14,301 - INFO - Verified unique data for DOMS: Latest price = Rs.2599.55
# 2025-05-19 16:19:14,306 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:14,307 - INFO - Verified unique data for DCMSHRIRAM: Latest price = Rs.1036.80
# 2025-05-19 16:19:14,335 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:14,378 - INFO - Processing Elgi Equipments Ltd. (ELGIEQUIP)
# 2025-05-19 16:19:14,395 - INFO - Processing Emcure Pharmaceuticals Ltd. (EMCURE)
# 2025-05-19 16:19:14,412 - INFO - Verified unique data for DATAPATTNS: Latest price = Rs.1681.95
# 2025-05-19 16:19:14,413 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:14,441 - INFO - Processing Engineers India Ltd. (ENGINERSIN)
# 2025-05-19 16:19:14,470 - INFO - DEEPAKFERT.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-24']
# 2025-05-19 16:19:14,493 - INFO - Verified unique data for DEEPAKFERT: Latest price = Rs.1206.45
# 2025-05-19 16:19:14,494 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:14,529 - INFO - Processing Eris Lifesciences Ltd. (ERIS)
# 2025-05-19 16:19:14,689 - INFO - Verified unique data for DELHIVERY: Latest price = Rs.246.95
# 2025-05-19 16:19:14,690 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:14,739 - INFO - Processing Fertilisers and Chemicals Travancore Ltd. (FACT)
# 2025-05-19 16:19:14,755 - INFO - Verified unique data for DEVYANI: Latest price = Rs.155.92
# 2025-05-19 16:19:14,756 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:14,785 - INFO - Processing Finolex Cables Ltd. (FINCABLES)
# 2025-05-19 16:19:15,014 - INFO - Verified unique data for LALPATHLAB: Latest price = Rs.2701.80
# 2025-05-19 16:19:15,015 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:15,046 - INFO - Processing Finolex Industries Ltd. (FINPIPE)
# 2025-05-19 16:19:15,289 - INFO - Verified unique data for EIDPARRY: Latest price = Rs.780.85
# 2025-05-19 16:19:15,291 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:15,366 - INFO - Processing Firstsource Solutions Ltd. (FSL)
# 2025-05-19 16:19:15,384 - INFO - Verified unique data for EIHOTEL: Latest price = Rs.361.35
# 2025-05-19 16:19:15,385 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:15,420 - INFO - Processing Five-Star Business Finance Ltd. (FIVESTAR)
# 2025-05-19 16:19:15,584 - INFO - Verified unique data for ELECON: Latest price = Rs.436.05
# 2025-05-19 16:19:15,585 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:15,616 - INFO - Processing Garden Reach Shipbuilders & Engineers Ltd. (GRSE)
# 2025-05-19 16:19:15,723 - INFO - Verified unique data for ELGIEQUIP: Latest price = Rs.422.15
# 2025-05-19 16:19:15,726 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:15,784 - INFO - Processing Gillette India Ltd. (GILLETTE)
# 2025-05-19 16:19:15,829 - INFO - Verified unique data for ENGINERSIN: Latest price = Rs.159.93
# 2025-05-19 16:19:15,832 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:15,873 - INFO - Processing Go Digit General Insurance Ltd. (GODIGIT)
# 2025-05-19 16:19:15,881 - INFO - Verified unique data for ERIS: Latest price = Rs.1384.80
# 2025-05-19 16:19:15,899 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:15,982 - INFO - Processing Godawari Power & Ispat Ltd. (GPIL)
# 2025-05-19 16:19:15,990 - INFO - Verified unique data for EMCURE: Latest price = Rs.919.45
# 2025-05-19 16:19:15,991 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:16,021 - INFO - Processing Godfrey Phillips India Ltd. (GODFRYPHLP)
# 2025-05-19 16:19:16,086 - INFO - Verified unique data for FACT: Latest price = Rs.624.65
# 2025-05-19 16:19:16,087 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:16,124 - INFO - Verified unique data for FINCABLES: Latest price = Rs.875.60
# 2025-05-19 16:19:16,135 - INFO - Processing Godrej Agrovet Ltd. (GODREJAGRO)
# 2025-05-19 16:19:16,136 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:16,169 - INFO - Processing Granules India Ltd. (GRANULES)
# 2025-05-19 16:19:16,388 - INFO - Verified unique data for FINPIPE: Latest price = Rs.171.98
# 2025-05-19 16:19:16,390 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:16,417 - INFO - Processing Graphite India Ltd. (GRAPHITE)
# 2025-05-19 16:19:16,603 - INFO - Verified unique data for FSL: Latest price = Rs.321.05
# 2025-05-19 16:19:16,604 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:16,642 - INFO - Processing Gravita India Ltd. (GRAVITA)
# 2025-05-19 16:19:16,672 - INFO - Verified unique data for FIVESTAR: Latest price = Rs.717.40
# 2025-05-19 16:19:16,674 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:16,704 - INFO - Processing Great Eastern Shipping Co. Ltd. (GESHIP)
# 2025-05-19 16:19:16,872 - INFO - Verified unique data for GRSE: Latest price = Rs.1615.10
# 2025-05-19 16:19:16,874 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:16,906 - INFO - Processing Gujarat Mineral Development Corporation Ltd. (GMDCLTD)
# 2025-05-19 16:19:17,099 - INFO - Verified unique data for GILLETTE: Latest price = Rs.7938.70
# 2025-05-19 16:19:17,107 - INFO - Verified unique data for GODIGIT: Latest price = Rs.281.05
# 2025-05-19 16:19:17,108 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:17,109 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:17,162 - INFO - Processing Gujarat Narmada Valley Fertilizers and Chemicals Ltd. (GNFC)
# 2025-05-19 16:19:17,188 - INFO - Processing Gujarat Pipavav Port Ltd. (GPPL)
# 2025-05-19 16:19:17,258 - INFO - GPIL.NS: 1d: price-repair-split: Corrected: 2023-04-12 -> 2023-12-29
# 2025-05-19 16:19:17,277 - INFO - Verified unique data for GPIL: Latest price = Rs.187.80
# 2025-05-19 16:19:17,279 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:17,309 - INFO - Processing Gujarat State Petronet Ltd. (GSPL)
# 2025-05-19 16:19:17,362 - INFO - Verified unique data for GODFRYPHLP: Latest price = Rs.7037.10
# 2025-05-19 16:19:17,363 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:17,396 - INFO - Processing H.E.G. Ltd. (HEG)
# 2025-05-19 16:19:17,464 - INFO - GODREJAGRO.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-27']
# 2025-05-19 16:19:17,478 - INFO - Verified unique data for GRANULES: Latest price = Rs.451.30
# 2025-05-19 16:19:17,487 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:17,517 - INFO - Verified unique data for GODREJAGRO: Latest price = Rs.768.85
# 2025-05-19 16:19:17,524 - INFO - Processing HBL Engineering Ltd. (HBLENGINE)
# 2025-05-19 16:19:17,525 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:17,551 - INFO - Processing HFCL Ltd. (HFCL)
# 2025-05-19 16:19:17,765 - INFO - Verified unique data for GRAPHITE: Latest price = Rs.451.80
# 2025-05-19 16:19:17,766 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:17,791 - INFO - Processing Happiest Minds Technologies Ltd. (HAPPSTMNDS)
# 2025-05-19 16:19:17,999 - INFO - Verified unique data for GRAVITA: Latest price = Rs.1845.93
# 2025-05-19 16:19:18,002 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,038 - INFO - Verified unique data for GESHIP: Latest price = Rs.857.89
# 2025-05-19 16:19:18,040 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,041 - INFO - Processing Himadri Speciality Chemical Ltd. (HSCL)
# 2025-05-19 16:19:18,070 - INFO - Processing Hindustan Copper Ltd. (HINDCOPPER)
# 2025-05-19 16:19:18,181 - INFO - Verified unique data for GMDCLTD: Latest price = Rs.276.05
# 2025-05-19 16:19:18,183 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,213 - INFO - Processing Home First Finance Company India Ltd. (HOMEFIRST)
# 2025-05-19 16:19:18,464 - INFO - Verified unique data for GNFC: Latest price = Rs.480.80
# 2025-05-19 16:19:18,465 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,487 - INFO - Processing Honasa Consumer Ltd. (HONASA)
# 2025-05-19 16:19:18,532 - INFO - Verified unique data for GPPL: Latest price = Rs.138.76
# 2025-05-19 16:19:18,535 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,579 - INFO - Processing IDBI Bank Ltd. (IDBI)
# 2025-05-19 16:19:18,600 - INFO - Verified unique data for GSPL: Latest price = Rs.314.25
# 2025-05-19 16:19:18,602 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,631 - INFO - Processing IFCI Ltd. (IFCI)
# 2025-05-19 16:19:18,678 - INFO - Verified unique data for HEG: Latest price = Rs.453.00
# 2025-05-19 16:19:18,680 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,707 - INFO - Processing IIFL Finance Ltd. (IIFL)
# 2025-05-19 16:19:18,776 - INFO - Verified unique data for HBLENGINE: Latest price = Rs.500.95
# 2025-05-19 16:19:18,779 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,838 - INFO - Processing INOX India Ltd. (INOXINDIA)
# 2025-05-19 16:19:18,849 - INFO - Verified unique data for HFCL: Latest price = Rs.76.01
# 2025-05-19 16:19:18,851 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:18,876 - INFO - Processing IRCON International Ltd. (IRCON)
# 2025-05-19 16:19:19,006 - INFO - HAPPSTMNDS.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-07']
# 2025-05-19 16:19:19,029 - INFO - Verified unique data for HAPPSTMNDS: Latest price = Rs.560.50
# 2025-05-19 16:19:19,031 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:19,060 - INFO - Processing ITI Ltd. (ITI)
# 2025-05-19 16:19:19,271 - INFO - Verified unique data for HSCL: Latest price = Rs.436.80
# 2025-05-19 16:19:19,272 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:19,302 - INFO - Processing Indegene Ltd. (INDGN)
# 2025-05-19 16:19:19,341 - INFO - Verified unique data for HINDCOPPER: Latest price = Rs.199.65
# 2025-05-19 16:19:19,342 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:19,370 - INFO - Processing India Cements Ltd. (INDIACEM)
# 2025-05-19 16:19:19,556 - INFO - Verified unique data for HOMEFIRST: Latest price = Rs.1059.00
# 2025-05-19 16:19:19,556 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:19,581 - INFO - Processing Indiamart Intermesh Ltd. (INDIAMART)
# 2025-05-19 16:19:19,677 - INFO - Verified unique data for HONASA: Latest price = Rs.231.94
# 2025-05-19 16:19:19,678 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:19,701 - INFO - Processing Indian Energy Exchange Ltd. (IEX)
# 2025-05-19 16:19:19,860 - INFO - Verified unique data for IDBI: Latest price = Rs.79.49
# 2025-05-19 16:19:19,864 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:19,903 - INFO - Processing Indian Overseas Bank (IOB)
# 2025-05-19 16:19:19,905 - INFO - Verified unique data for IFCI: Latest price = Rs.40.55
# 2025-05-19 16:19:19,908 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:19,934 - INFO - Processing Inox Wind Ltd. (INOXWIND)
# 2025-05-19 16:19:19,970 - INFO - Verified unique data for IIFL: Latest price = Rs.323.75
# 2025-05-19 16:19:19,971 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:19,994 - INFO - Processing Intellect Design Arena Ltd. (INTELLECT)
# 2025-05-19 16:19:20,042 - INFO - Verified unique data for INOXINDIA: Latest price = Rs.997.75
# 2025-05-19 16:19:20,044 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:20,077 - INFO - Processing International Gemmological Institute (India) Ltd. (IGIL)
# 2025-05-19 16:19:20,136 - INFO - Verified unique data for IRCON: Latest price = Rs.149.60
# 2025-05-19 16:19:20,137 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:20,164 - INFO - Processing Inventurus Knowledge Solutions Ltd. (IKS)
# 2025-05-19 16:19:20,362 - INFO - Verified unique data for ITI: Latest price = Rs.252.07
# 2025-05-19 16:19:20,363 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:20,399 - INFO - Processing J.B. Chemicals & Pharmaceuticals Ltd. (JBCHEPHARM)
# 2025-05-19 16:19:20,499 - INFO - Verified unique data for INDGN: Latest price = Rs.571.30
# 2025-05-19 16:19:20,500 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:20,524 - INFO - Processing JBM Auto Ltd. (JBMA)
# 2025-05-19 16:19:20,657 - INFO - Verified unique data for INDIACEM: Latest price = Rs.280.65
# 2025-05-19 16:19:20,658 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:20,687 - INFO - Processing JK Tyre & Industries Ltd. (JKTYRE)
# 2025-05-19 16:19:20,838 - INFO - Verified unique data for INDIAMART: Latest price = Rs.2093.90
# 2025-05-19 16:19:20,840 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:20,869 - INFO - Processing JM Financial Ltd. (JMFINANCIL)
# 2025-05-19 16:19:20,905 - INFO - IEX.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-28']
# 2025-05-19 16:19:20,936 - INFO - Verified unique data for IEX: Latest price = Rs.177.67
# 2025-05-19 16:19:20,938 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:20,970 - INFO - Processing JSW Holdings Ltd. (JSWHL)
# 2025-05-19 16:19:21,201 - INFO - Verified unique data for INOXWIND: Latest price = Rs.151.59
# 2025-05-19 16:19:21,205 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:21,234 - INFO - Verified unique data for IOB: Latest price = Rs.34.93
# 2025-05-19 16:19:21,236 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:21,271 - INFO - Processing Jaiprakash Power Ventures Ltd. (JPPOWER)
# 2025-05-19 16:19:21,280 - INFO - Processing Jammu & Kashmir Bank Ltd. (J&KBANK)
# 2025-05-19 16:19:21,318 - INFO - Verified unique data for IGIL: Latest price = Rs.337.30
# 2025-05-19 16:19:21,320 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:21,347 - INFO - Processing Jindal Saw Ltd. (JINDALSAW)
# 2025-05-19 16:19:21,392 - INFO - Verified unique data for INTELLECT: Latest price = Rs.660.60
# 2025-05-19 16:19:21,393 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:21,422 - INFO - Processing Jubilant Ingrevia Ltd. (JUBLINGREA)
# 2025-05-19 16:19:21,445 - INFO - Verified unique data for IKS: Latest price = Rs.1341.45
# 2025-05-19 16:19:21,446 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:21,467 - INFO - Processing Jubilant Pharmova Ltd. (JUBLPHARMA)
# 2025-05-19 16:19:21,780 - INFO - Verified unique data for JBCHEPHARM: Latest price = Rs.1571.60
# 2025-05-19 16:19:21,781 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:21,809 - INFO - Processing Jupiter Wagons Ltd. (JWL)
# 2025-05-19 16:19:21,963 - INFO - Verified unique data for JBMA: Latest price = Rs.618.15
# 2025-05-19 16:19:21,964 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:22,005 - INFO - Processing Justdial Ltd. (JUSTDIAL)
# 2025-05-19 16:19:22,051 - INFO - Verified unique data for JKTYRE: Latest price = Rs.284.05
# 2025-05-19 16:19:22,052 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:22,080 - INFO - Processing Jyothy Labs Ltd. (JYOTHYLAB)
# 2025-05-19 16:19:22,121 - INFO - Verified unique data for JMFINANCIL: Latest price = Rs.95.32
# 2025-05-19 16:19:22,122 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:22,148 - INFO - Processing Jyoti CNC Automation Ltd. (JYOTICNC)
# 2025-05-19 16:19:22,188 - INFO - Verified unique data for JSWHL: Latest price = Rs.23401.70
# 2025-05-19 16:19:22,189 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:22,216 - INFO - Processing KNR Constructions Ltd. (KNRCON)
# 2025-05-19 16:19:22,489 - INFO - Verified unique data for JPPOWER: Latest price = Rs.14.51
# 2025-05-19 16:19:22,491 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:22,515 - INFO - Processing Kajaria Ceramics Ltd. (KAJARIACER)
# 2025-05-19 16:19:22,612 - INFO - J&KBANK.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-14']
# 2025-05-19 16:19:22,632 - INFO - Verified unique data for JINDALSAW: Latest price = Rs.247.10
# 2025-05-19 16:19:22,636 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:22,696 - INFO - Verified unique data for J&KBANK: Latest price = Rs.91.16
# 2025-05-19 16:19:22,711 - INFO - Processing Kalpataru Projects International Ltd. (KPIL)
# 2025-05-19 16:19:22,718 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:22,761 - INFO - Verified unique data for JUBLINGREA: Latest price = Rs.634.30
# 2025-05-19 16:19:22,765 - INFO - Processing Kansai Nerolac Paints Ltd. (KANSAINER)
# 2025-05-19 16:19:22,766 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:22,790 - INFO - Processing Karur Vysya Bank Ltd. (KARURVYSYA)
# 2025-05-19 16:19:23,044 - INFO - Verified unique data for JWL: Latest price = Rs.370.90
# 2025-05-19 16:19:23,045 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:23,074 - INFO - Processing Kaynes Technology India Ltd. (KAYNES)
# 2025-05-19 16:19:23,213 - INFO - Verified unique data for JUBLPHARMA: Latest price = Rs.918.30
# 2025-05-19 16:19:23,214 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:23,242 - INFO - Processing Kec International Ltd. (KEC)
# 2025-05-19 16:19:23,325 - INFO - Verified unique data for JYOTICNC: Latest price = Rs.1011.30
# 2025-05-19 16:19:23,331 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:23,363 - INFO - Processing Kfin Technologies Ltd. (KFINTECH)
# 2025-05-19 16:19:23,376 - INFO - Verified unique data for JUSTDIAL: Latest price = Rs.835.50
# 2025-05-19 16:19:23,377 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:23,402 - INFO - Processing Kirloskar Brothers Ltd. (KIRLOSBROS)
# 2025-05-19 16:19:23,439 - INFO - Verified unique data for JYOTHYLAB: Latest price = Rs.366.80
# 2025-05-19 16:19:23,440 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:23,462 - INFO - Processing Kirloskar Oil Eng Ltd. (KIRLOSENG)
# 2025-05-19 16:19:23,618 - INFO - Verified unique data for KNRCON: Latest price = Rs.227.62
# 2025-05-19 16:19:23,619 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:23,647 - INFO - Processing Krishna Institute of Medical Sciences Ltd. (KIMS)
# 2025-05-19 16:19:23,776 - INFO - Verified unique data for KAJARIACER: Latest price = Rs.801.20
# 2025-05-19 16:19:23,777 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:23,806 - INFO - Processing LT Foods Ltd. (LTFOODS)
# 2025-05-19 16:19:24,115 - INFO - Verified unique data for KANSAINER: Latest price = Rs.249.58
# 2025-05-19 16:19:24,117 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,139 - INFO - Verified unique data for KARURVYSYA: Latest price = Rs.209.50
# 2025-05-19 16:19:24,147 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,175 - INFO - Processing Latent View Analytics Ltd. (LATENTVIEW)
# 2025-05-19 16:19:24,191 - INFO - Processing Laurus Labs Ltd. (LAURUSLABS)
# 2025-05-19 16:19:24,287 - INFO - Verified unique data for KAYNES: Latest price = Rs.5091.15
# 2025-05-19 16:19:24,289 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,325 - INFO - Processing Lemon Tree Hotels Ltd. (LEMONTREE)
# 2025-05-19 16:19:24,526 - INFO - Verified unique data for KEC: Latest price = Rs.660.05
# 2025-05-19 16:19:24,539 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,594 - INFO - Processing MMTC Ltd. (MMTC)
# 2025-05-19 16:19:24,641 - INFO - Verified unique data for KPIL: Latest price = Rs.896.30
# 2025-05-19 16:19:24,657 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,697 - INFO - Verified unique data for KFINTECH: Latest price = Rs.998.35
# 2025-05-19 16:19:24,724 - INFO - Processing Mahanagar Gas Ltd. (MGL)
# 2025-05-19 16:19:24,725 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,746 - INFO - Verified unique data for KIRLOSBROS: Latest price = Rs.1625.55
# 2025-05-19 16:19:24,780 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,808 - INFO - Processing Maharashtra Seamless Ltd. (MAHSEAMLES)
# 2025-05-19 16:19:24,832 - INFO - Verified unique data for KIRLOSENG: Latest price = Rs.726.15
# 2025-05-19 16:19:24,836 - INFO - Processing Manappuram Finance Ltd. (MANAPPURAM)
# 2025-05-19 16:19:24,838 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,883 - INFO - Processing Mastek Ltd. (MASTEK)
# 2025-05-19 16:19:24,898 - INFO - Verified unique data for KIMS: Latest price = Rs.616.75
# 2025-05-19 16:19:24,899 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:24,922 - INFO - Processing Metropolis Healthcare Ltd. (METROPOLIS)
# 2025-05-19 16:19:25,019 - INFO - LTFOODS.NS: 1d: div-adjust-repair-bad: Repaired too-small div-adjust: ['2024-11-06']
# 2025-05-19 16:19:25,400 - INFO - Verified unique data for LATENTVIEW: Latest price = Rs.379.90
# 2025-05-19 16:19:25,414 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:25,476 - INFO - Processing Minda Corporation Ltd. (MINDACORP)
# 2025-05-19 16:19:25,482 - INFO - Verified unique data for LAURUSLABS: Latest price = Rs.605.02
# 2025-05-19 16:19:25,486 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:25,540 - INFO - Processing Multi Commodity Exchange of India Ltd. (MCX)
# 2025-05-19 16:19:25,562 - INFO - Verified unique data for LTFOODS: Latest price = Rs.354.35
# 2025-05-19 16:19:25,564 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:25,602 - INFO - Processing NATCO Pharma Ltd. (NATCOPHARM)
# 2025-05-19 16:19:25,616 - INFO - Verified unique data for LEMONTREE: Latest price = Rs.139.75
# 2025-05-19 16:19:25,618 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:25,646 - INFO - Processing NBCC (India) Ltd. (NBCC)
# 2025-05-19 16:19:25,945 - INFO - Verified unique data for MGL: Latest price = Rs.1277.50
# 2025-05-19 16:19:25,955 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:25,993 - INFO - Verified unique data for MMTC: Latest price = Rs.50.36
# 2025-05-19 16:19:26,001 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:26,004 - INFO - Processing NCC Ltd. (NCC)
# 2025-05-19 16:19:26,038 - INFO - Processing NMDC Steel Ltd. (NSLNISP)
# 2025-05-19 16:19:26,099 - INFO - Verified unique data for MAHSEAMLES: Latest price = Rs.663.90
# 2025-05-19 16:19:26,107 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:26,168 - INFO - Processing Narayana Hrudayalaya Ltd. (NH)
# 2025-05-19 16:19:26,246 - INFO - Verified unique data for MANAPPURAM: Latest price = Rs.225.45
# 2025-05-19 16:19:26,250 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:26,295 - INFO - Processing Nava Ltd. (NAVA)
# 2025-05-19 16:19:26,296 - INFO - Verified unique data for METROPOLIS: Latest price = Rs.1601.60
# 2025-05-19 16:19:26,302 - INFO - Verified unique data for MASTEK: Latest price = Rs.2196.20
# 2025-05-19 16:19:26,303 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:26,305 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:26,349 - INFO - Processing Navin Fluorine International Ltd. (NAVINFLUOR)
# 2025-05-19 16:19:26,357 - INFO - Processing Netweb Technologies India Ltd. (NETWEB)
# 2025-05-19 16:19:26,719 - INFO - Verified unique data for MINDACORP: Latest price = Rs.494.50
# 2025-05-19 16:19:26,720 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:26,747 - INFO - Processing Network18 Media & Investments Ltd. (NETWORK18)
# 2025-05-19 16:19:26,794 - INFO - Verified unique data for MCX: Latest price = Rs.5441.45
# 2025-05-19 16:19:26,796 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:26,821 - INFO - Processing Neuland Laboratories Ltd. (NEULANDLAB)
# 2025-05-19 16:19:27,008 - INFO - Verified unique data for NATCOPHARM: Latest price = Rs.775.50
# 2025-05-19 16:19:27,016 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:27,074 - INFO - Verified unique data for NBCC: Latest price = Rs.89.10
# 2025-05-19 16:19:27,079 - INFO - Processing Newgen Software Technologies Ltd. (NEWGEN)
# 2025-05-19 16:19:27,080 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:27,149 - INFO - Processing Niva Bupa Health Insurance Company Ltd. (NIVABUPA)
# 2025-05-19 16:19:27,227 - INFO - NCC.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-24']
# 2025-05-19 16:19:27,250 - INFO - Verified unique data for NCC: Latest price = Rs.209.97
# 2025-05-19 16:19:27,251 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:27,275 - INFO - Processing Nuvama Wealth Management Ltd. (NUVAMA)
# 2025-05-19 16:19:27,340 - INFO - NH.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-05-19 16:19:27,385 - INFO - Verified unique data for NH: Latest price = Rs.1699.95
# 2025-05-19 16:19:27,398 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:27,414 - INFO - Verified unique data for NSLNISP: Latest price = Rs.35.04
# ...
# 2025-05-19 16:19:31,821 - INFO - Processing Sai Life Sciences Ltd. (SAILIFE)
# 2025-05-19 16:19:31,885 - INFO - Verified unique data for RTNINDIA: Latest price = Rs.40.85
# 2025-05-19 16:19:31,886 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:31,913 - INFO - Processing Sammaan Capital Ltd. (SAMMAANCAP)
# 2025-05-19 16:19:32,011 - INFO - Verified unique data for RAYMONDLSL: Latest price = Rs.1042.55
# 2025-05-19 16:19:32,013 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:32,048 - INFO - Processing Sapphire Foods India Ltd. (SAPPHIRE)
# 2025-05-19 16:19:32,405 - INFO - REDINGTON.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-05-19 16:19:32,433 - INFO - Verified unique data for REDINGTON: Latest price = Rs.215.48
# 2025-05-19 16:19:32,434 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:32,462 - INFO - Processing Sarda Energy and Minerals Ltd. (SARDAEN)
# 2025-05-19 16:19:32,510 - INFO - Verified unique data for RAYMOND: Latest price = Rs.1493.15
# 2025-05-19 16:19:32,511 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:32,539 - INFO - Processing Saregama India Ltd (SAREGAMA)
# 2025-05-19 16:19:32,738 - INFO - Verified unique data for RPOWER: Latest price = Rs.40.03
# 2025-05-19 16:19:32,752 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:32,821 - INFO - Processing Schneider Electric Infrastructure Ltd. (SCHNEIDER)
# 2025-05-19 16:19:32,840 - INFO - Verified unique data for ROUTE: Latest price = Rs.975.40
# 2025-05-19 16:19:32,888 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:32,934 - INFO - Processing Shipping Corporation of India Ltd. (SCI)
# 2025-05-19 16:19:32,944 - INFO - Verified unique data for SKFINDIA: Latest price = Rs.3861.95
# 2025-05-19 16:19:32,945 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:32,979 - INFO - Processing Shree Renuka Sugars Ltd. (RENUKA)
# 2025-05-19 16:19:33,018 - INFO - Verified unique data for SAILIFE: Latest price = Rs.669.50
# 2025-05-19 16:19:33,019 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:33,049 - INFO - Processing Shyam Metalics and Energy Ltd. (SHYAMMETL)
# 2025-05-19 16:19:33,073 - INFO - Verified unique data for SAGILITY: Latest price = Rs.39.87
# 2025-05-19 16:19:33,075 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:33,100 - INFO - Processing Signatureglobal (India) Ltd. (SIGNATURE)
# 2025-05-19 16:19:33,171 - INFO - Verified unique data for SAMMAANCAP: Latest price = Rs.107.80
# 2025-05-19 16:19:33,174 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:33,203 - INFO - Processing Sobha Ltd. (SOBHA)
# 2025-05-19 16:19:33,290 - INFO - Verified unique data for SAPPHIRE: Latest price = Rs.305.30
# 2025-05-19 16:19:33,292 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:33,330 - INFO - Processing Sonata Software Ltd. (SONATSOFTW)
# 2025-05-19 16:19:33,384 - INFO - Verified unique data for SBFC: Latest price = Rs.89.67
# 2025-05-19 16:19:33,386 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:33,415 - INFO - Processing Sterling and Wilson Renewable Energy Ltd. (SWSOLAR)
# 2025-05-19 16:19:33,704 - INFO - Verified unique data for SARDAEN: Latest price = Rs.467.65
# 2025-05-19 16:19:33,706 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:33,734 - INFO - Processing Sumitomo Chemical India Ltd. (SUMICHEM)
# 2025-05-19 16:19:33,812 - INFO - Verified unique data for SAREGAMA: Latest price = Rs.524.05
# 2025-05-19 16:19:33,813 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:33,845 - INFO - Processing Suven Pharmaceuticals Ltd. (SUVENPHAR)
# 2025-05-19 16:19:34,072 - INFO - Verified unique data for SCHNEIDER: Latest price = Rs.594.30
# 2025-05-19 16:19:34,075 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:34,102 - INFO - Processing Swan Energy Ltd. (SWANENERGY)
# 2025-05-19 16:19:34,137 - INFO - Verified unique data for RENUKA: Latest price = Rs.26.98
# 2025-05-19 16:19:34,139 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:34,174 - INFO - Processing Syrma SGS Technology Ltd. (SYRMA)
# 2025-05-19 16:19:34,231 - INFO - Verified unique data for SCI: Latest price = Rs.171.75
# 2025-05-19 16:19:34,233 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:34,300 - INFO - Processing TBO Tek Ltd. (TBOTEK)
# 2025-05-19 16:19:34,324 - INFO - Verified unique data for SHYAMMETL: Latest price = Rs.843.85
# 2025-05-19 16:19:34,327 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:34,361 - INFO - Verified unique data for SIGNATURE: Latest price = Rs.1088.40
# 2025-05-19 16:19:34,369 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:34,399 - INFO - Processing Tanla Platforms Ltd. (TANLA)
# 2025-05-19 16:19:34,411 - INFO - Processing Tata Chemicals Ltd. (TATACHEM)
# 2025-05-19 16:19:34,472 - INFO - Verified unique data for SOBHA: Latest price = Rs.1127.15
# 2025-05-19 16:19:34,474 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:34,500 - INFO - Processing Tata Teleservices (Maharashtra) Ltd. (TTML)
# 2025-05-19 16:19:34,581 - INFO - Verified unique data for SWSOLAR: Latest price = Rs.250.85
# 2025-05-19 16:19:34,582 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:34,644 - INFO - Processing Techno Electric & Engineering Company Ltd. (TECHNOE)
# 2025-05-19 16:19:34,659 - INFO - Verified unique data for SONATSOFTW: Latest price = Rs.315.55
# 2025-05-19 16:19:34,660 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:34,686 - INFO - Processing Tejas Networks Ltd. (TEJASNET)
# 2025-05-19 16:19:34,948 - INFO - SUMICHEM.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-21']
# 2025-05-19 16:19:34,979 - INFO - Verified unique data for SUMICHEM: Latest price = Rs.565.25
# 2025-05-19 16:19:34,980 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,015 - INFO - Processing The Ramco Cements Ltd. (RAMCOCEM)
# 2025-05-19 16:19:35,055 - INFO - Verified unique data for SUVENPHAR: Latest price = Rs.1149.60
# 2025-05-19 16:19:35,057 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,087 - INFO - Processing Timken India Ltd. (TIMKEN)
# 2025-05-19 16:19:35,345 - INFO - Verified unique data for SWANENERGY: Latest price = Rs.396.95
# 2025-05-19 16:19:35,346 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,375 - INFO - Processing Titagarh Rail Systems Ltd. (TITAGARH)
# 2025-05-19 16:19:35,421 - INFO - Verified unique data for SYRMA: Latest price = Rs.479.80
# 2025-05-19 16:19:35,423 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,452 - INFO - Processing Transformers And Rectifiers (India) Ltd. (TARIL)
# 2025-05-19 16:19:35,485 - INFO - Verified unique data for TBOTEK: Latest price = Rs.1073.90
# 2025-05-19 16:19:35,486 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,516 - INFO - Processing Trident Ltd. (TRIDENT)
# 2025-05-19 16:19:35,706 - INFO - Verified unique data for TTML: Latest price = Rs.56.63
# 2025-05-19 16:19:35,714 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,758 - INFO - Verified unique data for TANLA: Latest price = Rs.477.95
# 2025-05-19 16:19:35,760 - INFO - Processing Triveni Engineering & Industries Ltd. (TRIVENI)
# 2025-05-19 16:19:35,762 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,811 - INFO - Processing Triveni Turbine Ltd. (TRITURBINE)
# 2025-05-19 16:19:35,841 - INFO - Verified unique data for TATACHEM: Latest price = Rs.832.25
# 2025-05-19 16:19:35,844 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,880 - INFO - Processing UCO Bank (UCOBANK)
# 2025-05-19 16:19:35,948 - INFO - Verified unique data for TECHNOE: Latest price = Rs.987.95
# 2025-05-19 16:19:35,959 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:35,964 - INFO - Verified unique data for TEJASNET: Latest price = Rs.837.80
# 2025-05-19 16:19:35,995 - INFO - Processing UTI Asset Management Company Ltd. (UTIAMC)
# 2025-05-19 16:19:35,996 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:36,026 - INFO - Processing Usha Martin Ltd. (USHAMART)
# 2025-05-19 16:19:36,261 - INFO - RAMCOCEM.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-02']
# 2025-05-19 16:19:36,313 - INFO - Verified unique data for RAMCOCEM: Latest price = Rs.936.85
# 2025-05-19 16:19:36,320 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:36,353 - INFO - Verified unique data for TIMKEN: Latest price = Rs.2474.60
# 2025-05-19 16:19:36,357 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:36,374 - INFO - Processing V-Guard Industries Ltd. (VGUARD)
# 2025-05-19 16:19:36,394 - INFO - Processing Valor Estate Ltd. (DBREALTY)
# 2025-05-19 16:19:36,626 - INFO - Verified unique data for TARIL: Latest price = Rs.544.37
# 2025-05-19 16:19:36,627 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:36,694 - INFO - Processing Vardhman Textiles Ltd. (VTL)
# 2025-05-19 16:19:36,713 - INFO - Verified unique data for TITAGARH: Latest price = Rs.746.95
# 2025-05-19 16:19:36,715 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:36,744 - INFO - Processing Vedant Fashions Ltd. (MANYAVAR)
# 2025-05-19 16:19:36,791 - INFO - Verified unique data for TRIDENT: Latest price = Rs.26.08
# 2025-05-19 16:19:36,792 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:36,821 - INFO - Processing Vijaya Diagnostic Centre Ltd. (VIJAYA)
# 2025-05-19 16:19:36,991 - INFO - Verified unique data for TRIVENI: Latest price = Rs.379.90
# 2025-05-19 16:19:37,007 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:37,067 - INFO - Verified unique data for TRITURBINE: Latest price = Rs.495.80
# 2025-05-19 16:19:37,070 - INFO - Processing Welspun Corp Ltd. (WELCORP)
# 2025-05-19 16:19:37,071 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:37,098 - INFO - Processing Welspun Living Ltd. (WELSPUNLIV)
# 2025-05-19 16:19:37,146 - INFO - Verified unique data for UCOBANK: Latest price = Rs.28.57
# 2025-05-19 16:19:37,147 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:37,179 - INFO - Processing Westlife Foodworld Ltd. (WESTLIFE)
# 2025-05-19 16:19:37,234 - INFO - Verified unique data for UTIAMC: Latest price = Rs.998.15
# 2025-05-19 16:19:37,238 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:37,302 - INFO - Processing Whirlpool of India Ltd. (WHIRLPOOL)
# 2025-05-19 16:19:37,320 - INFO - Verified unique data for USHAMART: Latest price = Rs.306.10
# 2025-05-19 16:19:37,321 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:37,350 - INFO - Processing Wockhardt Ltd. (WOCKPHARMA)
# 2025-05-19 16:19:37,621 - INFO - Verified unique data for DBREALTY: Latest price = Rs.174.48
# 2025-05-19 16:19:37,622 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:37,651 - INFO - Processing ZF Commercial Vehicle Control Systems India Ltd. (ZFCVINDIA)
# 2025-05-19 16:19:37,765 - INFO - Verified unique data for VGUARD: Latest price = Rs.361.90
# 2025-05-19 16:19:37,767 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:37,797 - INFO - Processing Zee Entertainment Enterprises Ltd. (ZEEL)
# 2025-05-19 16:19:37,905 - INFO - Verified unique data for VTL: Latest price = Rs.461.10
# 2025-05-19 16:19:37,907 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:37,936 - INFO - Processing Zen Technologies Ltd. (ZENTEC)
# 2025-05-19 16:19:37,998 - INFO - Verified unique data for MANYAVAR: Latest price = Rs.802.45
# 2025-05-19 16:19:38,000 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:38,037 - INFO - Processing Zensar Technolgies Ltd. (ZENSARTECH)
# 2025-05-19 16:19:38,076 - INFO - Verified unique data for VIJAYA: Latest price = Rs.965.40
# 2025-05-19 16:19:38,078 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:38,109 - INFO - Processing eClerx Services Ltd. (ECLERX)
# 2025-05-19 16:19:38,395 - INFO - Verified unique data for WELCORP: Latest price = Rs.758.50
# 2025-05-19 16:19:38,397 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:38,462 - INFO - Verified unique data for WELSPUNLIV: Latest price = Rs.123.85
# 2025-05-19 16:19:38,466 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:38,501 - INFO - Verified unique data for WESTLIFE: Latest price = Rs.708.45
# 2025-05-19 16:19:38,507 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:38,635 - INFO - Verified unique data for WOCKPHARMA: Latest price = Rs.1319.15
# 2025-05-19 16:19:38,637 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:38,774 - INFO - Verified unique data for WHIRLPOOL: Latest price = Rs.1106.55
# 2025-05-19 16:19:38,775 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:38,918 - INFO - ZFCVINDIA.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-05-19 16:19:38,950 - INFO - Verified unique data for ZFCVINDIA: Latest price = Rs.12449.20
# 2025-05-19 16:19:38,953 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:39,082 - INFO - Verified unique data for ZEEL: Latest price = Rs.103.85
# 2025-05-19 16:19:39,084 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:39,168 - INFO - Verified unique data for ZENTEC: Latest price = Rs.1462.00
# 2025-05-19 16:19:39,170 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:39,346 - INFO - Verified unique data for ECLERX: Latest price = Rs.2402.20
# 2025-05-19 16:19:39,350 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:39,384 - INFO - Verified unique data for ZENSARTECH: Latest price = Rs.633.45
# 2025-05-19 16:19:39,400 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)

# %%
stock_list_microcap = """Company Name	Symbol
AGI Greenpac Ltd.	AGI
ASK Automotive Ltd.	ASKAUTOLTD
Aarti Drugs Ltd.	AARTIDRUGS
Aarti Pharmalabs Ltd.	AARTIPHARM
Aditya Vision Ltd.	AVL
Advanced Enzyme Tech Ltd.	ADVENZYMES
Aether Industries Ltd.	AETHER
Ahluwalia Contracts (India) Ltd.	AHLUCONT
Akzo Nobel India Ltd.	AKZOINDIA
Allcargo Logistics Ltd.	ALLCARGO
Allied Blenders and Distillers Ltd.	ABDL
Ami Organics Ltd.	AMIORG
Apeejay Surrendra Park Hotels Ltd.	PARKHOTELS
Archean Chemical Industries Ltd.	ACI
Arvind Fashions Ltd.	ARVINDFASN
Arvind Ltd.	ARVIND
Ashoka Buildcon Ltd.	ASHOKA
Astra Microwave Products Ltd.	ASTRAMICRO
Aurionpro Solution Ltd.	AURIONPRO
Avalon Technologies Ltd.	AVALON
Avanti Feeds Ltd.	AVANTIFEED
Awfis Space Solutions Ltd.	AWFIS
Azad Engineering Ltd.	AZAD
Bajaj Hindusthan Sugar Ltd.	BAJAJHIND
Balaji Amines Ltd.	BALAMINES
Balu Forge Industries Ltd.	BALUFORGE
Banco Products (India) Ltd.	BANCOINDIA
Bansal Wire Industries Ltd.	BANSALWIRE
Bhansali Engineering Polymers Ltd.	BEPL
Bharat Bijlee Ltd.	BBL
Birla Corporation Ltd.	BIRLACORPN
Blue Jet Healthcare Ltd.	BLUEJET
Bombay Dyeing & Manufacturing Co. Ltd.	BOMDYEING
Borosil Ltd.	BOROLTD
Borosil Renewables Ltd.	BORORENEW
CIE Automotive India Ltd.	CIEINDIA
CMS Info Systems Ltd.	CMSINFO
CSB Bank Ltd.	CSBBANK
Cartrade Tech Ltd.	CARTRADE
Ceigall India Ltd.	CEIGALL
Cello World Ltd.	CELLO
Chemplast Sanmar Ltd.	CHEMPLASTS
Choice International Ltd.	CHOICEIN
Cigniti Technologies Ltd.	CIGNITITEC
Cyient DLM Ltd.	CYIENTDLM
DCB Bank Ltd.	DCBBANK
DCX Systems Ltd.	DCXINDIA
Datamatics Global Services Ltd.	DATAMATICS
Dhani Services Ltd.	DHANI
Dilip Buildcon Ltd.	DBL
Dishman Carbogen Amcis Ltd.	DCAL
Dodla Dairy Ltd.	DODLA
Dynamatic Technologies Ltd.	DYNAMATECH
EPL Ltd.	EPL
Easy Trip Planners Ltd.	EASEMYTRIP
Edelweiss Financial Services Ltd.	EDELWEISS
Electronics Mart India Ltd.	EMIL
Electrosteel Castings Ltd.	ELECTCAST
Embassy Developments Ltd.	EMBDL
Entero Healthcare Solutions Ltd.	ENTERO
Enviro Infra Engineers Ltd.	EIEL
Epigral Ltd.	EPIGRAL
Equitas Small Finance Bank Ltd.	EQUITASBNK
Ethos Ltd.	ETHOSLTD
Eureka Forbes Ltd.	EUREKAFORB
FDC Ltd.	FDC
Fiem Industries Ltd	FIEMIND
Fine Organic Industries Ltd.	FINEORG
Fineotex Chemical Ltd.	FCL
Force Motors Ltd.	FORCEMOT
G R Infraprojects Ltd.	GRINFRA
GHCL Ltd.	GHCL
GMM Pfaudler Ltd.	GMMPFAUDLR
GMR Power and Urban Infra Ltd.	GMRP&UI
Gabriel India Ltd.	GABRIEL
Ganesh Housing Corporation Ltd.	GANESHHOUC
Ganesha Ecosphere Ltd.	GANECOS
Garware Hi-Tech Films Ltd.	GRWRHITECH
Garware Technical Fibres Ltd.	GARFIBRES
Gateway Distriparks Ltd.	GATEWAY
Gokaldas Exports Ltd.	GOKEX
Gopal Snacks Ltd.	GOPAL
Greaves Cotton Ltd.	GREAVESCOT
Greenpanel Industries Ltd.	GREENPANEL
Greenply Industries Ltd.	GREENPLY
Gujarat Ambuja Exports Ltd.	GAEL
Gujarat State Fertilizers & Chemicals Ltd.	GSFC
Gulf Oil Lubricants India Ltd.	GULFOILLUB
H.G. Infra Engineering Ltd.	HGINFRA
Hathway Cable & Datacom Ltd.	HATHWAY
Healthcare Global Enterprises Ltd.	HCG
HeidelbergCement India Ltd.	HEIDELBERG
Hemisphere Properties India Ltd.	HEMIPROP
Heritage Foods Ltd.	HERITGFOOD
Hikal Ltd.	HIKAL
Hindustan Construction Co. Ltd.	HCC
IFB Industries Ltd.	IFBIND
IIFL Capital Services Ltd.	IIFLCAPS
ITD Cementation India Ltd.	ITDCEM
Imagicaaworld Entertainment Ltd.	IMAGICAA
India Glycols Ltd.	INDIAGLYCO
India Shelter Finance Corporation Ltd.	INDIASHLTR
Indian Metals & Ferro Alloys Ltd.	IMFA
Indigo Paints Ltd.	INDIGOPNTS
Indo Count Industries Ltd.	ICIL
Infibeam Avenues Ltd.	INFIBEAM
Ingersoll Rand (India) Ltd.	INGERRAND
Innova Captab Ltd.	INNOVACAP
Inox Green Energy Services Ltd.	INOXGREEN
Ion Exchange (India) Ltd.	IONEXCHANG
Isgec Heavy Engineering Ltd.	ISGEC
J.Kumar Infraprojects Ltd.	JKIL
JK Lakshmi Cement Ltd.	JKLAKSHMI
JK Paper Ltd.	JKPAPER
JTL Industries Ltd.	JTLIND
Jai Balaji Industries Ltd.	JAIBALAJI
Jai Corp Ltd.	JAICORPLTD
Jain Irrigation Systems Ltd.	JISLJALEQS
Jamna Auto Industries Ltd.	JAMNAAUTO
Jana Small Finance Bank Ltd.	JSFB
Jindal Worldwide Ltd.	JINDWORLD
Johnson Controls - Hitachi Air Conditioning India Ltd.	JCHAC
KPI Green Energy Ltd.	KPIGREEN
KRBL Ltd.	KRBL
KSB Ltd.	KSB
Kalyani Steels Ltd.	KSL
Karnataka Bank Ltd.	KTKBANK
Kaveri Seed Company Ltd.	KSCL
Kirloskar Pneumatic Company Ltd.	KIRLPNU
LMW Ltd.	LMW
Laxmi Organic Industries Ltd.	LXCHEM
Le Travenues Technology Ltd.	IXIGO
Lloyds Engineering Works Ltd.	LLOYDSENGG
Lloyds Enterprises Ltd.	LLOYDSENT
Lux Industries Ltd.	LUXIND
MOIL Ltd.	MOIL
MSTC Ltd.	MSTCLTD
MTAR Technologies Ltd.	MTARTECH
Maharashtra Scooters Ltd.	MAHSCOOTER
Mahindra Lifespace Developers Ltd.	MAHLIFE
Man Infraconstruction Ltd.	MANINFRA
Marksans Pharma Ltd.	MARKSANS
Max Estates Ltd.	MAXESTATES
Medplus Health Services Ltd.	MEDPLUS
Mishra Dhatu Nigam Ltd.	MIDHANI
Mrs. Bectors Food Specialities Ltd.	BECTORFOOD
NEOGEN CHEMICALS LTD.	NEOGEN
NESCO Ltd.	NESCO
NOCIL Ltd.	NOCIL
National Fertilizers Ltd.	NFL
Nazara Technologies Ltd.	NAZARA
Nuvoco Vistas Corporation Ltd.	NUVOCO
Optiemus Infracom Ltd.	OPTIEMUS
Orchid Pharma Ltd.	ORCHPHARMA
Orient Cement Ltd.	ORIENTCEM
Orissa Min Dev Co Ltd.	ORISSAMINE
P N Gadgil Jewellers Ltd.	PNGJL
PC Jeweller Ltd.	PCJEWELLER
PTC India Ltd.	PTC
Paisalo Digital Ltd.	PAISALO
Paradeep Phosphates Ltd.	PARADEEP
Paras Defence and Space Technologies Ltd.	PARAS
Patel Engineering Ltd.	PATELENG
Pearl Global Industries Ltd.	PGIL
Polyplex Corporation Ltd.	POLYPLEX
Power Mech Projects Ltd.	POWERMECH
Pricol Ltd.	PRICOLLTD
Prince Pipes and Fittings Ltd.	PRINCEPIPE
Prism Johnson Ltd.	PRSMJOHNSN
Prudent Corporate Advisory Services Ltd.	PRUDENT
Rain Industries Ltd	RAIN
Rajesh Exports Ltd.	RAJESHEXPO
Rallis India Ltd.	RALLIS
Rategain Travel Technologies Ltd.	RATEGAIN
RattanIndia Power Ltd.	RTNPOWER
Redtape Ltd.	REDTAPE
Refex Industries Ltd.	REFEX
Reliance Infrastructure Ltd.	RELINFRA
Religare Enterprises Ltd.	RELIGARE
Responsive Industries Ltd.	RESPONIND
Restaurant Brands Asia Ltd.	RBA
Rossari Biotech Ltd.	ROSSARI
Safari Industries (India) Ltd.	SAFARI
Samhi Hotels Ltd.	SAMHI
Sanofi Consumer Healthcare India Ltd.	SANOFICONR
Sanofi India Ltd.	SANOFI
Sansera Engineering Ltd.	SANSERA
Senco Gold Ltd.	SENCO
Sequent Scientific Ltd.	SEQUENT
Shaily Engineering Plastics Ltd.	SHAILY
Shakti Pumps (India) Ltd.	SHAKTIPUMP
Sharda Cropchem Ltd.	SHARDACROP
Share India Securities Ltd.	SHAREINDIA
Sheela Foam Ltd.	SFL
Shilpa Medicare Ltd.	SHILPAMED
Shivalik Bimetal Controls Ltd.	SBCL
Shoppers Stop Ltd.	SHOPERSTOP
Shriram Pistons & Rings Ltd.	SHRIPISTON
Skipper Ltd.	SKIPPER
South Indian Bank Ltd.	SOUTHBANK
Spandana Sphoorty Financial Ltd.	SPANDANA
Star Cement Ltd.	STARCEMENT
Sterlite Technologies Ltd.	STLTECH
Strides Pharma Science Ltd.	STAR
Stylam Industries Ltd.	STYLAMIND
Subros Ltd.	SUBROS
Sudarshan Chemical Industries Ltd.	SUDARSCHEM
Sula Vineyards Ltd.	SULA
Sun Pharma Advanced Research Company Ltd.	SPARC
Sunflag Iron & Steel Company Ltd.	SUNFLAG
Sunteck Realty Ltd.	SUNTECK
Suprajit Engineering Ltd.	SUPRAJIT
Supriya Lifescience Ltd.	SUPRIYA
Surya Roshni Ltd.	SURYAROSNI
Symphony Ltd.	SYMPHONY
TARC Ltd.	TARC
TD Power Systems Ltd.	TDPOWERSYS
TVS Supply Chain Solutions Ltd.	TVSSCS
Teamlease Services Ltd.	TEAMLEASE
Technocraft Industries (India) Ltd.	TIIL
Tega Industries Ltd.	TEGA
Texmaco Rail & Eng. Ltd.	TEXRAIL
Thangamayil Jewellery Ltd.	THANGAMAYL
The Anup Engineering Ltd.	ANUP
Thirumalai Chemicals Ltd.	TIRUMALCHM
Thomas Cook (India) Ltd.	THOMASCOOK
Tilaknagar Industries Ltd.	TI
Time Technoplast Ltd.	TIMETECHNO
Tips Music Ltd.	TIPSMUSIC
Transrail Lighting Ltd.	TRANSRAILL
Ujjivan Small Finance Bank Ltd.	UJJIVANSFB
Unimech Aerospace and Manufacturing Ltd.	UNIMECH
V-Mart Retail Ltd.	VMART
V.I.P. Industries Ltd.	VIPIND
VST Industries Ltd.	VSTIND
Va Tech Wabag Ltd.	WABAG
Vaibhav Global Ltd.	VAIBHAVGBL
Varroc Engineering Ltd.	VARROC
Ventive Hospitality Ltd.	VENTIVE
Venus Pipes & Tubes Ltd.	VENUSPIPES
Vesuvius India Ltd.	VESUVIUS
Voltamp Transformers Ltd	VOLTAMP
Websol Energy System Ltd.	WEBELSOLAR
Welspun Enterprises Ltd.	WELENT
Wonderla Holidays Ltd.	WONDERLA
Yatharth Hospital & Trauma Care Services Ltd.	YATHARTH
Zaggle Prepaid Ocean Services Ltd.	ZAGGLE
Zinka Logistics Solutions Ltd.	BLACKBUCK
Zydus Wellness Ltd.	ZYDUSWELL
eMudhra Ltd.	EMUDHRA"""


stocks_microcap = parse_stock_list(stock_list_microcap)
results_smallcap = analyze_stocks(stocks_microcap, output_dir="stock_analysis/reports_v2/microcap_250", max_workers=10, end_date="2025-04-12")
# Out:
# 2025-05-19 16:19:45,541 - INFO - Processing AGI Greenpac Ltd. (AGI)
# 2025-05-19 16:19:45,545 - INFO - Processing ASK Automotive Ltd. (ASKAUTOLTD)
# 2025-05-19 16:19:45,548 - INFO - Processing Aarti Drugs Ltd. (AARTIDRUGS)
# 2025-05-19 16:19:45,550 - INFO - Processing Aarti Pharmalabs Ltd. (AARTIPHARM)
# 2025-05-19 16:19:45,552 - INFO - Processing Aditya Vision Ltd. (AVL)
# 2025-05-19 16:19:45,556 - INFO - Processing Advanced Enzyme Tech Ltd. (ADVENZYMES)
# 2025-05-19 16:19:45,557 - INFO - Processing Aether Industries Ltd. (AETHER)
# 2025-05-19 16:19:45,561 - INFO - Processing Ahluwalia Contracts (India) Ltd. (AHLUCONT)
# 2025-05-19 16:19:45,564 - INFO - Processing Akzo Nobel India Ltd. (AKZOINDIA)
# 2025-05-19 16:19:45,565 - INFO - Processing Allcargo Logistics Ltd. (ALLCARGO)
# 2025-05-19 16:19:46,796 - INFO - Verified unique data for AVL: Latest price = Rs.427.85
# 2025-05-19 16:19:46,804 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:46,933 - INFO - Processing Allied Blenders and Distillers Ltd. (ABDL)
# 2025-05-19 16:19:47,036 - INFO - Verified unique data for AETHER: Latest price = Rs.824.95
# 2025-05-19 16:19:47,051 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,218 - INFO - Verified unique data for AARTIDRUGS: Latest price = Rs.329.15
# 2025-05-19 16:19:47,221 - INFO - Processing Ami Organics Ltd. (AMIORG)
# 2025-05-19 16:19:47,240 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,252 - INFO - Verified unique data for AHLUCONT: Latest price = Rs.862.55
# 2025-05-19 16:19:47,258 - INFO - Verified unique data for ADVENZYMES: Latest price = Rs.272.65
# 2025-05-19 16:19:47,293 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,325 - INFO - Verified unique data for AARTIPHARM: Latest price = Rs.679.40
# 2025-05-19 16:19:47,341 - INFO - Processing Apeejay Surrendra Park Hotels Ltd. (PARKHOTELS)
# 2025-05-19 16:19:47,344 - INFO - Verified unique data for AGI: Latest price = Rs.768.55
# 2025-05-19 16:19:47,344 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,393 - INFO - Verified unique data for AKZOINDIA: Latest price = Rs.3510.45
# 2025-05-19 16:19:47,397 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,399 - INFO - Processing Archean Chemical Industries Ltd. (ACI)
# 2025-05-19 16:19:47,413 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,429 - INFO - Verified unique data for ALLCARGO: Latest price = Rs.27.72
# 2025-05-19 16:19:47,465 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,481 - INFO - Processing Arvind Fashions Ltd. (ARVINDFASN)
# 2025-05-19 16:19:47,518 - INFO - Processing Arvind Ltd. (ARVIND)
# 2025-05-19 16:19:47,529 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,539 - INFO - Processing Ashoka Buildcon Ltd. (ASHOKA)
# 2025-05-19 16:19:47,576 - INFO - Processing Astra Microwave Products Ltd. (ASTRAMICRO)
# 2025-05-19 16:19:47,610 - INFO - Processing Aurionpro Solution Ltd. (AURIONPRO)
# 2025-05-19 16:19:47,662 - INFO - Verified unique data for ASKAUTOLTD: Latest price = Rs.407.60
# 2025-05-19 16:19:47,663 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:47,690 - INFO - Processing Avalon Technologies Ltd. (AVALON)
# 2025-05-19 16:19:48,172 - INFO - Verified unique data for ABDL: Latest price = Rs.319.05
# 2025-05-19 16:19:48,174 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:48,206 - INFO - Processing Avanti Feeds Ltd. (AVANTIFEED)
# 2025-05-19 16:19:48,513 - INFO - Verified unique data for AMIORG: Latest price = Rs.1128.32
# 2025-05-19 16:19:48,515 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:48,542 - INFO - Processing Awfis Space Solutions Ltd. (AWFIS)
# 2025-05-19 16:19:48,579 - INFO - Verified unique data for PARKHOTELS: Latest price = Rs.139.78
# 2025-05-19 16:19:48,581 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:48,616 - INFO - Processing Azad Engineering Ltd. (AZAD)
# 2025-05-19 16:19:48,709 - INFO - ACI.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-21']
# 2025-05-19 16:19:48,755 - INFO - Verified unique data for ACI: Latest price = Rs.601.10
# 2025-05-19 16:19:48,762 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:48,832 - INFO - Processing Bajaj Hindusthan Sugar Ltd. (BAJAJHIND)
# 2025-05-19 16:19:48,904 - INFO - Verified unique data for ARVINDFASN: Latest price = Rs.382.00
# 2025-05-19 16:19:48,917 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,018 - INFO - Processing Balaji Amines Ltd. (BALAMINES)
# 2025-05-19 16:19:49,029 - INFO - Verified unique data for ASHOKA: Latest price = Rs.186.49
# 2025-05-19 16:19:49,047 - INFO - Verified unique data for ARVIND: Latest price = Rs.333.10
# 2025-05-19 16:19:49,076 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,083 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,117 - INFO - Verified unique data for AURIONPRO: Latest price = Rs.1556.80
# 2025-05-19 16:19:49,154 - INFO - Verified unique data for AVALON: Latest price = Rs.812.30
# 2025-05-19 16:19:49,165 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,182 - INFO - Processing Balu Forge Industries Ltd. (BALUFORGE)
# 2025-05-19 16:19:49,183 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,194 - INFO - Verified unique data for ASTRAMICRO: Latest price = Rs.723.00
# 2025-05-19 16:19:49,196 - INFO - Processing Banco Products (India) Ltd. (BANCOINDIA)
# 2025-05-19 16:19:49,240 - INFO - Processing Bansal Wire Industries Ltd. (BANSALWIRE)
# 2025-05-19 16:19:49,264 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,266 - INFO - Processing Bhansali Engineering Polymers Ltd. (BEPL)
# 2025-05-19 16:19:49,297 - INFO - Processing Bharat Bijlee Ltd. (BBL)
# 2025-05-19 16:19:49,460 - INFO - Verified unique data for AVANTIFEED: Latest price = Rs.799.65
# 2025-05-19 16:19:49,461 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,490 - INFO - Processing Birla Corporation Ltd. (BIRLACORPN)
# 2025-05-19 16:19:49,696 - INFO - Verified unique data for AWFIS: Latest price = Rs.634.35
# 2025-05-19 16:19:49,698 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,726 - INFO - Processing Blue Jet Healthcare Ltd. (BLUEJET)
# 2025-05-19 16:19:49,780 - INFO - Verified unique data for AZAD: Latest price = Rs.1337.25
# 2025-05-19 16:19:49,782 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:49,808 - INFO - Processing Bombay Dyeing & Manufacturing Co. Ltd. (BOMDYEING)
# 2025-05-19 16:19:50,036 - INFO - Verified unique data for BAJAJHIND: Latest price = Rs.18.22
# 2025-05-19 16:19:50,039 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:50,067 - INFO - Processing Borosil Ltd. (BOROLTD)
# 2025-05-19 16:19:50,229 - INFO - Verified unique data for BALAMINES: Latest price = Rs.1205.35
# 2025-05-19 16:19:50,231 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:50,258 - INFO - Processing Borosil Renewables Ltd. (BORORENEW)
# 2025-05-19 16:19:50,399 - INFO - Verified unique data for BALUFORGE: Latest price = Rs.627.75
# 2025-05-19 16:19:50,400 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:50,428 - INFO - Processing CIE Automotive India Ltd. (CIEINDIA)
# 2025-05-19 16:19:50,660 - INFO - Verified unique data for BEPL: Latest price = Rs.106.64
# 2025-05-19 16:19:50,671 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:50,700 - INFO - Verified unique data for BANCOINDIA: Latest price = Rs.335.85
# 2025-05-19 16:19:50,705 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:50,736 - INFO - Verified unique data for BBL: Latest price = Rs.2881.20
# 2025-05-19 16:19:50,739 - INFO - Processing CMS Info Systems Ltd. (CMSINFO)
# 2025-05-19 16:19:50,770 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:50,776 - INFO - Processing CSB Bank Ltd. (CSBBANK)
# 2025-05-19 16:19:50,842 - INFO - Processing Cartrade Tech Ltd. (CARTRADE)
# 2025-05-19 16:19:50,885 - INFO - Verified unique data for BIRLACORPN: Latest price = Rs.1109.95
# 2025-05-19 16:19:50,887 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:50,969 - INFO - Processing Ceigall India Ltd. (CEIGALL)
# 2025-05-19 16:19:51,005 - INFO - Verified unique data for BANSALWIRE: Latest price = Rs.349.75
# 2025-05-19 16:19:51,008 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:51,051 - INFO - Processing Cello World Ltd. (CELLO)
# 2025-05-19 16:19:51,071 - INFO - Verified unique data for BLUEJET: Latest price = Rs.683.55
# 2025-05-19 16:19:51,075 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:51,122 - INFO - Processing Chemplast Sanmar Ltd. (CHEMPLASTS)
# 2025-05-19 16:19:51,137 - INFO - Verified unique data for BOMDYEING: Latest price = Rs.126.91
# 2025-05-19 16:19:51,138 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:51,166 - INFO - Processing Choice International Ltd. (CHOICEIN)
# 2025-05-19 16:19:51,382 - INFO - Verified unique data for BOROLTD: Latest price = Rs.326.65
# 2025-05-19 16:19:51,383 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:51,414 - INFO - Processing Cigniti Technologies Ltd. (CIGNITITEC)
# 2025-05-19 16:19:51,447 - INFO - Verified unique data for BORORENEW: Latest price = Rs.478.65
# 2025-05-19 16:19:51,448 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:51,478 - INFO - Processing Cyient DLM Ltd. (CYIENTDLM)
# 2025-05-19 16:19:51,773 - INFO - Verified unique data for CIEINDIA: Latest price = Rs.394.18
# 2025-05-19 16:19:51,774 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:51,806 - INFO - Processing DCB Bank Ltd. (DCBBANK)
# 2025-05-19 16:19:51,969 - INFO - Verified unique data for CSBBANK: Latest price = Rs.323.00
# 2025-05-19 16:19:51,970 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,000 - INFO - Processing DCX Systems Ltd. (DCXINDIA)
# 2025-05-19 16:19:52,028 - INFO - Verified unique data for CARTRADE: Latest price = Rs.1538.10
# 2025-05-19 16:19:52,030 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,063 - INFO - Processing Datamatics Global Services Ltd. (DATAMATICS)
# 2025-05-19 16:19:52,129 - INFO - Verified unique data for CMSINFO: Latest price = Rs.453.35
# 2025-05-19 16:19:52,130 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,213 - INFO - Processing Dhani Services Ltd. (DHANI)
# 2025-05-19 16:19:52,284 - INFO - Verified unique data for CHEMPLASTS: Latest price = Rs.432.70
# 2025-05-19 16:19:52,285 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,314 - INFO - Processing Dilip Buildcon Ltd. (DBL)
# 2025-05-19 16:19:52,371 - INFO - Verified unique data for CELLO: Latest price = Rs.523.75
# 2025-05-19 16:19:52,390 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,477 - INFO - Processing Dishman Carbogen Amcis Ltd. (DCAL)
# 2025-05-19 16:19:52,513 - INFO - Verified unique data for CHOICEIN: Latest price = Rs.515.60
# 2025-05-19 16:19:52,536 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,588 - INFO - Verified unique data for CEIGALL: Latest price = Rs.254.60
# 2025-05-19 16:19:52,593 - INFO - Processing Dodla Dairy Ltd. (DODLA)
# 2025-05-19 16:19:52,594 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,625 - INFO - Processing Dynamatic Technologies Ltd. (DYNAMATECH)
# 2025-05-19 16:19:52,655 - INFO - Verified unique data for CYIENTDLM: Latest price = Rs.445.30
# 2025-05-19 16:19:52,656 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,684 - INFO - Processing EPL Ltd. (EPL)
# 2025-05-19 16:19:52,780 - INFO - Verified unique data for CIGNITITEC: Latest price = Rs.1172.35
# 2025-05-19 16:19:52,782 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:52,811 - INFO - Processing Easy Trip Planners Ltd. (EASEMYTRIP)
# 2025-05-19 16:19:53,041 - INFO - Verified unique data for DCBBANK: Latest price = Rs.117.91
# 2025-05-19 16:19:53,042 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:53,075 - INFO - Processing Edelweiss Financial Services Ltd. (EDELWEISS)
# 2025-05-19 16:19:53,214 - INFO - Verified unique data for DCXINDIA: Latest price = Rs.229.38
# 2025-05-19 16:19:53,217 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:53,244 - INFO - Processing Electronics Mart India Ltd. (EMIL)
# 2025-05-19 16:19:53,329 - INFO - Verified unique data for DATAMATICS: Latest price = Rs.570.45
# 2025-05-19 16:19:53,330 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:53,359 - INFO - Processing Electrosteel Castings Ltd. (ELECTCAST)
# 2025-05-19 16:19:53,389 - INFO - Verified unique data for DHANI: Latest price = Rs.54.00
# 2025-05-19 16:19:53,390 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:53,416 - INFO - Processing Embassy Developments Ltd. (EMBDL)
# 2025-05-19 16:19:53,508 - INFO - Verified unique data for DBL: Latest price = Rs.442.65
# 2025-05-19 16:19:53,509 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:53,537 - INFO - Processing Entero Healthcare Solutions Ltd. (ENTERO)
# 2025-05-19 16:19:53,720 - INFO - Verified unique data for DCAL: Latest price = Rs.203.95
# 2025-05-19 16:19:53,721 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:53,749 - INFO - Processing Enviro Infra Engineers Ltd. (EIEL)
# 2025-05-19 16:19:53,808 - INFO - Verified unique data for DODLA: Latest price = Rs.1185.80
# 2025-05-19 16:19:53,809 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:53,839 - INFO - Processing Epigral Ltd. (EPIGRAL)
# 2025-05-19 16:19:53,901 - INFO - Verified unique data for DYNAMATECH: Latest price = Rs.6275.50
# 2025-05-19 16:19:53,923 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:53,977 - INFO - Processing Equitas Small Finance Bank Ltd. (EQUITASBNK)
# 2025-05-19 16:19:53,986 - INFO - Verified unique data for EPL: Latest price = Rs.184.60
# 2025-05-19 16:19:53,989 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:54,026 - INFO - Processing Ethos Ltd. (ETHOSLTD)
# 2025-05-19 16:19:54,073 - INFO - Verified unique data for EASEMYTRIP: Latest price = Rs.13.08
# 2025-05-19 16:19:54,074 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:54,109 - INFO - Processing Eureka Forbes Ltd. (EUREKAFORB)
# 2025-05-19 16:19:54,377 - INFO - Verified unique data for EDELWEISS: Latest price = Rs.79.06
# 2025-05-19 16:19:54,378 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:54,409 - INFO - Processing FDC Ltd. (FDC)
# 2025-05-19 16:19:54,452 - INFO - Verified unique data for EMIL: Latest price = Rs.119.56
# 2025-05-19 16:19:54,454 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:54,482 - INFO - Processing Fiem Industries Ltd (FIEMIND)
# 2025-05-19 16:19:54,593 - INFO - Verified unique data for ELECTCAST: Latest price = Rs.94.87
# 2025-05-19 16:19:54,614 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:54,641 - INFO - Processing Fine Organic Industries Ltd. (FINEORG)
# 2025-05-19 16:19:54,702 - INFO - Verified unique data for ENTERO: Latest price = Rs.1160.55
# 2025-05-19 16:19:54,703 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:54,729 - INFO - Processing Fineotex Chemical Ltd. (FCL)
# 2025-05-19 16:19:54,809 - INFO - Verified unique data for EMBDL: Latest price = Rs.100.39
# 2025-05-19 16:19:54,810 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:54,832 - INFO - Processing Force Motors Ltd. (FORCEMOT)
# 2025-05-19 16:19:54,908 - INFO - Verified unique data for EIEL: Latest price = Rs.205.41
# 2025-05-19 16:19:54,909 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:54,928 - INFO - Processing G R Infraprojects Ltd. (GRINFRA)
# 2025-05-19 16:19:55,215 - INFO - Verified unique data for EQUITASBNK: Latest price = Rs.57.65
# 2025-05-19 16:19:55,216 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:55,272 - INFO - Processing GHCL Ltd. (GHCL)
# 2025-05-19 16:19:55,330 - INFO - Verified unique data for ETHOSLTD: Latest price = Rs.2548.10
# 2025-05-19 16:19:55,344 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:55,379 - INFO - Processing GMM Pfaudler Ltd. (GMMPFAUDLR)
# 2025-05-19 16:19:55,432 - INFO - Verified unique data for EPIGRAL: Latest price = Rs.1784.65
# 2025-05-19 16:19:55,434 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:55,460 - INFO - Processing GMR Power and Urban Infra Ltd. (GMRP&UI)
# 2025-05-19 16:19:55,482 - INFO - EUREKAFORB.NS: 1h: price-reconstruct: Too old (8 rows tagged)
# 2025-05-19 16:19:55,519 - INFO - Verified unique data for EUREKAFORB: Latest price = Rs.501.70
# 2025-05-19 16:19:55,520 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:55,543 - INFO - Processing Gabriel India Ltd. (GABRIEL)
# 2025-05-19 16:19:55,657 - INFO - Verified unique data for FDC: Latest price = Rs.421.50
# 2025-05-19 16:19:55,658 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:55,683 - INFO - Processing Ganesh Housing Corporation Ltd. (GANESHHOUC)
# 2025-05-19 16:19:55,780 - INFO - Verified unique data for FIEMIND: Latest price = Rs.1364.90
# 2025-05-19 16:19:55,781 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:55,809 - INFO - Processing Ganesha Ecosphere Ltd. (GANECOS)
# 2025-05-19 16:19:56,061 - INFO - Verified unique data for FCL: Latest price = Rs.227.57
# 2025-05-19 16:19:56,062 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:56,089 - INFO - Processing Garware Hi-Tech Films Ltd. (GRWRHITECH)
# 2025-05-19 16:19:56,124 - INFO - Verified unique data for GRINFRA: Latest price = Rs.1073.10
# 2025-05-19 16:19:56,126 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:56,155 - INFO - Processing Garware Technical Fibres Ltd. (GARFIBRES)
# 2025-05-19 16:19:56,220 - INFO - Verified unique data for FORCEMOT: Latest price = Rs.8705.05
# 2025-05-19 16:19:56,221 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# C:\Users\anand\AppData\Local\Temp\ipykernel_22668\2035657839.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = close_series.pct_change().dropna()
# C:\Users\anand\AppData\Local\Temp\ipykernel_22668\1984993891.py:133: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = data_df['Close'].pct_change().dropna()
# 2025-05-19 16:19:56,246 - INFO - Processing Gateway Distriparks Ltd. (GATEWAY)
# 2025-05-19 16:19:56,385 - INFO - Verified unique data for FINEORG: Latest price = Rs.4040.30
# 2025-05-19 16:19:56,386 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:56,414 - INFO - Processing Gokaldas Exports Ltd. (GOKEX)
# 2025-05-19 16:19:56,459 - INFO - Verified unique data for GHCL: Latest price = Rs.593.00
# 2025-05-19 16:19:56,460 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:56,487 - INFO - Processing Gopal Snacks Ltd. (GOPAL)
# 2025-05-19 16:19:56,723 - INFO - Verified unique data for GMMPFAUDLR: Latest price = Rs.1062.55
# 2025-05-19 16:19:56,724 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:56,760 - INFO - Processing Greaves Cotton Ltd. (GREAVESCOT)
# 2025-05-19 16:19:56,809 - INFO - Verified unique data for GMRP&UI: Latest price = Rs.116.76
# 2025-05-19 16:19:56,817 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:56,853 - INFO - Processing Greenpanel Industries Ltd. (GREENPANEL)
# 2025-05-19 16:19:56,862 - INFO - Verified unique data for GABRIEL: Latest price = Rs.532.00
# 2025-05-19 16:19:56,864 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:56,889 - INFO - Processing Greenply Industries Ltd. (GREENPLY)
# 2025-05-19 16:19:56,928 - INFO - Verified unique data for GANESHHOUC: Latest price = Rs.1018.85
# 2025-05-19 16:19:56,930 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:56,961 - INFO - Processing Gujarat Ambuja Exports Ltd. (GAEL)
# 2025-05-19 16:19:57,021 - INFO - Verified unique data for GANECOS: Latest price = Rs.1550.55
# 2025-05-19 16:19:57,023 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:57,049 - INFO - Processing Gujarat State Fertilizers & Chemicals Ltd. (GSFC)
# 2025-05-19 16:19:57,298 - INFO - Verified unique data for GRWRHITECH: Latest price = Rs.2649.75
# 2025-05-19 16:19:57,299 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:57,324 - INFO - Processing Gulf Oil Lubricants India Ltd. (GULFOILLUB)
# 2025-05-19 16:19:57,417 - INFO - Verified unique data for GARFIBRES: Latest price = Rs.843.95
# 2025-05-19 16:19:57,422 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:57,471 - INFO - Processing H.G. Infra Engineering Ltd. (HGINFRA)
# 2025-05-19 16:19:57,486 - INFO - Verified unique data for GATEWAY: Latest price = Rs.61.41
# 2025-05-19 16:19:57,489 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:57,516 - INFO - Processing Hathway Cable & Datacom Ltd. (HATHWAY)
# 2025-05-19 16:19:57,673 - INFO - Verified unique data for GOKEX: Latest price = Rs.783.45
# 2025-05-19 16:19:57,675 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:57,701 - INFO - Processing Healthcare Global Enterprises Ltd. (HCG)
# 2025-05-19 16:19:57,770 - INFO - Verified unique data for GOPAL: Latest price = Rs.278.20
# 2025-05-19 16:19:57,771 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:57,802 - INFO - Processing HeidelbergCement India Ltd. (HEIDELBERG)
# 2025-05-19 16:19:58,005 - INFO - Verified unique data for GREAVESCOT: Latest price = Rs.182.70
# 2025-05-19 16:19:58,006 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,036 - INFO - Processing Hemisphere Properties India Ltd. (HEMIPROP)
# 2025-05-19 16:19:58,098 - INFO - Verified unique data for GREENPLY: Latest price = Rs.286.45
# 2025-05-19 16:19:58,110 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,145 - INFO - Processing Heritage Foods Ltd. (HERITGFOOD)
# 2025-05-19 16:19:58,161 - INFO - Verified unique data for GREENPANEL: Latest price = Rs.227.65
# 2025-05-19 16:19:58,162 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,225 - INFO - Processing Hikal Ltd. (HIKAL)
# 2025-05-19 16:19:58,248 - INFO - Verified unique data for GAEL: Latest price = Rs.115.81
# 2025-05-19 16:19:58,249 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,276 - INFO - Processing Hindustan Construction Co. Ltd. (HCC)
# 2025-05-19 16:19:58,318 - INFO - Verified unique data for GSFC: Latest price = Rs.175.62
# 2025-05-19 16:19:58,319 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,351 - INFO - Processing IFB Industries Ltd. (IFBIND)
# 2025-05-19 16:19:58,575 - INFO - Verified unique data for GULFOILLUB: Latest price = Rs.1131.55
# 2025-05-19 16:19:58,576 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,604 - INFO - Processing IIFL Capital Services Ltd. (IIFLCAPS)
# 2025-05-19 16:19:58,706 - INFO - Verified unique data for HATHWAY: Latest price = Rs.13.04
# 2025-05-19 16:19:58,716 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,762 - INFO - Verified unique data for HGINFRA: Latest price = Rs.1052.85
# 2025-05-19 16:19:58,763 - INFO - Processing ITD Cementation India Ltd. (ITDCEM)
# 2025-05-19 16:19:58,765 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,794 - INFO - Processing Imagicaaworld Entertainment Ltd. (IMAGICAA)
# 2025-05-19 16:19:58,865 - INFO - Verified unique data for HCG: Latest price = Rs.533.90
# 2025-05-19 16:19:58,867 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:58,898 - INFO - Processing India Glycols Ltd. (INDIAGLYCO)
# 2025-05-19 16:19:59,043 - INFO - Verified unique data for HEIDELBERG: Latest price = Rs.194.91
# 2025-05-19 16:19:59,046 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:59,075 - INFO - Processing India Shelter Finance Corporation Ltd. (INDIASHLTR)
# 2025-05-19 16:19:59,200 - INFO - Verified unique data for HEMIPROP: Latest price = Rs.123.47
# 2025-05-19 16:19:59,201 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:59,225 - INFO - Processing Indian Metals & Ferro Alloys Ltd. (IMFA)
# 2025-05-19 16:19:59,414 - INFO - Verified unique data for HERITGFOOD: Latest price = Rs.403.15
# 2025-05-19 16:19:59,416 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:59,446 - INFO - Processing Indigo Paints Ltd. (INDIGOPNTS)
# 2025-05-19 16:19:59,515 - INFO - Verified unique data for HCC: Latest price = Rs.25.18
# 2025-05-19 16:19:59,521 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:59,571 - INFO - Processing Indo Count Industries Ltd. (ICIL)
# 2025-05-19 16:19:59,577 - INFO - Verified unique data for HIKAL: Latest price = Rs.418.85
# 2025-05-19 16:19:59,578 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:59,625 - INFO - Processing Infibeam Avenues Ltd. (INFIBEAM)
# 2025-05-19 16:19:59,640 - INFO - Verified unique data for IFBIND: Latest price = Rs.1289.95
# 2025-05-19 16:19:59,641 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:59,669 - INFO - Processing Ingersoll Rand (India) Ltd. (INGERRAND)
# 2025-05-19 16:19:59,781 - INFO - Verified unique data for IIFLCAPS: Latest price = Rs.206.54
# 2025-05-19 16:19:59,782 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:19:59,804 - INFO - Processing Innova Captab Ltd. (INNOVACAP)
# 2025-05-19 16:19:59,973 - INFO - Verified unique data for ITDCEM: Latest price = Rs.524.90
# 2025-05-19 16:19:59,980 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:00,034 - INFO - Verified unique data for IMAGICAA: Latest price = Rs.65.44
# 2025-05-19 16:20:00,036 - INFO - Processing Inox Green Energy Services Ltd. (INOXGREEN)
# 2025-05-19 16:20:00,037 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:00,064 - INFO - Processing Ion Exchange (India) Ltd. (IONEXCHANG)
# 2025-05-19 16:20:00,163 - INFO - Verified unique data for INDIAGLYCO: Latest price = Rs.1269.05
# 2025-05-19 16:20:00,164 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:00,190 - INFO - Processing Isgec Heavy Engineering Ltd. (ISGEC)
# 2025-05-19 16:20:00,240 - INFO - Verified unique data for INDIASHLTR: Latest price = Rs.850.90
# 2025-05-19 16:20:00,241 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:00,264 - INFO - Processing J.Kumar Infraprojects Ltd. (JKIL)
# 2025-05-19 16:20:00,495 - INFO - Verified unique data for IMFA: Latest price = Rs.594.70
# 2025-05-19 16:20:00,497 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:00,525 - INFO - Processing JK Lakshmi Cement Ltd. (JKLAKSHMI)
# 2025-05-19 16:20:00,686 - INFO - Verified unique data for INDIGOPNTS: Latest price = Rs.985.70
# 2025-05-19 16:20:00,688 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:00,715 - INFO - Processing JK Paper Ltd. (JKPAPER)
# 2025-05-19 16:20:00,819 - INFO - Verified unique data for ICIL: Latest price = Rs.280.15
# 2025-05-19 16:20:00,821 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:00,850 - INFO - Processing JTL Industries Ltd. (JTLIND)
# 2025-05-19 16:20:00,901 - INFO - Verified unique data for INFIBEAM: Latest price = Rs.16.25
# 2025-05-19 16:20:00,902 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:00,963 - INFO - Processing Jai Balaji Industries Ltd. (JAIBALAJI)
# 2025-05-19 16:20:00,980 - INFO - Verified unique data for INGERRAND: Latest price = Rs.3502.55
# 2025-05-19 16:20:00,991 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:01,161 - INFO - Verified unique data for INNOVACAP: Latest price = Rs.875.70
# 2025-05-19 16:20:01,162 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:01,190 - INFO - Processing Jai Corp Ltd. (JAICORPLTD)
# 2025-05-19 16:20:01,209 - INFO - Processing Jain Irrigation Systems Ltd. (JISLJALEQS)
# 2025-05-19 16:20:01,335 - INFO - Verified unique data for IONEXCHANG: Latest price = Rs.483.15
# 2025-05-19 16:20:01,337 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:01,364 - INFO - Processing Jamna Auto Industries Ltd. (JAMNAAUTO)
# 2025-05-19 16:20:01,393 - INFO - Verified unique data for INOXGREEN: Latest price = Rs.119.19
# 2025-05-19 16:20:01,395 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:01,446 - INFO - Processing Jana Small Finance Bank Ltd. (JSFB)
# 2025-05-19 16:20:01,459 - INFO - Verified unique data for ISGEC: Latest price = Rs.1033.20
# 2025-05-19 16:20:01,460 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:01,499 - INFO - Processing Jindal Worldwide Ltd. (JINDWORLD)
# 2025-05-19 16:20:01,532 - INFO - Verified unique data for JKIL: Latest price = Rs.693.35
# 2025-05-19 16:20:01,535 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:01,564 - INFO - Processing Johnson Controls - Hitachi Air Conditioning India Ltd. (JCHAC)
# 2025-05-19 16:20:01,936 - INFO - Verified unique data for JKLAKSHMI: Latest price = Rs.788.95
# 2025-05-19 16:20:01,945 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:01,986 - INFO - Processing KPI Green Energy Ltd. (KPIGREEN)
# 2025-05-19 16:20:01,991 - INFO - Verified unique data for JKPAPER: Latest price = Rs.320.60
# 2025-05-19 16:20:01,993 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,019 - INFO - Processing KRBL Ltd. (KRBL)
# 2025-05-19 16:20:02,122 - INFO - Verified unique data for JTLIND: Latest price = Rs.74.63
# 2025-05-19 16:20:02,124 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,154 - INFO - Processing KSB Ltd. (KSB)
# 2025-05-19 16:20:02,231 - INFO - Verified unique data for JAIBALAJI: Latest price = Rs.131.30
# 2025-05-19 16:20:02,232 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,256 - INFO - Processing Kalyani Steels Ltd. (KSL)
# 2025-05-19 16:20:02,407 - INFO - Verified unique data for JAICORPLTD: Latest price = Rs.84.21
# 2025-05-19 16:20:02,408 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,434 - INFO - Processing Karnataka Bank Ltd. (KTKBANK)
# 2025-05-19 16:20:02,551 - INFO - Verified unique data for JISLJALEQS: Latest price = Rs.52.25
# 2025-05-19 16:20:02,552 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,579 - INFO - Processing Kaveri Seed Company Ltd. (KSCL)
# 2025-05-19 16:20:02,636 - INFO - Verified unique data for JAMNAAUTO: Latest price = Rs.72.16
# 2025-05-19 16:20:02,641 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,685 - INFO - Verified unique data for JSFB: Latest price = Rs.452.90
# 2025-05-19 16:20:02,686 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,687 - INFO - Processing Kirloskar Pneumatic Company Ltd. (KIRLPNU)
# 2025-05-19 16:20:02,715 - INFO - Processing LMW Ltd. (LMW)
# 2025-05-19 16:20:02,759 - INFO - Verified unique data for JINDWORLD: Latest price = Rs.67.53
# 2025-05-19 16:20:02,760 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,786 - INFO - Processing Laxmi Organic Industries Ltd. (LXCHEM)
# 2025-05-19 16:20:02,948 - INFO - Verified unique data for JCHAC: Latest price = Rs.1737.05
# 2025-05-19 16:20:02,949 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:02,971 - INFO - Processing Le Travenues Technology Ltd. (IXIGO)
# 2025-05-19 16:20:03,316 - INFO - Verified unique data for KRBL: Latest price = Rs.288.45
# 2025-05-19 16:20:03,317 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:03,344 - INFO - Processing Lloyds Engineering Works Ltd. (LLOYDSENGG)
# 2025-05-19 16:20:03,428 - INFO - Verified unique data for KSB: Latest price = Rs.714.83
# 2025-05-19 16:20:03,429 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:03,458 - INFO - Processing Lloyds Enterprises Ltd. (LLOYDSENT)
# 2025-05-19 16:20:03,514 - INFO - Verified unique data for KPIGREEN: Latest price = Rs.410.15
# 2025-05-19 16:20:03,515 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:03,541 - INFO - Processing Lux Industries Ltd. (LUXIND)
# 2025-05-19 16:20:03,578 - INFO - Verified unique data for KSL: Latest price = Rs.729.30
# 2025-05-19 16:20:03,579 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:03,608 - INFO - Processing MOIL Ltd. (MOIL)
# 2025-05-19 16:20:03,648 - INFO - Verified unique data for KTKBANK: Latest price = Rs.181.67
# 2025-05-19 16:20:03,649 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:03,671 - INFO - Processing MSTC Ltd. (MSTCLTD)
# 2025-05-19 16:20:03,840 - INFO - Verified unique data for KSCL: Latest price = Rs.1432.25
# 2025-05-19 16:20:03,841 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:03,865 - INFO - Processing MTAR Technologies Ltd. (MTARTECH)
# 2025-05-19 16:20:03,924 - INFO - Verified unique data for KIRLPNU: Latest price = Rs.1101.85
# 2025-05-19 16:20:03,925 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:03,964 - INFO - Processing Maharashtra Scooters Ltd. (MAHSCOOTER)
# 2025-05-19 16:20:04,030 - INFO - Verified unique data for LMW: Latest price = Rs.15283.35
# 2025-05-19 16:20:04,041 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:04,044 - INFO - Verified unique data for LXCHEM: Latest price = Rs.170.88
# 2025-05-19 16:20:04,060 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:04,078 - INFO - Processing Mahindra Lifespace Developers Ltd. (MAHLIFE)
# 2025-05-19 16:20:04,096 - INFO - Processing Man Infraconstruction Ltd. (MANINFRA)
# 2025-05-19 16:20:04,172 - INFO - Verified unique data for IXIGO: Latest price = Rs.141.27
# 2025-05-19 16:20:04,173 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:04,201 - INFO - Processing Marksans Pharma Ltd. (MARKSANS)
# 2025-05-19 16:20:04,696 - INFO - Verified unique data for LLOYDSENT: Latest price = Rs.52.02
# 2025-05-19 16:20:04,697 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:04,717 - INFO - Processing Max Estates Ltd. (MAXESTATES)
# 2025-05-19 16:20:04,778 - INFO - Verified unique data for LUXIND: Latest price = Rs.1352.75
# 2025-05-19 16:20:04,779 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:04,862 - INFO - Processing Medplus Health Services Ltd. (MEDPLUS)
# 2025-05-19 16:20:04,959 - INFO - Verified unique data for MOIL: Latest price = Rs.306.30
# 2025-05-19 16:20:04,963 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:05,000 - INFO - Verified unique data for MSTCLTD: Latest price = Rs.500.00
# 2025-05-19 16:20:05,006 - INFO - Processing Mishra Dhatu Nigam Ltd. (MIDHANI)
# 2025-05-19 16:20:05,011 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:05,073 - INFO - Processing Mrs. Bectors Food Specialities Ltd. (BECTORFOOD)
# 2025-05-19 16:20:05,121 - INFO - Verified unique data for MTARTECH: Latest price = Rs.1322.75
# 2025-05-19 16:20:05,124 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:05,158 - INFO - Processing NEOGEN CHEMICALS LTD. (NEOGEN)
# 2025-05-19 16:20:05,262 - INFO - Verified unique data for LLOYDSENGG: Latest price = Rs.59.23
# 2025-05-19 16:20:05,263 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:05,296 - INFO - Verified unique data for MAHSCOOTER: Latest price = Rs.10448.30
# 2025-05-19 16:20:05,301 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:05,304 - INFO - Processing NESCO Ltd. (NESCO)
# 2025-05-19 16:20:05,358 - INFO - Processing NOCIL Ltd. (NOCIL)
# 2025-05-19 16:20:05,443 - INFO - Verified unique data for MAHLIFE: Latest price = Rs.293.45
# 2025-05-19 16:20:05,446 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:05,459 - INFO - Verified unique data for MANINFRA: Latest price = Rs.144.80
# 2025-05-19 16:20:05,504 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:05,510 - INFO - Processing National Fertilizers Ltd. (NFL)
# 2025-05-19 16:20:05,549 - INFO - Processing Nazara Technologies Ltd. (NAZARA)
# 2025-05-19 16:20:05,555 - INFO - Verified unique data for MARKSANS: Latest price = Rs.205.58
# 2025-05-19 16:20:05,557 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:05,585 - INFO - Processing Nuvoco Vistas Corporation Ltd. (NUVOCO)
# 2025-05-19 16:20:06,193 - INFO - Verified unique data for MEDPLUS: Latest price = Rs.789.20
# 2025-05-19 16:20:06,194 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,249 - INFO - Processing Optiemus Infracom Ltd. (OPTIEMUS)
# 2025-05-19 16:20:06,309 - INFO - Verified unique data for MIDHANI: Latest price = Rs.266.40
# 2025-05-19 16:20:06,310 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,369 - INFO - Processing Orchid Pharma Ltd. (ORCHPHARMA)
# 2025-05-19 16:20:06,377 - INFO - Verified unique data for BECTORFOOD: Latest price = Rs.1586.20
# 2025-05-19 16:20:06,385 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,430 - INFO - Processing Orient Cement Ltd. (ORIENTCEM)
# 2025-05-19 16:20:06,500 - INFO - Verified unique data for MAXESTATES: Latest price = Rs.402.75
# 2025-05-19 16:20:06,502 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,540 - INFO - Verified unique data for NEOGEN: Latest price = Rs.1558.55
# 2025-05-19 16:20:06,541 - INFO - Processing Orissa Min Dev Co Ltd. (ORISSAMINE)
# 2025-05-19 16:20:06,543 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,597 - INFO - Processing P N Gadgil Jewellers Ltd. (PNGJL)
# 2025-05-19 16:20:06,663 - INFO - Verified unique data for NESCO: Latest price = Rs.950.70
# 2025-05-19 16:20:06,668 - INFO - Verified unique data for NOCIL: Latest price = Rs.180.36
# 2025-05-19 16:20:06,669 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,670 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,710 - INFO - Processing PC Jeweller Ltd. (PCJEWELLER)
# 2025-05-19 16:20:06,726 - INFO - Processing PTC India Ltd. (PTC)
# 2025-05-19 16:20:06,776 - INFO - Verified unique data for NFL: Latest price = Rs.78.28
# 2025-05-19 16:20:06,777 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,805 - INFO - Processing Paisalo Digital Ltd. (PAISALO)
# 2025-05-19 16:20:06,916 - INFO - Verified unique data for NAZARA: Latest price = Rs.961.05
# 2025-05-19 16:20:06,919 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,960 - INFO - Processing Paradeep Phosphates Ltd. (PARADEEP)
# 2025-05-19 16:20:06,962 - INFO - Verified unique data for NUVOCO: Latest price = Rs.314.45
# 2025-05-19 16:20:06,964 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:06,994 - INFO - Processing Paras Defence and Space Technologies Ltd. (PARAS)
# 2025-05-19 16:20:07,426 - INFO - Verified unique data for OPTIEMUS: Latest price = Rs.406.80
# 2025-05-19 16:20:07,427 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:07,454 - INFO - Processing Patel Engineering Ltd. (PATELENG)
# 2025-05-19 16:20:07,583 - INFO - Verified unique data for ORCHPHARMA: Latest price = Rs.719.70
# 2025-05-19 16:20:07,584 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:07,617 - INFO - Processing Pearl Global Industries Ltd. (PGIL)
# 2025-05-19 16:20:07,698 - INFO - Verified unique data for ORIENTCEM: Latest price = Rs.357.80
# 2025-05-19 16:20:07,699 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:07,727 - INFO - Processing Polyplex Corporation Ltd. (POLYPLEX)
# 2025-05-19 16:20:07,845 - INFO - Verified unique data for ORISSAMINE: Latest price = Rs.4693.95
# 2025-05-19 16:20:07,846 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:07,876 - INFO - Processing Power Mech Projects Ltd. (POWERMECH)
# 2025-05-19 16:20:07,975 - INFO - Verified unique data for PTC: Latest price = Rs.167.83
# 2025-05-19 16:20:07,978 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:08,032 - INFO - Processing Pricol Ltd. (PRICOLLTD)
# 2025-05-19 16:20:08,037 - INFO - Verified unique data for PCJEWELLER: Latest price = Rs.13.60
# 2025-05-19 16:20:08,098 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:08,175 - INFO - Processing Prince Pipes and Fittings Ltd. (PRINCEPIPE)
# 2025-05-19 16:20:08,218 - INFO - Verified unique data for PNGJL: Latest price = Rs.532.55
# 2025-05-19 16:20:08,230 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:08,253 - INFO - Verified unique data for PAISALO: Latest price = Rs.31.72
# 2025-05-19 16:20:08,271 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:08,325 - INFO - Processing Prism Johnson Ltd. (PRSMJOHNSN)
# 2025-05-19 16:20:08,336 - INFO - Processing Prudent Corporate Advisory Services Ltd. (PRUDENT)
# 2025-05-19 16:20:08,344 - INFO - Verified unique data for PARAS: Latest price = Rs.973.25
# 2025-05-19 16:20:08,349 - INFO - Verified unique data for PARADEEP: Latest price = Rs.119.91
# 2025-05-19 16:20:08,350 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:08,352 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:08,396 - INFO - Processing Rain Industries Ltd (RAIN)
# 2025-05-19 16:20:08,407 - INFO - Processing Rajesh Exports Ltd. (RAJESHEXPO)
# 2025-05-19 16:20:08,637 - INFO - Verified unique data for PATELENG: Latest price = Rs.39.87
# 2025-05-19 16:20:08,639 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:08,669 - INFO - Processing Rallis India Ltd. (RALLIS)
# 2025-05-19 16:20:08,854 - INFO - Verified unique data for PGIL: Latest price = Rs.1010.80
# ...
# 2025-05-19 16:20:12,306 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:12,328 - INFO - Processing Star Cement Ltd. (STARCEMENT)
# 2025-05-19 16:20:12,512 - INFO - Verified unique data for SHAREINDIA: Latest price = Rs.157.48
# 2025-05-19 16:20:12,513 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:12,541 - INFO - Processing Sterlite Technologies Ltd. (STLTECH)
# 2025-05-19 16:20:12,565 - INFO - Verified unique data for SFL: Latest price = Rs.657.55
# 2025-05-19 16:20:12,566 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:12,590 - INFO - Processing Strides Pharma Science Ltd. (STAR)
# 2025-05-19 16:20:12,802 - INFO - Verified unique data for SHILPAMED: Latest price = Rs.639.90
# 2025-05-19 16:20:12,805 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:12,827 - INFO - Processing Stylam Industries Ltd. (STYLAMIND)
# 2025-05-19 16:20:12,892 - INFO - Verified unique data for SBCL: Latest price = Rs.401.05
# 2025-05-19 16:20:12,893 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:12,916 - INFO - Processing Subros Ltd. (SUBROS)
# 2025-05-19 16:20:12,985 - INFO - Verified unique data for SHOPERSTOP: Latest price = Rs.495.20
# 2025-05-19 16:20:12,986 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:13,009 - INFO - Processing Sudarshan Chemical Industries Ltd. (SUDARSCHEM)
# 2025-05-19 16:20:13,078 - INFO - Verified unique data for SHRIPISTON: Latest price = Rs.1782.25
# 2025-05-19 16:20:13,079 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:13,101 - INFO - Processing Sula Vineyards Ltd. (SULA)
# 2025-05-19 16:20:13,192 - INFO - Verified unique data for SKIPPER: Latest price = Rs.426.20
# 2025-05-19 16:20:13,194 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:13,217 - INFO - Processing Sun Pharma Advanced Research Company Ltd. (SPARC)
# 2025-05-19 16:20:13,433 - INFO - Verified unique data for SOUTHBANK: Latest price = Rs.23.59
# 2025-05-19 16:20:13,434 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:13,470 - INFO - Processing Sunflag Iron & Steel Company Ltd. (SUNFLAG)
# 2025-05-19 16:20:13,482 - INFO - Verified unique data for SPANDANA: Latest price = Rs.240.20
# 2025-05-19 16:20:13,483 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:13,504 - INFO - Processing Sunteck Realty Ltd. (SUNTECK)
# 2025-05-19 16:20:13,526 - INFO - Verified unique data for STARCEMENT: Latest price = Rs.220.56
# 2025-05-19 16:20:13,527 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:13,549 - INFO - Processing Suprajit Engineering Ltd. (SUPRAJIT)
# 2025-05-19 16:20:13,797 - INFO - Verified unique data for STAR: Latest price = Rs.615.30
# 2025-05-19 16:20:13,801 - INFO - Verified unique data for STLTECH: Latest price = Rs.81.67
# 2025-05-19 16:20:13,802 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:13,803 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:13,847 - INFO - Processing Supriya Lifescience Ltd. (SUPRIYA)
# 2025-05-19 16:20:13,850 - INFO - Processing Surya Roshni Ltd. (SURYAROSNI)
# 2025-05-19 16:20:14,037 - INFO - Verified unique data for STYLAMIND: Latest price = Rs.1680.55
# 2025-05-19 16:20:14,038 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:14,059 - INFO - Processing Symphony Ltd. (SYMPHONY)
# 2025-05-19 16:20:14,099 - INFO - Verified unique data for SUBROS: Latest price = Rs.570.30
# 2025-05-19 16:20:14,100 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:14,123 - INFO - Processing TARC Ltd. (TARC)
# 2025-05-19 16:20:14,256 - INFO - Verified unique data for SUDARSCHEM: Latest price = Rs.1009.95
# 2025-05-19 16:20:14,257 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:14,279 - INFO - Processing TD Power Systems Ltd. (TDPOWERSYS)
# 2025-05-19 16:20:14,330 - INFO - Verified unique data for SULA: Latest price = Rs.275.50
# 2025-05-19 16:20:14,331 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:14,357 - INFO - Processing TVS Supply Chain Solutions Ltd. (TVSSCS)
# 2025-05-19 16:20:14,414 - INFO - Verified unique data for SPARC: Latest price = Rs.145.48
# 2025-05-19 16:20:14,415 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:14,445 - INFO - Processing Teamlease Services Ltd. (TEAMLEASE)
# 2025-05-19 16:20:14,635 - INFO - Verified unique data for SUNFLAG: Latest price = Rs.232.21
# 2025-05-19 16:20:14,636 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:14,662 - INFO - Processing Technocraft Industries (India) Ltd. (TIIL)
# 2025-05-19 16:20:14,699 - INFO - Verified unique data for SUNTECK: Latest price = Rs.373.50
# 2025-05-19 16:20:14,700 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:14,724 - INFO - Processing Tega Industries Ltd. (TEGA)
# 2025-05-19 16:20:14,788 - INFO - Verified unique data for SUPRAJIT: Latest price = Rs.381.80
# 2025-05-19 16:20:14,789 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:14,812 - INFO - Processing Texmaco Rail & Eng. Ltd. (TEXRAIL)
# 2025-05-19 16:20:15,056 - INFO - Verified unique data for SUPRIYA: Latest price = Rs.711.05
# 2025-05-19 16:20:15,057 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:15,081 - INFO - Processing Thangamayil Jewellery Ltd. (THANGAMAYL)
# 2025-05-19 16:20:15,127 - INFO - Verified unique data for SURYAROSNI: Latest price = Rs.247.48
# 2025-05-19 16:20:15,129 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:15,153 - INFO - Processing The Anup Engineering Ltd. (ANUP)
# 2025-05-19 16:20:15,320 - INFO - Verified unique data for SYMPHONY: Latest price = Rs.1135.75
# 2025-05-19 16:20:15,321 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:15,355 - INFO - Processing Thirumalai Chemicals Ltd. (TIRUMALCHM)
# 2025-05-19 16:20:15,367 - INFO - Verified unique data for TARC: Latest price = Rs.148.42
# 2025-05-19 16:20:15,369 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:15,392 - INFO - Processing Thomas Cook (India) Ltd. (THOMASCOOK)
# 2025-05-19 16:20:15,487 - INFO - Verified unique data for TDPOWERSYS: Latest price = Rs.408.75
# 2025-05-19 16:20:15,489 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:15,511 - INFO - Processing Tilaknagar Industries Ltd. (TI)
# 2025-05-19 16:20:15,641 - INFO - Verified unique data for TEAMLEASE: Latest price = Rs.1808.00
# 2025-05-19 16:20:15,642 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:15,663 - INFO - Processing Time Technoplast Ltd. (TIMETECHNO)
# 2025-05-19 16:20:15,942 - INFO - Verified unique data for TEGA: Latest price = Rs.1449.60
# 2025-05-19 16:20:15,947 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:15,988 - INFO - Processing Tips Music Ltd. (TIPSMUSIC)
# 2025-05-19 16:20:16,020 - INFO - Verified unique data for TIIL: Latest price = Rs.2304.20
# 2025-05-19 16:20:16,022 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:16,071 - INFO - Processing Transrail Lighting Ltd. (TRANSRAILL)
# 2025-05-19 16:20:16,098 - INFO - Verified unique data for TEXRAIL: Latest price = Rs.134.30
# 2025-05-19 16:20:16,101 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:16,165 - INFO - Processing Ujjivan Small Finance Bank Ltd. (UJJIVANSFB)
# 2025-05-19 16:20:16,183 - INFO - Verified unique data for TVSSCS: Latest price = Rs.110.21
# 2025-05-19 16:20:16,185 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:16,205 - INFO - Processing Unimech Aerospace and Manufacturing Ltd. (UNIMECH)
# 2025-05-19 16:20:16,327 - INFO - Verified unique data for THANGAMAYL: Latest price = Rs.2048.95
# 2025-05-19 16:20:16,328 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:16,353 - INFO - Processing V-Mart Retail Ltd. (VMART)
# 2025-05-19 16:20:16,425 - INFO - Verified unique data for ANUP: Latest price = Rs.3064.45
# 2025-05-19 16:20:16,427 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:16,450 - INFO - Processing V.I.P. Industries Ltd. (VIPIND)
# 2025-05-19 16:20:16,997 - INFO - Verified unique data for TIRUMALCHM: Latest price = Rs.261.54
# 2025-05-19 16:20:17,000 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,051 - INFO - Processing VST Industries Ltd. (VSTIND)
# 2025-05-19 16:20:17,055 - INFO - Verified unique data for THOMASCOOK: Latest price = Rs.131.31
# 2025-05-19 16:20:17,057 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,081 - INFO - Processing Va Tech Wabag Ltd. (WABAG)
# 2025-05-19 16:20:17,122 - INFO - Verified unique data for TI: Latest price = Rs.238.45
# 2025-05-19 16:20:17,123 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,147 - INFO - Processing Vaibhav Global Ltd. (VAIBHAVGBL)
# 2025-05-19 16:20:17,187 - INFO - Verified unique data for TIMETECHNO: Latest price = Rs.351.25
# 2025-05-19 16:20:17,189 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,219 - INFO - Processing Varroc Engineering Ltd. (VARROC)
# 2025-05-19 16:20:17,255 - INFO - Verified unique data for TRANSRAILL: Latest price = Rs.453.25
# 2025-05-19 16:20:17,268 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,294 - INFO - Processing Ventive Hospitality Ltd. (VENTIVE)
# 2025-05-19 16:20:17,335 - INFO - Verified unique data for TIPSMUSIC: Latest price = Rs.641.15
# 2025-05-19 16:20:17,336 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,379 - INFO - Processing Venus Pipes & Tubes Ltd. (VENUSPIPES)
# 2025-05-19 16:20:17,416 - INFO - Verified unique data for UNIMECH: Latest price = Rs.904.60
# 2025-05-19 16:20:17,422 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,449 - INFO - Processing Vesuvius India Ltd. (VESUVIUS)
# 2025-05-19 16:20:17,464 - INFO - Verified unique data for UJJIVANSFB: Latest price = Rs.39.77
# 2025-05-19 16:20:17,467 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,493 - INFO - Processing Voltamp Transformers Ltd (VOLTAMP)
# 2025-05-19 16:20:17,538 - INFO - Verified unique data for VMART: Latest price = Rs.3148.95
# 2025-05-19 16:20:17,539 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,564 - INFO - Processing Websol Energy System Ltd. (WEBELSOLAR)
# 2025-05-19 16:20:17,781 - INFO - Verified unique data for VIPIND: Latest price = Rs.267.20
# 2025-05-19 16:20:17,782 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:17,805 - INFO - Processing Welspun Enterprises Ltd. (WELENT)
# 2025-05-19 16:20:18,251 - INFO - Verified unique data for WABAG: Latest price = Rs.1401.60
# 2025-05-19 16:20:18,252 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:18,279 - INFO - Processing Wonderla Holidays Ltd. (WONDERLA)
# 2025-05-19 16:20:18,323 - INFO - Verified unique data for VSTIND: Latest price = Rs.273.70
# 2025-05-19 16:20:18,325 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:18,352 - INFO - Processing Yatharth Hospital & Trauma Care Services Ltd. (YATHARTH)
# 2025-05-19 16:20:18,394 - INFO - Verified unique data for VARROC: Latest price = Rs.407.10
# 2025-05-19 16:20:18,404 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:18,465 - INFO - Processing Zaggle Prepaid Ocean Services Ltd. (ZAGGLE)
# 2025-05-19 16:20:18,479 - INFO - Verified unique data for VAIBHAVGBL: Latest price = Rs.211.18
# 2025-05-19 16:20:18,480 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:18,519 - INFO - Processing Zinka Logistics Solutions Ltd. (BLACKBUCK)
# 2025-05-19 16:20:18,535 - INFO - Verified unique data for VENTIVE: Latest price = Rs.714.75
# 2025-05-19 16:20:18,536 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:18,556 - INFO - Processing Zydus Wellness Ltd. (ZYDUSWELL)
# 2025-05-19 16:20:18,699 - INFO - Verified unique data for VENUSPIPES: Latest price = Rs.1197.35
# 2025-05-19 16:20:18,701 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:18,729 - INFO - Processing eMudhra Ltd. (EMUDHRA)
# 2025-05-19 16:20:18,817 - INFO - Verified unique data for VESUVIUS: Latest price = Rs.4394.76
# 2025-05-19 16:20:18,819 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:18,880 - INFO - Verified unique data for VOLTAMP: Latest price = Rs.6977.50
# 2025-05-19 16:20:18,882 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:18,934 - INFO - Verified unique data for WEBELSOLAR: Latest price = Rs.1263.15
# 2025-05-19 16:20:18,936 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:19,017 - INFO - Verified unique data for WELENT: Latest price = Rs.488.40
# 2025-05-19 16:20:19,018 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:19,523 - INFO - Verified unique data for YATHARTH: Latest price = Rs.453.25
# 2025-05-19 16:20:19,524 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:19,589 - INFO - Verified unique data for WONDERLA: Latest price = Rs.691.70
# 2025-05-19 16:20:19,590 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:19,690 - INFO - Verified unique data for BLACKBUCK: Latest price = Rs.396.30
# 2025-05-19 16:20:19,691 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:19,903 - INFO - Verified unique data for ZYDUSWELL: Latest price = Rs.1748.10
# 2025-05-19 16:20:19,906 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:19,980 - INFO - Verified unique data for EMUDHRA: Latest price = Rs.840.90
# 2025-05-19 16:20:19,983 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-05-19 16:20:20,049 - INFO - Verified unique data for ZAGGLE: Latest price = Rs.320.90
# 2025-05-19 16:20:20,050 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)

# %%
# Green color ANSI escape code
GREEN = '\033[92m'
RESET = '\033[0m'  # Reset color code

print(f"{GREEN}Nifty Stocks Processed {len(stocks_nifty)} \nMidcap Stocks Processed {len(stocks_midcap)} \nSmallcap Stocks Processed {len(stocks_smallcap)} \nMicrocap Stocks Processed {len(stocks_microcap)}{RESET}")
print(f"{GREEN}Total Stocks Processed {len(stocks_nifty)+len(stocks_midcap)+len(stocks_smallcap)+len(stocks_microcap)}{RESET}")
# Out:
# Nifty Stocks Processed 50
# Midcap Stocks Processed 150
# Smallcap Stocks Processed 250
# Microcap Stocks Processed 250
# Total Stocks Processed 700

# %%
# price is a factor for our company, so we're going to use a low cost model

MODEL = "gemini-2.0-flash"
db_name = "vector_db"
path = "stock_analysis/reports_v2/*"

# %%
load_dotenv()
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY', 'your-key-if-not-using-env')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
# Read in documents using LangChain's loaders
# Take everything in all the sub-folders of our knowledgebase

folders = glob.glob(path)
print("folders ", folders)
# With thanks to CG and Jon R, students on the course, for this fix needed for some users
text_loader_kwargs = {'encoding': 'utf-8'}
# If that doesn't work, some Windows users might need to uncomment the next line instead
# text_loader_kwargs={'autodetect_encoding': True}

documents = []
for folder in folders:
    # Extract category name from folder path (nifty_50, midcap_150, etc.)
    category = os.path.basename(folder)
    loader = DirectoryLoader(folder, glob="**/*.md", loader_cls=TextLoader, loader_kwargs=text_loader_kwargs)
    folder_docs = loader.load()
    for doc in folder_docs:
        # Extract stock symbol from filename (e.g., HDFC.md -> HDFC)
        filename = os.path.basename(doc.metadata["source"])
        symbol = os.path.splitext(filename)[0]

        # Add structured metadata
        doc.metadata["category"] = category  # Explicit category field
        doc.metadata["stock_category"] = category  # Alternative name for filtering
        doc.metadata["symbol"] = symbol  # Add symbol for stock-specific searches
        doc.metadata["doc_type"] = category  # Keep original for compatibility
        documents.append(doc)

    print(f"Loaded {len(folder_docs)} documents from {category}")
# Out:
# folders  ['stock_analysis/reports_v2\\microcap_250', 'stock_analysis/reports_v2\\midcap_150', 'stock_analysis/reports_v2\\nifty_50', 'stock_analysis/reports_v2\\smallcap_250']
# Loaded 250 documents from microcap_250
# Loaded 150 documents from midcap_150
# Loaded 50 documents from nifty_50
# Loaded 250 documents from smallcap_250

# %%
# Add preprocessing to ensure key information like normalized z-score rank is prominently included
documents_with_enhanced_context = []
for doc in documents:
    # Extract the most important ranking information from the document
    normalized_z_rank = re.findall(r'Normalized Z-Score Rank: (\d+) out of (\d+)', doc.page_content)
    weighted_z_rank = re.findall(r'Weighted Z-Score Rank: (\d+) out of (\d+)', doc.page_content)
    one_year_rank = re.findall(r'1-Year Momentum Rank: (\d+) out of (\d+)', doc.page_content)
    six_month_rank = re.findall(r'6-Month Momentum Rank: (\d+) out of (\d+)', doc.page_content)

    # Get universe/category information
    universe_match = re.search(r'Universe/Category: ([^\n]+)', doc.page_content)
    universe = universe_match.group(1) if universe_match else None

    # Get stock name and symbol from the first line (usually contains "# Company Name (SYMBOL) Analysis")
    stock_info = re.search(r'# (.*?) \((.*?)\)', doc.page_content)
    company_name = stock_info.group(1) if stock_info else "Unknown Company"
    symbol = stock_info.group(2) if stock_info else "UNKNOWN"

    # Extract current price and performance metrics
    current_price_match = re.search(r'Current Price: Rs\.([0-9.]+)', doc.page_content)
    current_price = current_price_match.group(1) if current_price_match else None

    one_year_change_match = re.search(r'1-Year Change: ([0-9.-]+)%', doc.page_content)
    one_year_change = one_year_change_match.group(1) if one_year_change_match else None

    six_month_change_match = re.search(r'6-Month Change: ([0-9.-]+)%', doc.page_content)
    six_month_change = six_month_change_match.group(1) if six_month_change_match else None

    # If the document contains rank information, enhance its representation
    rank_summary = f"STOCK RANKING INFORMATION - HIGH PRIORITY:\n"
    rank_summary += f"Stock: {company_name} ({symbol})\n"

    if universe:
        rank_summary += f"Universe/Category: {universe}\n"

    if current_price:
        rank_summary += f"Current Price: Rs.{current_price}\n"

    if one_year_change:
        rank_summary += f"1-Year Change: {one_year_change}%\n"

    if six_month_change:
        rank_summary += f"6-Month Change: {six_month_change}%\n"

    # Add ranking information with special formatting to make it stand out
    if normalized_z_rank:
        rank_summary += f"===NORMALIZED Z-SCORE RANK: {normalized_z_rank[0][0]} OUT OF {normalized_z_rank[0][1]}===\n"

    if weighted_z_rank:
        rank_summary += f"===WEIGHTED Z-SCORE RANK: {weighted_z_rank[0][0]} OUT OF {weighted_z_rank[0][1]}===\n"

    if one_year_rank:
        rank_summary += f"===1-YEAR MOMENTUM RANK: {one_year_rank[0][0]} OUT OF {one_year_rank[0][1]}===\n"

    if six_month_rank:
        rank_summary += f"===6-MONTH MOMENTUM RANK: {six_month_rank[0][0]} OUT OF {six_month_rank[0][1]}===\n"

    # Prepend the summary to the document content (THREE times to heavily emphasize it)
    # This ensures that the ranking information gets the highest weight in the embedding
    doc.page_content = rank_summary + "\n" + rank_summary + "\n" + rank_summary + "\n" + doc.page_content

    # Also add key information to metadata for filtering
    if normalized_z_rank:
        doc.metadata['normalized_z_rank'] = int(normalized_z_rank[0][0])
        doc.metadata['normalized_z_total'] = int(normalized_z_rank[0][1])

    if weighted_z_rank:
        doc.metadata['weighted_z_rank'] = int(weighted_z_rank[0][0])
        doc.metadata['weighted_z_total'] = int(weighted_z_rank[0][1])

    if one_year_rank:
        doc.metadata['one_year_rank'] = int(one_year_rank[0][0])
        doc.metadata['one_year_total'] = int(one_year_rank[0][1])

    if six_month_rank:
        doc.metadata['six_month_rank'] = int(six_month_rank[0][0])
        doc.metadata['six_month_total'] = int(six_month_rank[0][1])

    documents_with_enhanced_context.append(doc)

# Use the enhanced documents for chunking - adjust the chunking strategy to preserve entire rank sections
text_splitter = CharacterTextSplitter(
    chunk_size=1800,  # Increase chunk size to ensure rank sections stay together
    chunk_overlap=400,  # Increase overlap for better context preservation
    separator="\n\n",  # Split on paragraph boundaries
    add_start_index=True
)

chunks = text_splitter.split_documents(documents_with_enhanced_context)


# Print some examples of the metadata to verify
for i in range(min(3, len(chunks))):
    print(f"Chunk {i} metadata: {chunks[i].metadata}")
# Out:
# Chunk 0 metadata: {'source': 'stock_analysis\\reports_v2\\microcap_250\\AARTIDRUGS.md', 'category': 'microcap_250', 'stock_category': 'microcap_250', 'symbol': 'AARTIDRUGS', 'doc_type': 'microcap_250', 'normalized_z_rank': 224, 'normalized_z_total': 244, 'weighted_z_rank': 224, 'weighted_z_total': 244, 'one_year_rank': 225, 'one_year_total': 250, 'six_month_rank': 226, 'six_month_total': 250, 'start_index': 0}
# Chunk 1 metadata: {'source': 'stock_analysis\\reports_v2\\microcap_250\\AARTIDRUGS.md', 'category': 'microcap_250', 'stock_category': 'microcap_250', 'symbol': 'AARTIDRUGS', 'doc_type': 'microcap_250', 'normalized_z_rank': 224, 'normalized_z_total': 244, 'weighted_z_rank': 224, 'weighted_z_total': 244, 'one_year_rank': 225, 'one_year_total': 250, 'six_month_rank': 226, 'six_month_total': 250, 'start_index': 1287}
# Chunk 2 metadata: {'source': 'stock_analysis\\reports_v2\\microcap_250\\AARTIDRUGS.md', 'category': 'microcap_250', 'stock_category': 'microcap_250', 'symbol': 'AARTIDRUGS', 'doc_type': 'microcap_250', 'normalized_z_rank': 224, 'normalized_z_total': 244, 'weighted_z_rank': 224, 'weighted_z_total': 244, 'one_year_rank': 225, 'one_year_total': 250, 'six_month_rank': 226, 'six_month_total': 250, 'start_index': 2884}

# %%
len(chunks)
# Out:
# 2079

# %%
doc_types = set(chunk.metadata['doc_type'] for chunk in chunks)
print(f"Document types found: {', '.join(doc_types)}")
# Out:
# Document types found: midcap_150, nifty_50, smallcap_250, microcap_250

# %%
# Put the chunks of data into a Vector Store that associates a Vector Embedding with each chunk

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Delete if already exists

if os.path.exists(db_name):
    Chroma(persist_directory=db_name, embedding_function=embeddings).delete_collection()

# Create vectorstore

vectorstore = vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=db_name,
    collection_metadata={"hnsw:space": "cosine"}  # Explicitly specify distance metric
)
print(f"Vectorstore created with {vectorstore._collection.count()} documents")

collection = vectorstore._collection
sample_embedding = collection.get(limit=1, include=["embeddings"])["embeddings"][0]
dimensions = len(sample_embedding)
print(f"The vectors have {dimensions:,} dimensions")
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_22668\1568052698.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# 2025-05-19 16:20:35,675 - INFO - PyTorch version 2.7.0 available.
# 2025-05-19 16:20:35,678 - INFO - Duckdb version 1.2.1 available.
# 2025-05-19 16:20:36,059 - INFO - Use pytorch device_name: cpu
# 2025-05-19 16:20:36,060 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# C:\Users\anand\AppData\Local\Temp\ipykernel_22668\1568052698.py:8: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   Chroma(persist_directory=db_name, embedding_function=embeddings).delete_collection()
# 2025-05-19 16:20:39,994 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# Vectorstore created with 2079 documents
# The vectors have 384 dimensions

# %%
# Prework for chroma vectors

result = collection.get(include=['embeddings', 'documents', 'metadatas'])
vectors = np.array(result['embeddings'])
documents = result['documents']
doc_types = [metadata['doc_type'] for metadata in result['metadatas']]
colors = [['blue', 'green', 'red', 'orange'][['nifty_50', 'midcap_150', 'smallcap_250','microcap_250'].index(t)] for t in doc_types]

# %%
def create_2d_visualization():
    # We humans find it easier to visalize things in 2D!
    tsne = TSNE(n_components=2, random_state=42, perplexity=min(25, len(vectors) - 1))
    reduced_vectors = tsne.fit_transform(vectors)

    # Create the 2D scatter plot with improved layout for side-by-side display
    fig = go.Figure(data=[go.Scatter(
        x=reduced_vectors[:, 0],
        y=reduced_vectors[:, 1],
        mode='markers',
        marker=dict(size=5, color=colors, opacity=0.8),
        text=[f"Type: {t}<br>Text: {d[:100]}..." for t, d in zip(doc_types, documents)],
        hoverinfo='text'
    )])

    fig.update_layout(
        margin=dict(r=10, b=10, l=10, t=10),  # Minimize margins
        template="plotly_white",
        autosize=True,
        hovermode="closest",
        height=None,  # Let height be determined by container
        width=None    # Let width be determined by container
    )

    return fig

def create_3d_visualization():
    tsne = TSNE(n_components=3, random_state=42, perplexity=min(25, len(vectors) - 1))
    reduced_vectors = tsne.fit_transform(vectors)

    # Create the 3D scatter plot with improved layout for side-by-side display
    fig = go.Figure(data=[go.Scatter3d(
        x=reduced_vectors[:, 0],
        y=reduced_vectors[:, 1],
        z=reduced_vectors[:, 2],
        mode='markers',
        marker=dict(size=4, color=colors, opacity=0.7),  # Smaller markers for better performance
        text=[f"Type: {t}<br>Text: {d[:100]}..." for t, d in zip(doc_types, documents)],
        hoverinfo='text'
    )])

    fig.update_layout(
        scene=dict(
            xaxis_title='x',
            yaxis_title='y',
            zaxis_title='z',
            aspectmode='data'  # Better fitting for the container
        ),
        margin=dict(r=0, b=0, l=0, t=0),  # Minimize margins
        template="plotly_white",
        autosize=True,
        height=None,  # Let height be determined by container
        width=None    # Let width be determined by container
    )

    return fig

# %%
print(f"Total chunks in vectorstore: {len(chunks)}")
print(f"Total unique stocks: 621")
print(f"Average chunks per stock: {len(chunks)/621:.2f}")

# Calculate recommended k value
recommended_k = len(chunks)  # Start with maximum possible chunks
print(f"Recommended k value: {recommended_k}")
# Out:
# Total chunks in vectorstore: 2079
# Total unique stocks: 621
# Average chunks per stock: 3.35
# Recommended k value: 2079

# %%
TEMPLATE = """
You are a financial advisor specializing in the Indian stock market analysis.
Use the following pieces of context to answer the question at the end.
Always respond in English only.
Focus on providing factual information from the given context.

If the question is about a specific category of stocks (like "Nifty 50", "midcap", "smallcap", or "microcap"):
- Group your answer by the requested category
- Present information as a well-organized list
- Include key metrics like price, momentum scores, and rankings when available
- When asked for rankings or "top stocks", ALWAYS sort by Normalized Z-Score Rank in ascending order (Rank 1 is best) unless another specific rank type is mentioned
- When asked for "top 10" or similar, return EXACTLY the stocks with ranks 1-10, not any random 10 stocks
- Be very precise about the category - never mix stocks from different categories (e.g., don't include microcap stocks when asked about smallcap or don't mix stocks from one universe to other)

If the question mentions "normalized z-score" or "normalized z-score rank":
- THIS IS EXTREMELY IMPORTANT: Sort results by Normalized Z-Score Rank in ascending order (Rank 1 is best)
- Include ONLY stocks that have this specific rank information
- Present results with lowest rank numbers first (1, 2, 3, etc.)
- Include the stock symbol, company name, and the exact Normalized Z-Score Rank value
- Example format for each stock: "Company Name (SYMBOL) - Normalized Z-Score Rank: X out of Y"

If the question mentions "weighted z-score" or "weighted z-score rank":
- Sort results by Weighted Z-Score Rank in ascending order (Rank 1 is best)
- Include ONLY stocks that have this specific rank information
- Present results with lowest rank numbers first (1, 2, 3, etc.)
- Include the stock symbol, company name, and the exact Weighted Z-Score Rank value

If the question mentions "momentum", "positive momentum", "strong performance" or similar terms:
- Focus on stocks with positive momentum indicators such as:
  * Positive 1-year or 6-month price change (>0%)
  * Strong RSI values (above 50)
  * Good momentum ranks (in top 40% of their category)
  * Positive MACD indicators
  * Price above key moving averages
- Sort results by momentum ranks when available (Rank 1 is best)
- Be explicit about which momentum criteria you're using

If the question is about a specific stock, make sure to include:
- Technical indicators (RSI, MACD, etc.) if available
- Price performance data
- Strength and weakness analysis
- Momentum rankings if available

If you don't know the answer based on the given context, just say you don't have enough information.
Don't make up information that isn't provided in the context.

Context:
{context}

Question: {question}

Helpful Answer (in English only):
"""

# %%
prompt = PromptTemplate(template=TEMPLATE, input_variables=["context", "question"])

# %%
# Set up the base retriever parameters
max_k = min(100, len(chunks) // 10)  # Cap at 100 or 10% of chunks, whichever is smaller

# %%
def process_category_query(query, vectorstore):
    """Add category-specific processing for better retrieval"""
    query_lower = query.lower()

    # Define category keywords and mappings
    categories = {
        "nifty 50": "nifty_50",
        "nifty50": "nifty_50",
        "nifty": "nifty_50",
        "midcap": "midcap_150",
        "mid-cap": "midcap_150",
        "mid cap": "midcap_150",
        "smallcap": "smallcap_250",
        "small-cap": "smallcap_250",
        "small cap": "smallcap_250",
        "microcap": "microcap_250",
        "micro-cap": "microcap_250",
        "micro cap": "microcap_250"
    }

    # Check if query contains category keywords
    detected_category = None
    for keyword, folder_name in categories.items():
        pattern = r'\b' + re.escape(keyword) + r'\b'
        if re.search(pattern, query_lower):
            detected_category = folder_name
            print(f"Detected category: {detected_category}")
            break
        if keyword in query_lower:
            detected_category = folder_name
            print(f"Detected category: {detected_category}")
            break

    # Check for momentum or performance filter
    momentum_filter = False
    momentum_keywords = ["momentum", "positive momentum", "strong momentum", "good performance",
                         "top performing", "top stocks", "best stocks", "positive return"]

    # Check for rank-based queries
    rank_based_query = bool(re.search(r'top\s+\d+|best\s+\d+', query_lower))
    rank_keywords = ["rank", "ranking", "ranked", "momentum rank", "z-score rank"]

    for keyword in momentum_keywords:
        if keyword in query_lower:
            momentum_filter = True
            print(f"Detected momentum filter: {keyword}")
            break

    for keyword in rank_keywords:
        if keyword in query_lower:
            momentum_filter = True
            print(f"Detected rank filter: {keyword}")
            break

    # Around line 2940-2965
    if detected_category:
        # Use metadata filtering with the vectorstore
        filtered_retriever = vectorstore.as_retriever(
            search_type="mmr",
            search_kwargs={
                "k": max_k,
                "fetch_k": max_k * 3,
                "lambda_mult": 0.6,
                "filter": {
                    # Use multiple metadata fields for redundant filtering
                    "$and": [
                        {"doc_type": detected_category},
                        {"category": detected_category}
                    ]
                }
            }
        )
        return filtered_retriever, detected_category, momentum_filter or rank_based_query

    # If no category detected, return the default retriever
    return vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={
            "k": max_k,
            "fetch_k": max_k * 2,
            "lambda_mult": 0.7,
        }
    ), None, momentum_filter or rank_based_query

# %%
def debug_retrieval(query):
    """Test function to check what documents are being retrieved for a query"""
    # Get the query keywords
    query_lower = query.lower()

    # Check for category keywords
    categories = {
        "nifty 50": "nifty_50",
        "nifty50": "nifty_50",
        "nifty": "nifty_50",
        "midcap": "midcap_150",
        "mid-cap": "midcap_150",
        "mid cap": "midcap_150",
        "smallcap": "smallcap_250",
        "small-cap": "smallcap_250",
        "small cap": "smallcap_250",
        "microcap": "microcap_250",
        "micro-cap": "microcap_250",
        "micro cap": "microcap_250"
    }

    detected = False
    for keyword, category in categories.items():
        if keyword in query_lower:
            print(f"Found category keyword '{keyword}' -> '{category}'")
            detected = True

    if not detected:
        print("No category keyword detected in query")

    # Test retrieval with the process_category_query
    specific_retriever = process_category_query(query, vectorstore)
    docs = specific_retriever.get_relevant_documents(query)

    # Check document metadata
    print(f"\nRetrieved {len(docs)} documents")
    categories_found = {}

    for i, doc in enumerate(docs[:5]):  # Check first 5 docs
        doc_type = doc.metadata.get('doc_type', 'unknown')
        categories_found[doc_type] = categories_found.get(doc_type, 0) + 1
        if i < 3:  # Show details for first 3 docs
            print(f"\nDocument {i+1}:")
            print(f"  Metadata: {doc.metadata}")
            print(f"  Content (first 100 chars): {doc.page_content[:100]}...")

    print("\nDocument categories distribution:")
    for cat, count in categories_found.items():
        print(f"  - {cat}: {count} documents")

    return docs

# Uncomment and run this to debug specific queries
# debug_retrieval("Show me Nifty 50 stocks")
# debug_retrieval("List midcap stocks with good RSI")
# debug_retrieval("What are the smallcap stocks with strong momentum?")
# debug_retrieval("Show me microcap stocks")

# %%
class DynamicCategoryRetriever(BaseRetriever):
    vectorstore: Any = Field(description="Vector store for embeddings")

    class Config:
        """Configuration for this pydantic object."""
        arbitrary_types_allowed = True

    def get_relevant_documents(self, query: str) -> List[Document]:
        # Get the appropriate retriever based on query content
        specific_retriever, category, has_momentum_or_rank_filter = process_category_query(query, self.vectorstore)

        # Use it to retrieve documents
        docs = specific_retriever.get_relevant_documents(query)

        # Check if this is a rank-based query (like "top 10 stocks")
        rank_based_query = bool(re.search(r'top\s+\d+|best\s+\d+', query.lower()))

        # Apply additional momentum/ranking filtering if needed
        if (has_momentum_or_rank_filter or rank_based_query) and len(docs) > 0:
            # We'll increase the number of documents retrieved for rank-based queries
            # to ensure we have enough data to find the truly top-ranked stocks
            if rank_based_query and category:
                print(f"Rank-based query detected for {category}. Retrieved {len(docs)} documents.")
                # The actual sorting will be handled by the LLM with the improved prompt

        return docs

    async def aget_relevant_documents(self, query: str) -> List[Document]:
        # Just call the synchronous version for simplicity
        return self.get_relevant_documents(query)
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_22668\2350124086.py:1: DeprecationWarning: Retrievers must implement abstract `_get_relevant_documents` method instead of `get_relevant_documents`
#   class DynamicCategoryRetriever(BaseRetriever):
# C:\Users\anand\AppData\Local\Temp\ipykernel_22668\2350124086.py:1: DeprecationWarning: Retrievers must implement abstract `_aget_relevant_documents` method instead of `aget_relevant_documents`
#   class DynamicCategoryRetriever(BaseRetriever):

# %%
# create a new Chat with GenerativeAI
llm = ChatGoogleGenerativeAI(model=MODEL, temperature=0.7, google_api_key = GOOGLE_API_KEY)

# set up the conversation memory for the chat
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True, output_key='answer')

# Create the dynamic retriever
retriever = DynamicCategoryRetriever(vectorstore=vectorstore)

# Create the conversation chain as a global variable so it's accessible
global conversation_chain
conversation_chain = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=retriever,
    memory=memory,
    combine_docs_chain_kwargs={"prompt": prompt},
    return_source_documents=True
)
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_22668\3609644246.py:5: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True, output_key='answer')

# %%
# Function to inspect the vectorstore for category distribution
def inspect_vectorstore_categories(vectorstore):
    collection = vectorstore._collection
    result = collection.get(include=['metadatas'], limit=1000)

    metadatas = result['metadatas']
    categories = {}

    print(f"Inspecting {len(metadatas)} documents in vectorstore")

    # Count documents by doc_type (category)
    for metadata in metadatas:
        doc_type = metadata.get('doc_type', 'unknown')
        categories[doc_type] = categories.get(doc_type, 0) + 1

    print("\nDocument distribution by category:")
    for category, count in categories.items():
        print(f"  - {category}: {count} documents")

    return categories

# Run this to check your vectorstore category distribution
categories_in_db = inspect_vectorstore_categories(vectorstore)
# Out:
# Inspecting 1000 documents in vectorstore
#
# Document distribution by category:
#   - microcap_250: 744 documents
#   - midcap_150: 256 documents

# %%
# # Debug function to inspect metadata in the vectorstore
# def inspect_vectorstore_metadata(vectorstore, n_samples=5):
#     collection = vectorstore._collection
#     result = collection.get(include=['embeddings', 'documents', 'metadatas'], limit=100)

#     metadatas = result['metadatas']
#     categories = {}

#     print(f"\n=== Inspecting metadata for {len(metadatas)} documents ===")

#     # Count documents by category
#     for metadata in metadatas:
#         category = metadata.get('category', metadata.get('doc_type', 'unknown'))
#         categories[category] = categories.get(category, 0) + 1

#     print("\nDocuments by category:")
#     for category, count in categories.items():
#         print(f"  - {category}: {count} documents")

#     # Show sample metadata entries
#     print(f"\nSample metadata entries ({n_samples}):")
#     for i, metadata in enumerate(metadatas[:n_samples]):
#         print(f"\nDocument {i+1}:")
#         for key, value in metadata.items():
#             print(f"  {key}: {value}")

#     return categories

# # Run the inspection after creating the vectorstore
# categories = inspect_vectorstore_metadata(vectorstore)

# %%
def chat(message, history):
    global conversation_chain  # Explicitly use the global variable
    try:
        # Check for normalized z-score keywords in the query
        normalized_z_keywords = ["normalized z-score", "normalized z score", "normalized z-score rank", "normalized z score rank"]
        has_normalized_z = any(keyword in message.lower() for keyword in normalized_z_keywords)

        # Check for weighted z-score keywords in the query
        weighted_z_keywords = ["weighted z-score", "weighted z score", "weighted z-score rank", "weighted z score rank"]
        has_weighted_z = any(keyword in message.lower() for keyword in weighted_z_keywords)

        # Check for generic rank keywords that should use normalized z-score as default
        generic_rank_keywords = ["rank", "ranking", "top stocks", "best stocks"]
        has_generic_rank = any(keyword in message.lower() for keyword in generic_rank_keywords) and not has_normalized_z and not has_weighted_z

        # Check for momentum keywords in the query
        momentum_keywords = ["momentum", "positive momentum", "strong momentum", "good performance",
                           "top performing", "top stocks", "best stocks", "positive return"]
        has_momentum_filter = any(keyword in message.lower() for keyword in momentum_keywords)

        # Check for rank-based queries (top N stocks)
        rank_based_query = bool(re.search(r'top\s+\d+|best\s+\d+', message.lower()))
        rank_keywords = ["rank", "ranking", "ranked", "momentum rank"]
        has_rank_filter = any(keyword in message.lower() for keyword in rank_keywords)

        # If it's a normalized z-score query or generic rank query, add instructions
        if has_normalized_z or has_generic_rank:
            print("Detected normalized z-score or generic rank query, using normalized z-score rank...")
            message = message + " (Please sort results by Normalized Z-Score Rank in ascending order, with Rank 1 being the best. Format each result as 'Company Name (SYMBOL) - Normalized Z-Score Rank: X out of Y')"

        # If it's a weighted z-score query, add instructions
        elif has_weighted_z:
            print("Detected weighted z-score query, adding special instructions...")
            message = message + " (Please sort results by Weighted Z-Score Rank in ascending order, with Rank 1 being the best. Format each result as 'Company Name (SYMBOL) - Weighted Z-Score Rank: X out of Y')"

        # If it's a momentum or rank query, add instructions
        elif has_momentum_filter or rank_based_query or has_rank_filter:
            print("Detected momentum or rank-based query, adding context...")

            # For "top N" queries specifically about ranks, add explicit sorting instructions
            if rank_based_query or has_rank_filter:
                print("Adding rank sorting instructions...")
                # Modify the query to explicitly instruct sorting by rank (1 is best)
                message = message + " (Please sort by momentum rank in ascending order, with Rank 1 being the best)"

        result = conversation_chain.invoke({"question": message})
        return result["answer"]
    except Exception as e:
        print(f"Error in chat function: {e}")
        return f"Sorry, an error occurred: {str(e)}"

# %%
# Define custom CSS for better spacing and layout

# css = """
# .gradio-container {max-width: 1200px !important; margin-left: auto !important; margin-right: auto !important;}
# .plot-container {width: 100% !important; display: flex !important; justify-content: center !important;}
# .visualization-row {display: flex !important; justify-content: space-between !important; width: 100% !important;}
# .visualization-column {flex: 1 !important; padding: 0 10px !important;}
# """

css = """
.gradio-container {
    max-width: 100% !important;
    width: 100% !important;
    margin: 0 !important;
    padding: 0 !important;
    min-height: 100vh !important;
}

/* Main row container */
.app-container {
    display: flex;
    min-height: 100vh;
}

/* Chat container styling */
.chat-container {
    display: flex;
    flex-direction: column;
    min-height: 100vh;
}

/* Target the chatbot message container */
.chat-container > .prose {
    flex: 1;
}

/* Make the message container scrollable */
.message-wrap, .chatbot-message-container {
    height: calc(100vh - 180px) !important;
    max-height: none !important;
    overflow-y: auto !important;
}

/* Visualization container styling */
.plots-container {
    display: flex;
    flex-direction: column;
    min-height: 100vh;
}

.plot-3d-container, .plot-2d-container {
    height: 50vh;
    width: 100%;
}

/* Make plot elements fill their containers */
.plot-container {
    width: 100% !important;
    height: 100% !important;
}

/* Responsive layout for smaller screens */
@media (max-width: 992px) {
    .app-container {
        flex-direction: column;
    }

    .chat-container, .plots-containers {
        min-height: 50vh;
    }

    .message-wrap, .chatbot-message-container {
        height: calc(50vh - 120px) !important;
    }
}
"""

# %%
# Create a Blocks interface with visualizations
with gr.Blocks(css=css, theme="soft") as view:
    with gr.Row(elem_classes="app-container"):
        # Left side - Chat interface
        with gr.Column(elem_classes="chat-container"):
            gr.HTML(f"<h2 style='text-align:center;'>Stock Market Analysis By AJ14314</h2><p style='text-align:center;'>Using model: <b>{MODEL}</b></p>")
            chat_interface = gr.ChatInterface(
                fn=chat,
                examples=[
                    "Show me all Nifty 50 stocks",
                    "List the top 10 performing midcap stocks",
                    "What are the smallcap stocks with positive momentum?",
                    "Show microcap stocks with highest ranks",
                    "Compare Reliance and TCS performance"
                ],
                description="Ask questions about Indian stocks to get insights based on technical analysis reports.",
                theme="soft",
                autofocus=True,
                fill_height=True
            )

        # Right side - Plots container with 3D on top and 2D below
        with gr.Column(elem_classes="plots-container"):
            # 3D Plot on top
            with gr.Column(elem_classes="plot-3d-container"):
                gr.HTML("<h3 style='text-align:center;'>3D Vector Space Visualization</h3>")
                plot_3d = gr.Plot(create_3d_visualization(), elem_id="plot-3d", container=True)

            # 2D Plot below
            with gr.Column(elem_classes="plot-2d-container"):
                gr.HTML("<h3 style='text-align:center;'>2D Vector Space Visualization</h3>")
                plot_2d = gr.Plot(create_2d_visualization(), elem_id="plot-2d", container=True)
# Out:
# c:\Users\anand\.conda\envs\llm_learnings\Lib\site-packages\gradio\chat_interface.py:338: UserWarning:
#
# The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#
# 2025-05-19 16:28:38,324 - INFO - HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 2025-05-19 16:28:38,402 - INFO - HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"

# %%
view.launch(inbrowser=True)
# Out:
# 2025-05-19 16:28:49,862 - INFO - HTTP Request: GET http://127.0.0.1:7862/gradio_api/startup-events "HTTP/1.1 200 OK"
# 2025-05-19 16:28:49,878 - INFO - HTTP Request: HEAD http://127.0.0.1:7862/ "HTTP/1.1 200 OK"
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
